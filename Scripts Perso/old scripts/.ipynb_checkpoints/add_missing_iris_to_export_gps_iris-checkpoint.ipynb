# %%
import pandas as pd

# %%
df = pd.read_csv('export_gps_iris_ALL.csv', dtype = {'Code postal 5 chiffres': str, 'Code commune INSEE': str,
                                             'code_iris_clean': str})
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-9feeba3e9773> in <module>
# ----> 1 df = pd.read_csv('export_gps_iris_ALL.csv', dtype = {'Code postal 5 chiffres': str, 'Code commune INSEE': str,
#       2                                              'code_iris_clean': str})
#       3 df.head()
#
# ~\anaconda\envs\Geo\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# ~\anaconda\envs\Geo\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# ~\anaconda\envs\Geo\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# ~\anaconda\envs\Geo\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# ~\anaconda\envs\Geo\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# ~\anaconda\envs\Geo\lib\site-packages\pandas\io\parsers.py in _open_handles(self, src, kwds)
#    1360         Let the readers open IOHanldes after they are done with their potential raises.
#    1361         """
# -> 1362         self.handles = get_handle(
#    1363             src,
#    1364             "r",
#
# ~\anaconda\envs\Geo\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     645                 errors = "replace"
#     646             # Encoding
# --> 647             handle = open(
#     648                 handle,
#     649                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'export_gps_iris_ALL.csv'

# %%
missing_iris = pd.read_csv('databases/gps_iris/iris_missing_completed.csv')
missing_iris.head()
# Out:
# C:\Users\olivier\anaconda\envs\Geo\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (9,10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    Unnamed: 0  index                               Adresse  Commune_Lat  \
# 0           0      5      CHAMP PORTIER 1370 VAL-REVERMONT          NaN
# 1           1     19  5340 IMP GRAND CHAMP 1310 SAINT-REMY    46.184664
# 2           2     38         6058  OUSSIAT 1160 PONT-D AIN          NaN
# 3           3     42             5136  LE BOURG 1160 PRIAY    46.019752
# 4           4     43                   LE BOURG 1160 PRIAY    46.019752
#
#    Commune_Lon       lon        lat Code departement  Code postal 5 chiffres  \
# 0          NaN  5.342953  46.264482               01                  1370.0
# 1     5.167714  6.161794  49.174718               01                  1310.0
# 2          NaN  5.361196  46.055795               01                  1160.0
# 3     5.285234  5.207310  46.069185               01                  1160.0
# 4     5.285234  5.207310  46.069185               01                  1160.0
#
#   Code commune INSEE code_iris_clean
# 0              01426       014260000
# 1              01385             NaN
# 2              01304       013040000
# 3              01314             NaN
# 4              01314             NaN

# %%
missing_iris = missing_iris.drop(columns = {'Unnamed: 0', 'index', 'Commune_Lat', 'Commune_Lon', 'lon', 'lat', 'Code departement',
                            'Code postal 5 chiffres', 'Code commune INSEE'})
missing_iris.head()
# Out:
#                                 Adresse code_iris_clean
# 0      CHAMP PORTIER 1370 VAL-REVERMONT       014260000
# 1  5340 IMP GRAND CHAMP 1310 SAINT-REMY             NaN
# 2         6058  OUSSIAT 1160 PONT-D AIN       013040000
# 3             5136  LE BOURG 1160 PRIAY             NaN
# 4                   LE BOURG 1160 PRIAY             NaN

# %%
dvf = df.merge(missing_iris, on = "Adresse", how = "left")
# Out:
#     Unnamed: 0  Code service CH  Reference document  1 Articles CGI  \
# 7            7              NaN                 NaN             NaN
# 8            8              NaN                 NaN             NaN
# 66          66              NaN                 NaN             NaN
# 85          85              NaN                 NaN             NaN
# 86          86              NaN                 NaN             NaN
#
#     2 Articles CGI  3 Articles CGI  4 Articles CGI  5 Articles CGI  \
# 7              NaN             NaN             NaN             NaN
# 8              NaN             NaN             NaN             NaN
# 66             NaN             NaN             NaN             NaN
# 85             NaN             NaN             NaN             NaN
# 86             NaN             NaN             NaN             NaN
#
#     No disposition Date mutation  ... Surface terrain  \
# 7                1    07/01/2020  ...            55.0
# 8                1    07/01/2020  ...            68.0
# 66               1    13/01/2020  ...           924.0
# 85               1    17/01/2020  ...           700.0
# 86               1    17/01/2020  ...          1361.0
#
#                                       Adresse  Commune_Lat Commune_Lon  \
# 7            CHAMP PORTIER 1370 VAL-REVERMONT          NaN         NaN
# 8            CHAMP PORTIER 1370 VAL-REVERMONT          NaN         NaN
# 66              6058  OUSSIAT 1160 PONT-D AIN          NaN         NaN
# 85  60 CHE DU MAS GAILLARD 1370 VAL-REVERMONT          NaN         NaN
# 86  60 CHE DU MAS GAILLARD 1370 VAL-REVERMONT          NaN         NaN
#
#          lon        lat Code postal 5 chiffres  Code commune INSEE  \
# 7   5.342953  46.264482                  01370               01426
# 8   5.342953  46.264482                  01370               01426
# 66  5.361196  46.055795                  01160               01304
# 85  5.336988  46.278457                  01370               01426
# 86  5.336988  46.278457                  01370               01426
#
#    code_iris_clean_x code_iris_clean_y
# 7                NaN         014260000
# 8                NaN         014260000
# 66               NaN         013040000
# 85               NaN         014260000
# 86               NaN         014260000
#
# [5 rows x 53 columns]

# %%
dvf['code_iris_clean'] = dvf['code_iris_clean_y'].where(dvf['code_iris_clean_x'].isna(), dvf['code_iris_clean_x'])

# %%
dvf[dvf['code_iris_clean_y'].isna()].head()
# Out:
#    Unnamed: 0  Code service CH  Reference document  1 Articles CGI  \
# 0           0              NaN                 NaN             NaN
# 1           1              NaN                 NaN             NaN
# 2           2              NaN                 NaN             NaN
# 3           3              NaN                 NaN             NaN
# 4           4              NaN                 NaN             NaN
#
#    2 Articles CGI  3 Articles CGI  4 Articles CGI  5 Articles CGI  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
#    No disposition Date mutation  ...                           Adresse  \
# 0               1    07/01/2020  ...           FORTUNAT 1250 CEYZERIAT
# 1               1    02/01/2020  ...  TERRES DES CINQ SAULES 1290 LAIZ
# 2               1    02/01/2020  ...      BOIS DU CHAMP RION 1290 LAIZ
# 3               1    02/01/2020  ...             EN COROBERT 1290 LAIZ
# 4               1    02/01/2020  ...  TERRES DES CINQ SAULES 1290 LAIZ
#
#    Commune_Lat  Commune_Lon       lon        lat Code postal 5 chiffres  \
# 0    46.183217     5.320072  5.323007  46.173753                  01250
# 1    46.246992     4.899335  4.892457  46.246330                  01290
# 2    46.246992     4.899335  4.892457  46.246330                  01290
# 3    46.246992     4.899335  4.881913  46.248368                  01290
# 4    46.246992     4.899335  4.892457  46.246330                  01290
#
#   Code commune INSEE  code_iris_clean_x code_iris_clean_y code_iris_clean
# 0              01072          010720000               NaN       010720000
# 1              01203          012030000               NaN       012030000
# 2              01203          012030000               NaN       012030000
# 3              01203          012030000               NaN       012030000
# 4              01203          012030000               NaN       012030000
#
# [5 rows x 54 columns]

# %%
dvf[dvf['code_iris_clean_x'].isna()].head()
# Out:
#     Unnamed: 0  Code service CH  Reference document  1 Articles CGI  \
# 7            7              NaN                 NaN             NaN
# 8            8              NaN                 NaN             NaN
# 33          33              NaN                 NaN             NaN
# 66          66              NaN                 NaN             NaN
# 73          73              NaN                 NaN             NaN
#
#     2 Articles CGI  3 Articles CGI  4 Articles CGI  5 Articles CGI  \
# 7              NaN             NaN             NaN             NaN
# 8              NaN             NaN             NaN             NaN
# 33             NaN             NaN             NaN             NaN
# 66             NaN             NaN             NaN             NaN
# 73             NaN             NaN             NaN             NaN
#
#     No disposition Date mutation  ...                               Adresse  \
# 7                1    07/01/2020  ...      CHAMP PORTIER 1370 VAL-REVERMONT
# 8                1    07/01/2020  ...      CHAMP PORTIER 1370 VAL-REVERMONT
# 33               1    09/01/2020  ...  5340 IMP GRAND CHAMP 1310 SAINT-REMY
# 66               1    13/01/2020  ...         6058  OUSSIAT 1160 PONT-D AIN
# 73               1    15/01/2020  ...             5136  LE BOURG 1160 PRIAY
#
#     Commune_Lat  Commune_Lon       lon        lat Code postal 5 chiffres  \
# 7           NaN          NaN  5.342953  46.264482                  01370
# 8           NaN          NaN  5.342953  46.264482                  01370
# 33    46.184664     5.167714  6.161794  49.174718                  01310
# 66          NaN          NaN  5.361196  46.055795                  01160
# 73    46.019752     5.285234  5.207310  46.069185                  01160
#
#    Code commune INSEE  code_iris_clean_x code_iris_clean_y code_iris_clean
# 7               01426                NaN         014260000       014260000
# 8               01426                NaN         014260000       014260000
# 33              01385                NaN               NaN             NaN
# 66              01304                NaN         013040000       013040000
# 73              01314                NaN               NaN             NaN
#
# [5 rows x 54 columns]

# %%
dvf = dvf.drop(columns = {'code_iris_clean_x', 'code_iris_clean_y'})
dvf.head()
# Out:
#    Unnamed: 0  Code service CH  Reference document  1 Articles CGI  \
# 0           0              NaN                 NaN             NaN
# 1           1              NaN                 NaN             NaN
# 2           2              NaN                 NaN             NaN
# 3           3              NaN                 NaN             NaN
# 4           4              NaN                 NaN             NaN
#
#    2 Articles CGI  3 Articles CGI  4 Articles CGI  5 Articles CGI  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
#    No disposition Date mutation  ... Nature culture speciale  Surface terrain  \
# 0               1    07/01/2020  ...                     NaN           1061.0
# 1               1    02/01/2020  ...                     NaN             85.0
# 2               1    02/01/2020  ...                     NaN           1115.0
# 3               1    02/01/2020  ...                     NaN           1940.0
# 4               1    02/01/2020  ...                     NaN           1148.0
#
#                             Adresse Commune_Lat Commune_Lon       lon  \
# 0           FORTUNAT 1250 CEYZERIAT   46.183217    5.320072  5.323007
# 1  TERRES DES CINQ SAULES 1290 LAIZ   46.246992    4.899335  4.892457
# 2      BOIS DU CHAMP RION 1290 LAIZ   46.246992    4.899335  4.892457
# 3             EN COROBERT 1290 LAIZ   46.246992    4.899335  4.881913
# 4  TERRES DES CINQ SAULES 1290 LAIZ   46.246992    4.899335  4.892457
#
#          lat  Code postal 5 chiffres Code commune INSEE code_iris_clean
# 0  46.173753                   01250              01072       010720000
# 1  46.246330                   01290              01203       012030000
# 2  46.246330                   01290              01203       012030000
# 3  46.248368                   01290              01203       012030000
# 4  46.246330                   01290              01203       012030000
#
# [5 rows x 52 columns]

# %%
dvf.to_csv('dvf_out_2020_cleaniris.csv')

# %%
dvf['code_iris_clean'].isna().sum()
# Out:
# 216012
