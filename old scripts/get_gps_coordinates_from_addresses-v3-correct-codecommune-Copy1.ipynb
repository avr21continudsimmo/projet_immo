# %% [markdown]
# # Constitution d'une base adresse à partir de fichiers DVF
# - Adresse complète
# - Code commune INSEE
# - Code IRIS (code quartier de l'INSEE)
# - Coordonnées GPS de la commune
# - Coorodnnées GPS de l'adresse

# %% [markdown]
# ## Lecture du fichier DVF

# %%
import warnings
from pandas.core.common import SettingWithCopyWarning
warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)

# %%
import pandas as pd
import numpy as np
from geopy.geocoders import Nominatim
import json
import requests
import time

# %%
# Renseigner ici la première ligne et la dernière ligne de la base adresses qui vont être utilisées
row_first = 819100
row_last = 900000

# %%
# Chargement du jeu de données
df = pd.read_csv('valeursfoncieres-2020.txt',sep="|",decimal=",")
df.head()
# Out:
# C:\Users\Charles\anaconda3\envs\CDV-perso\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (14,18,23,24,26,28,41) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    Code service CH  Reference document  1 Articles CGI  2 Articles CGI  \
# 0              NaN                 NaN             NaN             NaN
# 1              NaN                 NaN             NaN             NaN
# 2              NaN                 NaN             NaN             NaN
# 3              NaN                 NaN             NaN             NaN
# 4              NaN                 NaN             NaN             NaN
#
#    3 Articles CGI  4 Articles CGI  5 Articles CGI  No disposition  \
# 0             NaN             NaN             NaN               1
# 1             NaN             NaN             NaN               1
# 2             NaN             NaN             NaN               1
# 3             NaN             NaN             NaN               1
# 4             NaN             NaN             NaN               1
#
#   Date mutation Nature mutation  ...  Surface Carrez du 5eme lot  \
# 0    07/01/2020           Vente  ...                         NaN
# 1    02/01/2020           Vente  ...                         NaN
# 2    02/01/2020           Vente  ...                         NaN
# 3    02/01/2020           Vente  ...                         NaN
# 4    02/01/2020           Vente  ...                         NaN
#
#    Nombre de lots Code type local Type local Identifiant local  \
# 0               0             NaN        NaN               NaN
# 1               0             NaN        NaN               NaN
# 2               0             NaN        NaN               NaN
# 3               0             NaN        NaN               NaN
# 4               0             NaN        NaN               NaN
#
#   Surface reelle bati  Nombre pieces principales Nature culture  \
# 0                 NaN                        NaN              T
# 1                 NaN                        NaN             BT
# 2                 NaN                        NaN              T
# 3                 NaN                        NaN              T
# 4                 NaN                        NaN              T
#
#   Nature culture speciale  Surface terrain
# 0                     NaN           1061.0
# 1                     NaN             85.0
# 2                     NaN           1115.0
# 3                     NaN           1940.0
# 4                     NaN           1148.0
#
# [5 rows x 43 columns]

# %%
print(df.columns)
# Out:
# Index(['Code service CH', 'Reference document', '1 Articles CGI',
#        '2 Articles CGI', '3 Articles CGI', '4 Articles CGI', '5 Articles CGI',
#        'No disposition', 'Date mutation', 'Nature mutation', 'Valeur fonciere',
#        'No voie', 'B/T/Q', 'Type de voie', 'Code voie', 'Voie', 'Code postal',
#        'Commune', 'Code departement', 'Code commune', 'Prefixe de section',
#        'Section', 'No plan', 'No Volume', '1er lot',
#        'Surface Carrez du 1er lot', '2eme lot', 'Surface Carrez du 2eme lot',
#        '3eme lot', 'Surface Carrez du 3eme lot', '4eme lot',
#        'Surface Carrez du 4eme lot', '5eme lot', 'Surface Carrez du 5eme lot',
#        'Nombre de lots', 'Code type local', 'Type local', 'Identifiant local',
#        'Surface reelle bati', 'Nombre pieces principales', 'Nature culture',
#        'Nature culture speciale', 'Surface terrain'],
#       dtype='object')

# %% [markdown]
# ## Constitution d'une base adresse à partir du fichier DVF

# %%
# focus on the address datas
ad = df[['No voie', 'Type de voie', 'Voie', 'Code postal','Commune', 'Code departement', 'Code commune']]
ad.shape
# Out:
# (2459560, 7)

# %%
ad.head()
# Out:
#    No voie Type de voie                    Voie  Code postal    Commune  \
# 0      NaN          NaN                FORTUNAT       1250.0  CEYZERIAT
# 1      NaN          NaN  TERRES DES CINQ SAULES       1290.0       LAIZ
# 2      NaN          NaN      BOIS DU CHAMP RION       1290.0       LAIZ
# 3      NaN          NaN             EN COROBERT       1290.0       LAIZ
# 4      NaN          NaN  TERRES DES CINQ SAULES       1290.0       LAIZ
#
#   Code departement  Code commune
# 0                1            72
# 1                1           203
# 2                1           203
# 3                1           203
# 4                1           203

# %%
ad['Commune'] = ad['Commune'].replace(['MARSEILLE 1ER', 'MARSEILLE 2EME', 'MARSEILLE 3EME', 'MARSEILLE 4EME',
                                           'MARSEILLE 5EME', 'MARSEILLE 6EME', 'MARSEILLE 7EME', 'MARSEILLE 8EME',
                                           'MARSEILLE 9EME', 'MARSEILLE 10EME', 'MARSEILLE 11EME', 'MARSEILLE 12EME',
                                           'MARSEILLE 13EME', 'MARSEILLE 14EME', 'MARSEILLE 15EME', 'MARSEILLE 16EME',
                                           'LYON 1ER', 'LYON 2EME', 'LYON 3EME', 'LYON 4EME', 'LYON 5EME',
                                           'LYON 6EME', 'LYON 7EME', 'LYON 8EME', 'LYON 9EME',
                                           'PARIS 01', 'PARIS 02', 'PARIS 03', 'PARIS 04', 'PARIS 05', 'PARIS 06',
                                           'PARIS 07', 'PARIS 08', 'PARIS 09', 'PARIS 10', 'PARIS 11', 'PARIS 12',
                                           'PARIS 13', 'PARIS 14', 'PARIS 15', 'PARIS 16', 'PARIS 17', 'PARIS 18',
                                           'PARIS 19', 'PARIS 20'],
                                          ['MARSEILLE', 'MARSEILLE', 'MARSEILLE', 'MARSEILLE',
                                          'MARSEILLE', 'MARSEILLE', 'MARSEILLE', 'MARSEILLE',
                                          'MARSEILLE', 'MARSEILLE', 'MARSEILLE', 'MARSEILLE',
                                          'MARSEILLE', 'MARSEILLE', 'MARSEILLE', 'MARSEILLE',
                                          'LYON', 'LYON', 'LYON', 'LYON', 'LYON',
                                          'LYON', 'LYON', 'LYON', 'LYON',
                                          'PARIS', 'PARIS', 'PARIS', 'PARIS', 'PARIS', 'PARIS',
                                          'PARIS', 'PARIS', 'PARIS', 'PARIS', 'PARIS', 'PARIS',
                                          'PARIS', 'PARIS', 'PARIS', 'PARIS', 'PARIS', 'PARIS',
                                          'PARIS', 'PARIS'])

# %%
ad['Voie'] = ad['Voie'].replace([' L ', ' D '], [' L\'', ' D\''], regex = True)

# %%
# On supprime les adresses dupliquées pour éviter d'interroger les API plusieurs fois avec exactement la même adresse
ad = ad.drop_duplicates()
ad.shape
# Out:
# (1059387, 7)

# %%
# Traitement des codes postaux (transformés en INT sauf les NA)

ad['Code postal'] = ad['Code postal'].fillna(-1).astype(int).astype(str).replace('-1', np.nan)
ad.head()
# Out:
#    No voie Type de voie                    Voie Code postal    Commune  \
# 0      NaN          NaN                FORTUNAT        1250  CEYZERIAT
# 1      NaN          NaN  TERRES DES CINQ SAULES        1290       LAIZ
# 2      NaN          NaN      BOIS DU CHAMP RION        1290       LAIZ
# 3      NaN          NaN             EN COROBERT        1290       LAIZ
# 6      NaN          RUE        DE LA CHARTREUSE        1960   PERONNAS
#
#   Code departement  Code commune
# 0                1            72
# 1                1           203
# 2                1           203
# 3                1           203
# 6                1           289

# %%
ad['Code departement'] = ad['Code departement'].apply(lambda x: str(x).zfill(2) if len(str(x)) == 1 else x)
ad['Code commune'] = ad['Code commune'].apply(lambda x: str(x).zfill(3) if len(str(x)) < 3 else x)
ad['Code commune INSEE'] = ad['Code departement'].astype(str) + ad['Code commune'].astype(str)
ad.head()
# Out:
#    No voie Type de voie                    Voie Code postal    Commune  \
# 0      NaN          NaN                FORTUNAT        1250  CEYZERIAT
# 1      NaN          NaN  TERRES DES CINQ SAULES        1290       LAIZ
# 2      NaN          NaN      BOIS DU CHAMP RION        1290       LAIZ
# 3      NaN          NaN             EN COROBERT        1290       LAIZ
# 6      NaN          RUE        DE LA CHARTREUSE        1960   PERONNAS
#
#   Code departement Code commune Code commune INSEE
# 0               01          072              01072
# 1               01          203              01203
# 2               01          203              01203
# 3               01          203              01203
# 6               01          289              01289

# %%
# On formate les adresses
# tools functions : nan values management
def escapeNan(row):
    val = str(row)
    if val == "nan":
        val = " "
    else:
        val = val.replace('.0','') # if from float values
        val = val + " "
    return val

# %%
# Création d'un champ "Ville" pour interroger les coordonnées GPS lorsque le champ Adresse ne donne rien
ad['Ville'] = ad['Code postal'] + " " + ad['Commune']
ad.head()
# Out:
#    No voie Type de voie                    Voie Code postal    Commune  \
# 0      NaN          NaN                FORTUNAT        1250  CEYZERIAT
# 1      NaN          NaN  TERRES DES CINQ SAULES        1290       LAIZ
# 2      NaN          NaN      BOIS DU CHAMP RION        1290       LAIZ
# 3      NaN          NaN             EN COROBERT        1290       LAIZ
# 6      NaN          RUE        DE LA CHARTREUSE        1960   PERONNAS
#
#   Code departement Code commune Code commune INSEE           Ville
# 0               01          072              01072  1250 CEYZERIAT
# 1               01          203              01203       1290 LAIZ
# 2               01          203              01203       1290 LAIZ
# 3               01          203              01203       1290 LAIZ
# 6               01          289              01289   1960 PERONNAS

# %%
# Création du champ "addressName" qui sera utilisée dans la requête API
ad['Adresse'] = ad.apply(lambda row: 
    escapeNan(row['No voie'])
    + escapeNan(row['Type de voie'])         
    + escapeNan(row['Voie'])
    + escapeNan(row['Code postal']).zfill(5) # pour respecter le format des codes postaux
    + str(row['Commune'])
    , axis = 1).str.strip()

# %%
ad.head()
# Out:
#    No voie Type de voie                    Voie Code postal    Commune  \
# 0      NaN          NaN                FORTUNAT        1250  CEYZERIAT
# 1      NaN          NaN  TERRES DES CINQ SAULES        1290       LAIZ
# 2      NaN          NaN      BOIS DU CHAMP RION        1290       LAIZ
# 3      NaN          NaN             EN COROBERT        1290       LAIZ
# 6      NaN          RUE        DE LA CHARTREUSE        1960   PERONNAS
#
#   Code departement Code commune Code commune INSEE           Ville  \
# 0               01          072              01072  1250 CEYZERIAT
# 1               01          203              01203       1290 LAIZ
# 2               01          203              01203       1290 LAIZ
# 3               01          203              01203       1290 LAIZ
# 6               01          289              01289   1960 PERONNAS
#
#                               Adresse
# 0             FORTUNAT 1250 CEYZERIAT
# 1    TERRES DES CINQ SAULES 1290 LAIZ
# 2        BOIS DU CHAMP RION 1290 LAIZ
# 3               EN COROBERT 1290 LAIZ
# 6  RUE DE LA CHARTREUSE 1960 PERONNAS

# %%
ad['Ville'] = ad['Ville'].replace('-', ' ', regex=True).astype(str)
ad.head()
# Out:
#    No voie Type de voie                    Voie Code postal    Commune  \
# 0      NaN          NaN                FORTUNAT        1250  CEYZERIAT
# 1      NaN          NaN  TERRES DES CINQ SAULES        1290       LAIZ
# 2      NaN          NaN      BOIS DU CHAMP RION        1290       LAIZ
# 3      NaN          NaN             EN COROBERT        1290       LAIZ
# 6      NaN          RUE        DE LA CHARTREUSE        1960   PERONNAS
#
#   Code departement Code commune Code commune INSEE           Ville  \
# 0               01          072              01072  1250 CEYZERIAT
# 1               01          203              01203       1290 LAIZ
# 2               01          203              01203       1290 LAIZ
# 3               01          203              01203       1290 LAIZ
# 6               01          289              01289   1960 PERONNAS
#
#                               Adresse
# 0             FORTUNAT 1250 CEYZERIAT
# 1    TERRES DES CINQ SAULES 1290 LAIZ
# 2        BOIS DU CHAMP RION 1290 LAIZ
# 3               EN COROBERT 1290 LAIZ
# 6  RUE DE LA CHARTREUSE 1960 PERONNAS

# %% [markdown]
# ## Sélection des adresses à parser pour ajout des coordonnées GPS et codes IRIS

# %%
# Sélection des adresses à partir de row_first et row_last définies plus haut
selec = ad.iloc[row_first:row_last, :]
selec.shape
# Out:
# (80900, 10)

# %%
# Instanciation de la BDD de correspondance entre Code Postal / Communes et Code INSEE + GPS Communes (nécessaire pour code IRIS)
# La BDD se trouve ici : https://data.opendatasoft.com/explore/dataset/code-postal-code-insee-2015@public/download/?format=csv&timezone=Europe/Berlin&lang=fr&use_labels_for_header=true&csv_separator=%3B
communes = pd.read_csv('databases/code-postal-code-insee-2015.csv', sep = ";")
communes.head()
# Out:
#                       Geo Point  \
# 0  49.0097923668,0.696073334129
# 1  49.0521199676,0.412267826158
# 2  48.7896521776,0.276557382012
# 3  48.8470682746,0.643176111978
# 4  48.8662500091,0.559682765078
#
#                                            Geo Shape  CODE_COM INSEE_COM  \
# 0  {"type": "Polygon", "coordinates": [[[0.682900...        49     27049
# 1  {"type": "Polygon", "coordinates": [[[0.409543...       547     27547
# 2  {"type": "Polygon", "coordinates": [[[0.260047...       347     61347
# 3  {"type": "Polygon", "coordinates": [[[0.628763...       359     27359
# 4  {"type": "Polygon", "coordinates": [[[0.553791...       136     61136
#
#                      NOM_COM          STATUT  X_CENTROID  Y_CENTROID  Z_MOYEN  \
# 0                 BEAUMESNIL  Commune simple      531927     6881409      162
# 1  SAINT-GERMAIN-LA-CAMPAGNE  Commune simple      510734     6886673      176
# 2                  RESENLIEU  Commune simple      500194     6858135      231
# 3                 JUIGNETTES  Commune simple      527172     6863726      228
# 4                   COUVAINS  Commune simple      521103     6865598      236
#
#    SUPERFICIE  POPULATION  CODE_CANT  CODE_ARR CODE_DEPT NOM_DEPT  \
# 0        1264         562        2.0       2.0        27     EURE
# 1        2231         895        3.0       2.0        27     EURE
# 2         504         210       21.0       2.0        61     ORNE
# 3        1302         243        6.0       3.0        27     EURE
# 4        1788         167       18.0       2.0        61     ORNE
#
#    Code_postal             Nom_commune               coordonnees_gps  \
# 0      27330.0         MESNIL EN OUCHE  49.0090520551,0.696415474297
# 1      27230.0  ST GERMAIN LA CAMPAGNE  49.0522921876,0.412852228157
# 2      61230.0               RESENLIEU  48.7900887821,0.276930426076
# 3      27250.0              JUIGNETTES   48.8472706788,0.64345379282
# 4          NaN                     NaN                           NaN
#
#    Unnamed: 18
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
# On ne garde que les colonnes qui nous intéressent 
# (On a les coordonnees gps dedans, ce sera intéressant pour faire un check des coordonnees qu'on récupère plus bas)

communes = communes[['INSEE_COM', 'NOM_COM', 'Code_postal', 'Nom_commune', 'coordonnees_gps']]
communes = communes.rename(columns = {'NOM_COM': "Commune"})
communes.head()
# Out:
#   INSEE_COM                    Commune  Code_postal             Nom_commune  \
# 0     27049                 BEAUMESNIL      27330.0         MESNIL EN OUCHE
# 1     27547  SAINT-GERMAIN-LA-CAMPAGNE      27230.0  ST GERMAIN LA CAMPAGNE
# 2     61347                  RESENLIEU      61230.0               RESENLIEU
# 3     27359                 JUIGNETTES      27250.0              JUIGNETTES
# 4     61136                   COUVAINS          NaN                     NaN
#
#                 coordonnees_gps
# 0  49.0090520551,0.696415474297
# 1  49.0522921876,0.412852228157
# 2  48.7900887821,0.276930426076
# 3   48.8472706788,0.64345379282
# 4                           NaN

# %%
# Instanciation d'un dataframe communes_ville qui ne conserve que le code INSEE, les coordonnés, et la ville
communes_ville = communes
communes_ville['Code_postal'] = communes_ville['Code_postal'].fillna(-1).astype(int).astype(str).replace('-1', np.nan)
communes_ville['Ville'] = communes_ville['Code_postal'] + " " + communes_ville['Commune']
communes_ville['Ville'] = communes_ville['Ville'].where(-communes_ville['Code_postal'].isna(), communes_ville['Commune'])
communes_ville = communes_ville.drop(columns = {'Commune', 'Code_postal', 'Nom_commune'})
communes_ville['Ville'] = communes_ville['Ville'].replace('-', ' ', regex=True).astype(str)
communes_ville.head()
# Out:
#   INSEE_COM               coordonnees_gps                            Ville
# 0     27049  49.0090520551,0.696415474297                 27330 BEAUMESNIL
# 1     27547  49.0522921876,0.412852228157  27230 SAINT GERMAIN LA CAMPAGNE
# 2     61347  48.7900887821,0.276930426076                  61230 RESENLIEU
# 3     27359   48.8472706788,0.64345379282                 27250 JUIGNETTES
# 4     61136                           NaN                         COUVAINS

# %%
# Ajout du code commune INSEE et Coordonnées GPS à la sélection d'adresses
selec = selec.merge(communes_ville, on = "Ville", how = "left")
selec.head()
# Out:
#    No voie Type de voie              Voie Code postal  Commune  \
# 0      NaN          NaN        LE VILLAGE       77650  JUTIGNY
# 1     35.0           AV          VOLTAIRE       77370   NANGIS
# 2      2.0          RUE  GERMAINE TILLION       77370   NANGIS
# 3     14.0          RUE  DE LA REPUBLIQUE       77370   NANGIS
# 4     35.0           AV  DU MARECHAL FOCH       77370   NANGIS
#
#   Code departement Code commune Code commune INSEE          Ville  \
# 0               77          242              77242  77650 JUTIGNY
# 1               77          327              77327   77370 NANGIS
# 2               77          327              77327   77370 NANGIS
# 3               77          327              77327   77370 NANGIS
# 4               77          327              77327   77370 NANGIS
#
#                                 Adresse INSEE_COM              coordonnees_gps
# 0              LE VILLAGE 77650 JUTIGNY     77242  48.4940082553,3.22666999554
# 1           35 AV VOLTAIRE 77370 NANGIS     77327   48.554637282,3.00883892893
# 2   2 RUE GERMAINE TILLION 77370 NANGIS     77327   48.554637282,3.00883892893
# 3  14 RUE DE LA REPUBLIQUE 77370 NANGIS     77327   48.554637282,3.00883892893
# 4   35 AV DU MARECHAL FOCH 77370 NANGIS     77327   48.554637282,3.00883892893

# %%
# Test sur Marseille car les codes communes INSEE semblent être différents selon la source
selec[(selec['Ville'].str.contains("MARSEILLE")) & (selec['Code departement'] == 13)]
# Out:
# Empty DataFrame
# Columns: [No voie, Type de voie, Voie, Code postal, Commune, Code departement, Code commune, Code commune INSEE, Ville, Adresse, INSEE_COM, coordonnees_gps]
# Index: []

# %%
selec['Commune_Lat'] = selec['coordonnees_gps'].str.split(",", expand = True)[0]
selec['Commune_Lon'] = selec['coordonnees_gps'].str.split(",", expand = True)[1]
selec = selec.drop(columns = {'coordonnees_gps'})
selec.head(15)
# Out:
#     No voie Type de voie               Voie Code postal          Commune  \
# 0       NaN          NaN         LE VILLAGE       77650          JUTIGNY
# 1      35.0           AV           VOLTAIRE       77370           NANGIS
# 2       2.0          RUE   GERMAINE TILLION       77370           NANGIS
# 3      14.0          RUE   DE LA REPUBLIQUE       77370           NANGIS
# 4      35.0           AV   DU MARECHAL FOCH       77370           NANGIS
# 5       NaN          NaN    LES PRES DU GUE       77370           NANGIS
# 6       1.0          RUE            TESSIER       77320   BETON-BAZOCHES
# 7      27.0          RUE             GRANDE       77114           GOUAIX
# 8       NaN          NaN       LES BARDINES       77160          PROVINS
# 9      13.0          IMP  ANCIENNE LAITERIE       77480   MOUY-SUR-SEINE
# 10      4.0          RUE         DES FOSSES       77171          SOURDUN
# 11      5.0          ALL     DES BOUVREUILS       77480   BRAY-SUR-SEINE
# 12      NaN          NaN          LA SOLINE       77114  NOYEN-SUR-SEINE
# 13      NaN          NaN          GRIVAUDON       77114  NOYEN-SUR-SEINE
# 14      NaN          NaN     LES JONCHERUES       77650       SOISY-BOUY
#
#    Code departement Code commune Code commune INSEE                  Ville  \
# 0                77          242              77242          77650 JUTIGNY
# 1                77          327              77327           77370 NANGIS
# 2                77          327              77327           77370 NANGIS
# 3                77          327              77327           77370 NANGIS
# 4                77          327              77327           77370 NANGIS
# 5                77          327              77327           77370 NANGIS
# 6                77          032              77032   77320 BETON BAZOCHES
# 7                77          208              77208           77114 GOUAIX
# 8                77          379              77379          77160 PROVINS
# 9                77          325              77325   77480 MOUY SUR SEINE
# 10               77          459              77459          77171 SOURDUN
# 11               77          051              77051   77480 BRAY SUR SEINE
# 12               77          341              77341  77114 NOYEN SUR SEINE
# 13               77          341              77341  77114 NOYEN SUR SEINE
# 14               77          456              77456       77650 SOISY BOUY
#
#                                           Adresse INSEE_COM    Commune_Lat  \
# 0                        LE VILLAGE 77650 JUTIGNY     77242  48.4940082553
# 1                     35 AV VOLTAIRE 77370 NANGIS     77327   48.554637282
# 2             2 RUE GERMAINE TILLION 77370 NANGIS     77327   48.554637282
# 3            14 RUE DE LA REPUBLIQUE 77370 NANGIS     77327   48.554637282
# 4             35 AV DU MARECHAL FOCH 77370 NANGIS     77327   48.554637282
# 5                    LES PRES DU GUE 77370 NANGIS     77327   48.554637282
# 6              1 RUE TESSIER 77320 BETON-BAZOCHES     77032  48.7072104391
# 7                      27 RUE GRANDE 77114 GOUAIX     77208  48.4760442904
# 8                      LES BARDINES 77160 PROVINS     77379  48.5633093312
# 9   13 IMP ANCIENNE LAITERIE 77480 MOUY-SUR-SEINE     77325  48.4321477503
# 10                 4 RUE DES FOSSES 77171 SOURDUN     77459  48.5369434021
# 11      5 ALL DES BOUVREUILS 77480 BRAY-SUR-SEINE     77051  48.4145972795
# 12                LA SOLINE 77114 NOYEN-SUR-SEINE     77341  48.4518691045
# 13                GRIVAUDON 77114 NOYEN-SUR-SEINE     77341  48.4518691045
# 14                LES JONCHERUES 77650 SOISY-BOUY     77456  48.5084866501
#
#       Commune_Lon
# 0   3.22666999554
# 1   3.00883892893
# 2   3.00883892893
# 3   3.00883892893
# 4   3.00883892893
# 5   3.00883892893
# 6   3.24596468954
# 7    3.2968135463
# 8   3.28756780085
# 9   3.24604389645
# 10   3.3628787539
# 11  3.24389965363
# 12  3.34226623535
# 13  3.34226623535
# 14  3.29987604926

# %%
# Ne conserver dans code commune INSEE final que Code commune INSEE sauf si > 5 caractères, dans ce cas prendre INSEE_COM
#(DOMTOM ne fonctionne pas sinon pour code iris)

# Problème avec les adresses ayant des apostrophes : non reconnues par geolocator (exemple rue de l'Arcade ...)

# %%
selec['code_iris'] = ""
selec['lon'] = ""
selec['lat'] = ""
selec.head()
# Out:
#    No voie Type de voie              Voie Code postal  Commune  \
# 0      NaN          NaN        LE VILLAGE       77650  JUTIGNY
# 1     35.0           AV          VOLTAIRE       77370   NANGIS
# 2      2.0          RUE  GERMAINE TILLION       77370   NANGIS
# 3     14.0          RUE  DE LA REPUBLIQUE       77370   NANGIS
# 4     35.0           AV  DU MARECHAL FOCH       77370   NANGIS
#
#   Code departement Code commune Code commune INSEE          Ville  \
# 0               77          242              77242  77650 JUTIGNY
# 1               77          327              77327   77370 NANGIS
# 2               77          327              77327   77370 NANGIS
# 3               77          327              77327   77370 NANGIS
# 4               77          327              77327   77370 NANGIS
#
#                                 Adresse INSEE_COM    Commune_Lat  \
# 0              LE VILLAGE 77650 JUTIGNY     77242  48.4940082553
# 1           35 AV VOLTAIRE 77370 NANGIS     77327   48.554637282
# 2   2 RUE GERMAINE TILLION 77370 NANGIS     77327   48.554637282
# 3  14 RUE DE LA REPUBLIQUE 77370 NANGIS     77327   48.554637282
# 4   35 AV DU MARECHAL FOCH 77370 NANGIS     77327   48.554637282
#
#      Commune_Lon code_iris lon lat
# 0  3.22666999554
# 1  3.00883892893
# 2  3.00883892893
# 3  3.00883892893
# 4  3.00883892893

# %%
selec.shape
# Out:
# (80900, 16)

# %% [markdown]
# ## Récupération des codes IRIS et coordonnées GPS à partir de l'API Nominatim et geo.api.gouv

# %%
# Get GPS Coordinates + IRIS Code from addresses

geolocator = Nominatim(user_agent="pyPredImmoTER")

start = time.time()
etape = time.time()
print("Heure début : ")
print(time.strftime('%H:%M:%S', time.gmtime(start)))
print("\n")
n=0

for row in range(0, row_last - row_first):
    
    iris = ""
    longitude_api = ""
    latitude_api = ""
    longitude_adresse = ""
    latitude_adresse = ""

    
    adresse = selec['Adresse'][row]
    ville = selec['Ville'][row]
    code_INSEE = selec['Code commune INSEE'][row]

    # Interrogation de l'API Nominatim
    location = geolocator.geocode(adresse, country_codes = 'fr', timeout = 5) # On interroge l'API à partir de l'adresse
    
    if location is None: 
        location = geolocator.geocode(ville, country_codes = 'fr', timeout = 5) # Sinon on interroge l'API à partir de la ville
    else:
        latitude_adresse = location.latitude          # On récupère les coordonnées GPS de l'adresse seulement si l'API renvoie qch
        longitude_adresse = location.longitude        
    
    if location is None:                      # Sinon aucun résultat, on ne met rien dans les coordonnées GPS qui vont servir à interroger les codes IRIS
        latitude_api = ""
        longitude_api = ""
    
    else:
        latitude_api = location.latitude
        longitude_api = location.longitude
        
        if isinstance(code_INSEE, float):     # Si pas de code commune
            print(adresse + ': pas de code commune INSEE')
            iris = ""
        elif latitude_api == "":               # Si pas de coordonnées GPS
            print(adresse + ": pas de coordonnees GPS pour code IRIS")
            iris = ""
        else:                              # Sinon on interroge l'API du gouv pour récupérer le code IRIS
            result = requests.get('https://geo.api.gouv.fr/iris?lon=' + str(longitude_api) + '&lat=' 
                                  + str(latitude_api) + '&codeCommune=' + str(code_INSEE), timeout = 5)
            if result.ok == True:
                obj = json.loads(result.text)
                iris = obj['codeIris']
                #print(obj['codeIris'])
            else:
                result.close()
            print(adresse + " ===> " + str(latitude_adresse) + "," + str(longitude_adresse) + " (code IRIS = " + str(iris) + ")")
        
    selec['code_iris'][row] = iris
    selec['lon'][row] = longitude_adresse
    selec['lat'][row] = latitude_adresse
    
    n = n + 1
    
    if (n % 100 == 0):
        print("\n")
        print("Etape : " + str(n))
        print(time.strftime('%H:%M:%S', time.gmtime(time.time())))
        print("Temps pour 100 : " + str(time.time() - etape) + " sec")
        print("\n")
        etape = time.time()

    if (n % 10000 == 0):
        selec.iloc[(n - 10000) : n, :].to_csv(
            'export_gps_iris_' + str(row_first + n - 10000) + "-" + str(row_first + n)+'.csv')
        
end = time.time()
print("\n")
print("Heure fin : ")
print(time.strftime('%H:%M:%S', time.gmtime(end)))
print("\n")

print("Temps de calcul : ")
print(str(end - start) + ' sec')
# Out:
# Heure début :
# 15:17:52
#
#
# LE VILLAGE 77650 JUTIGNY ===> 48.4978612,3.232652 (code IRIS = 772420000)
# 35 AV VOLTAIRE 77370 NANGIS ===> 48.5560401,3.0190378 (code IRIS = 773270101)
# 2 RUE GERMAINE TILLION 77370 NANGIS ===> 48.5543564,3.0024955 (code IRIS = 773270103)
# 14 RUE DE LA REPUBLIQUE 77370 NANGIS ===> 48.5546389,3.016545 (code IRIS = 773270101)
# 35 AV DU MARECHAL FOCH 77370 NANGIS ===> 48.5609609,3.0133417 (code IRIS = 773270101)
# LES PRES DU GUE 77370 NANGIS ===> , (code IRIS = 773270101)
# 1 RUE TESSIER 77320 BETON-BAZOCHES ===> 48.7006265,3.2434879 (code IRIS = 770320000)
# 27 RUE GRANDE 77114 GOUAIX ===> 48.4872893,3.2926824 (code IRIS = 772080000)
# LES BARDINES 77160 PROVINS ===> 48.5700373,3.3035148 (code IRIS = 773790101)
# 13 IMP ANCIENNE LAITERIE 77480 MOUY-SUR-SEINE ===> , (code IRIS = 773250000)
# 4 RUE DES FOSSES 77171 SOURDUN ===> 48.5396547,3.3557812 (code IRIS = 774590000)
# 5 ALL DES BOUVREUILS 77480 BRAY-SUR-SEINE ===> 48.4119803,3.2435953 (code IRIS = 770510000)
# LA SOLINE 77114 NOYEN-SUR-SEINE ===> 48.4612524,3.3409612 (code IRIS = 773410000)
# GRIVAUDON 77114 NOYEN-SUR-SEINE ===> , (code IRIS = 773410000)
# LES JONCHERUES 77650 SOISY-BOUY ===> , (code IRIS = 774560000)
# LES SABLONS 77650 SOISY-BOUY ===> , (code IRIS = 774560000)
# LES CARREAUX 77650 SOISY-BOUY ===> , (code IRIS = 774560000)
# LES BOIS AUX RENARDS 77650 SOISY-BOUY ===> , (code IRIS = 774560000)
# 10 COUR AUX ORGES 77160 PROVINS ===> 48.5612415,3.3060553 (code IRIS = 773790103)
# 17 RUE GRANDE 77114 NOYEN-SUR-SEINE ===> 48.453378,3.3470078 (code IRIS = 773410000)
# RUE GRANDE 77114 NOYEN-SUR-SEINE ===> 48.453378,3.3470078 (code IRIS = 773410000)
# LA MAISON BLAISE 77126 CHATENAY-SUR-SEINE ===> 48.4164428,3.0926378 (code IRIS = 771010000)
# RTE DE MONTEREAU 77126 CHATENAY-SUR-SEINE ===> 48.4176046,3.0916772 (code IRIS = 771010000)
# 7 RUE DES MARAIS 77126 EGLIGNY ===> 48.4286828,3.1260984 (code IRIS = 771670000)
# 35 RUE VICTOR ARNOUL 77160 PROVINS ===> 48.5583524,3.3029908 (code IRIS = 773790103)
# 11  DOMAINE DE BECHERET 77560 VILLIERS-SAINT-GEORGES ===> 48.648434,3.4103608 (code IRIS = 775190000)
# 30 RUE LOUIS PLATRIEZ 77650 LONGUEVILLE ===> 48.5116466,3.2517959 (code IRIS = 772600000)
# 3 IMP DES AULNES 77480 FONTAINE-FOURCHES ===> 48.4104068,3.4026324 (code IRIS = 771870000)
# JOUY 77970 JOUY-LE-CHATEL ===> 48.66485725,3.1328896457364594 (code IRIS = 772390000)
# LES ROUGEREAUX 77970 JOUY-LE-CHATEL ===> , (code IRIS = 772390000)
# 10 RUE PASTEUR 77370 NANGIS ===> 48.5572736,3.0124131 (code IRIS = 773270101)
# 8 RUE SAINT JEAN 77160 PROVINS ===> 48.5615726,3.2836298 (code IRIS = 773790102)
# LE MEZ DE LA MADELEINE 77160 POIGNY ===> 48.5441621,3.264025 (code IRIS = 773680000)
# MARCHODON 77160 POIGNY ===> , (code IRIS = 773680000)
# 4 BD GILBERT CHOMTON 77160 PROVINS ===> 48.5570168,3.2932643 (code IRIS = 773790103)
# 60 RUE GRANDE 77118 BAZOCHES LES BRAY ===> 48.3975148,3.1894349 (code IRIS = 770250000)
# 11 RUE SALGUES 77520 DONNEMARIE-DONTILLY ===> 48.4790953,3.1335083 (code IRIS = 771590000)
# RUE DE PROVINS 77160 MORTERY ===> 48.598155,3.2606874 (code IRIS = 773190000)
# 19 RUE JEAN JAURES 77370 NANGIS ===> 48.5522939,3.0104522 (code IRIS = 773270103)
# 7 RUE DE PROVINS 77520 THENISY ===> 48.4905065,3.1766619 (code IRIS = 774610000)
# 23 RUE DES BORDES 77154 VILLENEUVE-LES-BORDES ===> 48.4853365,3.0400539 (code IRIS = 775090000)
# VILLENEUVE 77154 VILLENEUVE-LES-BORDES ===> 48.4969509,3.0169874 (code IRIS = 775090000)
# 18 RUE DE LA CROIX BLANCHE 77370 MAISON-ROUGE ===> 48.55863,3.1486361 (code IRIS = 772720000)
# 240 RUE DANTON 77480 BRAY-SUR-SEINE ===> 48.4112074,3.2351305 (code IRIS = 770510000)
# 7 RTE DE PROVINS 77520 DONNEMARIE-DONTILLY ===> 48.4786388,3.1358108 (code IRIS = 771590000)
# DONNEMARIE 77520 DONNEMARIE-DONTILLY ===> 48.481740099999996,3.1154426725501474 (code IRIS = 771590000)
# LE PARC AUX BOEUFS 77370 MAISON-ROUGE ===> , (code IRIS = 772720000)
# 3 RUE AUX PAVIS 77520 MONS-EN-MONTOIS ===> 48.4914834,3.1525902 (code IRIS = 772980000)
# 441 RUE DE VILLENEUVE 77154 COUTENCON ===> 48.4725774,3.0001978 (code IRIS = 771400000)
# LE HAMEAU DE LA CHAPELLE 77126 CHATENAY-SUR-SEINE ===> , (code IRIS = 771010000)
# 14 RUE DE LA MUETTE 77126 CHATENAY-SUR-SEINE ===> 48.4144428,3.0968651 (code IRIS = 771010000)
# 12 RUE MAXIMILIEN MICHELIN 77160 PROVINS ===> 48.559102,3.2909465 (code IRIS = 773790102)
# 19 RTE VIEILLE DE PROVINS 77160 ROUILLY ===> 48.580493,3.2857174 (code IRIS = 773910000)
# 17 GR GRANDE RUE 77160 CHENOISE-CUCHARMOY ===> , (code IRIS = 771090000)
# 11 RUE AUX OUCHES 77480 FONTAINE-FOURCHES ===> 48.413294,3.3925925 (code IRIS = 771870000)
# LE BAS DE FOURCHES 77480 FONTAINE-FOURCHES ===> , (code IRIS = 771870000)
# GRISY 77480 GRISY-SUR-SEINE ===> 48.4486219,3.3208207 (code IRIS = 772180000)
# 30 RUE DE L'EGLISE 77171 SOURDUN ===> 48.5367252,3.3511694 (code IRIS = 774590000)
# 13 RUE DU 19 MARS 1962 77370 NANGIS ===> 48.5581435,3.0092157 (code IRIS = 773270101)
# 41 RUE DE LA REPUBLIQUE 77370 NANGIS ===> 48.5546389,3.016545 (code IRIS = 773270101)
# RUPEREUX 77560 RUPEREUX ===> 48.636355,3.327893 (code IRIS = 773960000)
# 1 RUE DU VIEUX MOULIN 77650 JUTIGNY ===> 48.5004562,3.2328559 (code IRIS = 772420000)
# LES PRES DES GRANDS SILLON 77650 JUTIGNY ===> , (code IRIS = 772420000)
# 4 RUE DE LA FONTAINE A L'ANGE 77970 BANNOST-VILLEGAGNON ===> 48.6780011,3.1939958 (code IRIS = 770200000)
# 1 ALL DES TILLEULS 77370 NANGIS ===> 48.5498094,3.014425 (code IRIS = 773270103)
# RUE DE LA TOUR 77970 BANNOST-VILLEGAGNON ===> 48.6684174,3.1781418 (code IRIS = 770200000)
# LE PETIT CESSOY 77520 CESSOY-EN-MONTOIS ===> , (code IRIS = 770680000)
# 8 RUE DES FORTS 77370 FONTAINS ===> 48.5295576,3.0136709 (code IRIS = 771900000)
# FONTAINS 77370 FONTAINS ===> , (code IRIS = 771900000)
# 40 RUE DES FOSSES 77370 RAMPILLON ===> 48.5490246,3.0705643 (code IRIS = 773830000)
# RAMPILLON 77370 RAMPILLON ===> 48.549915,3.068839 (code IRIS = 773830000)
# 2 ALL PAUL TROUVERY 77370 NANGIS ===> 48.5495985,3.0115115 (code IRIS = 773270103)
# LE VILLAGE 77560 LOUAN-VILLEGRUIS-FONTAINE ===> 48.60977645,3.48573511325103 (code IRIS = 772620000)
# AU DESSUS DE CLAUZE BARBE 77650 SAINTE-COLOMBE ===> , (code IRIS = 774040000)
# 3 RTE DE COURTON 77160 VULAINES-LES-PROVINS ===> 48.5600979,3.2202454 (code IRIS = 775320000)
# HAUTE FEUILLE 77160 VULAINES-LES-PROVINS ===> , (code IRIS = 775320000)
# TOURY 77114 HERME ===> 48.4818282,3.3651695 (code IRIS = 772270000)
# 16 RUE DU GUE 77480 SAINT-SAUVEUR-LES-BRAY ===> 48.4373184,3.2060429 (code IRIS = 774340000)
# CLOS BOURDON 77520 MONTIGNY-LENCOUP ===> , (code IRIS = 773110000)
# 31 GR GRANDE RUE 77520 MONTIGNY-LENCOUP ===> , (code IRIS = 773110000)
# RUE DU MONT 77650 SAVINS ===> 48.5151923,3.2067552 (code IRIS = 774460000)
# LE VAL 77650 SAVINS ===> 48.5106287,3.205609 (code IRIS = 774460000)
# 3 RUE DE LA TUILERIE 77370 VIEUX-CHAMPAGNE ===> 48.5859756,3.1594417 (code IRIS = 774960000)
# LA TUILERIE 77370 VIEUX-CHAMPAGNE ===> 48.5859756,3.1594417 (code IRIS = 774960000)
# RUE HUBERT 77370 VIEUX-CHAMPAGNE ===> , (code IRIS = 774960000)
# 9 RUE DE BARLAY 77160 PROVINS ===> 48.5642972,3.3049119 (code IRIS = 773790101)
# 42 GR GRANDE RUE DE COUTURE 77134 ORMES-SUR-VOULZIE (LES) ===> 48.4605917,3.2176078 (code IRIS = 773470000)
# 10 RUE DU GRAND MARAIS 77650 CHALMAISON ===> 48.4809544,3.2484712 (code IRIS = 770760000)
# 17 RUE RES LE CLOS DU CHATEL 77970 JOUY-LE-CHATEL ===> , (code IRIS = 772390000)
# CORNILLON 77320 BETON-BAZOCHES ===> 48.7184712,3.2633954 (code IRIS = 770320000)
# 11 RUE DU MOULIN 77480 SAINT-SAUVEUR-LES-BRAY ===> 48.4367343,3.2121435 (code IRIS = 774340000)
# 7 CHE DES FOSSES NORD 77118 BAZOCHES LES BRAY ===> 48.3998083,3.1863011 (code IRIS = 770250000)
# 4 RUE DES HAIES 77480 FONTAINE-FOURCHES ===> 48.4142694,3.3882864 (code IRIS = 771870000)
# SEPTVEILLES LE BAS 77650 SAINTE-COLOMBE ===> 48.5283119,3.2602319 (code IRIS = 774040000)
# LES HUYOTTES 77650 SAINTE-COLOMBE ===> 48.5256669,3.2627746 (code IRIS = 774040000)
# 33 RUE DU DOCTEUR SCHWEITZER 77650 SAINTE-COLOMBE ===> 48.5298128,3.2608112 (code IRIS = 774040000)
# VILLIERS 77114 VILLIERS-SUR-SEINE ===> 48.455891,3.3761309 (code IRIS = 775220000)
# 6 GR GRANDE RUE 77114 VILLIERS-SUR-SEINE ===> 48.4568645,3.3741232 (code IRIS = 775220000)
# L AMOUREE 77650 LONGUEVILLE ===> , (code IRIS = 772600000)
# 10 RUE DE L'AMOUREE 77650 LONGUEVILLE ===> 48.516442,3.2464847 (code IRIS = 772600000)
#
#
# Etape : 100
# 15:18:54
# Temps pour 100 : 61.9341938495636 sec
# 17 RUE DU VIEUX PONT 77480 MOUY-SUR-SEINE ===> 48.4200446,3.238593 (code IRIS = 773250000)
# L EPINEE 77480 MOUY-SUR-SEINE ===> , (code IRIS = 773250000)
# 9 RUE DU VIEUX MOULIN 77114 HERME ===> 48.4831881,3.3591355 (code IRIS = 772270000)
# 10 RUE DES DAMES 77171 SOURDUN ===> 48.5386485,3.3569872 (code IRIS = 774590000)
# 1 RTE NANGIS 77970 BANNOST-VILLEGAGNON ===> 48.6632935,3.1744317 (code IRIS = 770200000)
# RUE DE NANGIS 77970 BANNOST-VILLEGAGNON ===> 48.6632935,3.1744317 (code IRIS = 770200000)
# 8 RUE AUX CHAMPS 77171 MELZ-SUR-SEINE ===> 48.5088904,3.3912903 (code IRIS = 772890000)
# MAULNY 77171 MELZ-SUR-SEINE ===> 48.5084467,3.3916892 (code IRIS = 772890000)
# LES FOSSES 77171 MELZ-SUR-SEINE ===> , (code IRIS = 772890000)
# 6 RUE FARABOEUF 77160 PROVINS ===> 48.5567814,3.2955743 (code IRIS = 773790103)
# 2 RUE DE ST AIGNAN 77171 LECHELLE ===> , (code IRIS = 772460000)
# VOULTON 77560 VOULTON ===> 48.616867,3.333054 (code IRIS = 775300000)
# 62 AV VICTOR HUGO 77370 NANGIS ===> 48.5582158,3.0113302 (code IRIS = 773270101)
# 54 RUE GRANDE 77520 THENISY ===> 48.4903079,3.1756797 (code IRIS = 774610000)
# LES PENDANTS 77160 ROUILLY ===> , (code IRIS = 773910000)
# 2 RTE ROUTE DU GRAND FLEIGNY 77160 ROUILLY ===> , (code IRIS = 773910000)
# 2 RUE DE LA NASSE 77160 PROVINS ===> 48.5630669,3.2859919 (code IRIS = 773790102)
# LE ROCCOT 77160 SAINT-BRICE ===> , (code IRIS = 774030000)
# 32 RUE DES CHOMETTES 77160 SAINT-BRICE ===> 48.5679348,3.3169465 (code IRIS = 774030000)
# 1 RUE AUX AULX 77160 PROVINS ===> 48.5602511,3.2969913 (code IRIS = 773790103)
# LE CHAMP PAS BON 77114 HERME ===> , (code IRIS = 772270000)
# 3 RUE DE LA MUETTE 77126 CHATENAY-SUR-SEINE ===> 48.4144428,3.0968651 (code IRIS = 771010000)
# 12 RTE DE BRAY 77650 LONGUEVILLE ===> 48.517365,3.2387538 (code IRIS = 772600000)
# CHEMIN D'EN BAS 77560 LOUAN-VILLEGRUIS-FONTAINE ===> , (code IRIS = 772620000)
# BOIS DE MONTAIGUILLON 77560 LOUAN-VILLEGRUIS-FONTAINE ===> , (code IRIS = 772620000)
# BOISDON 77970 BOISDON ===> 48.6845989,3.2265338 (code IRIS = 770360000)
# 20 RUE GRANDE 77970 BOISDON ===> 48.6846954,3.2240193 (code IRIS = 770360000)
# 16 PL DE L'EGLISE 77370 GASTINS ===> 48.6277947,3.0202777 (code IRIS = 772010000)
# 17 RUE DES TILLEULS 77480 MOUY-SUR-SEINE ===> 48.4213326,3.2375067 (code IRIS = 773250000)
# 3 RUE DE L'AVENIR 77650 LONGUEVILLE ===> 48.5178492,3.2407614 (code IRIS = 772600000)
# 15 RUE DES BORDES 77160 PROVINS ===> 48.5574308,3.3029134 (code IRIS = 773790103)
# 1 RTE DE MONS 77520 THENISY ===> 48.4873476,3.1764743 (code IRIS = 774610000)
# 6 RUE DU COQ 77520 CESSOY-EN-MONTOIS ===> 48.5040796,3.1463131 (code IRIS = 770680000)
# CLOS DES BLINS 77520 MONTIGNY-LENCOUP ===> , (code IRIS = 773110000)
# 20 RUE ROBERT DESNOS 77370 NANGIS ===> 48.5530666,3.0041618 (code IRIS = 773270103)
# 5051 CHE DU CANAL 77370 CROIX-EN-BRIE (LA) ===> , (code IRIS = 771470000)
# 3 RUE DU BELVEDERE 77370 CROIX-EN-BRIE (LA) ===> 48.5924534,3.0804373 (code IRIS = 771470000)
# 20 RUE DE LA MAROTTE 77520 MONTIGNY-LENCOUP ===> 48.4589806,3.0706349 (code IRIS = 773110000)
# 8 RLE DU PRESBYTERE 77370 RAMPILLON ===> , (code IRIS = 773830000)
# LE COURTIL DES CHAMPS 77970 BANNOST-VILLEGAGNON ===> , (code IRIS = 770200000)
# 5116  LE COURTIL DES CHAMPS 77970 BANNOST-VILLEGAGNON ===> , (code IRIS = 770200000)
# 8 RUE DE VILLEFLON 77970 BANNOST-VILLEGAGNON ===> , (code IRIS = 770200000)
# 14 RUE DU FORGERON 77560 BEAUCHERY-SAINT-MARTIN ===> 48.6175194,3.4043251 (code IRIS = 770260000)
# 3 RUE DU GUE 77520 VIMPELLES ===> 48.4438817,3.1641452 (code IRIS = 775240000)
# 5  LES EAUX 77560 COURTACON ===> , (code IRIS = 771370000)
# 5 CHE DE L'ECOLE 77160 SAINT-HILLIERS ===> 48.6211452,3.2584206 (code IRIS = 774140000)
# LE VILLAGE 77160 SAINT-HILLIERS ===> 48.6215827,3.2567048 (code IRIS = 774140000)
# 31 RUE DE CHANGIS 77160 PROVINS ===> 48.5579828,3.3044721 (code IRIS = 773790103)
# 16 RUE DE MONTRAME 77650 SOISY-BOUY ===> 48.5066876,3.2903728 (code IRIS = 774560000)
# 16 RUE DU MINAGE 77160 PROVINS ===> 48.5599998,3.3015944 (code IRIS = 773790103)
# 15 RUE BERTHIER 77520 SOGNOLLES-EN-MONTOIS ===> 48.513245,3.1663502 (code IRIS = 774540000)
# 24 RUE DE LA TOUR 77171 LECHELLE ===> 48.5774236,3.3893187 (code IRIS = 772460000)
# 3 RUE DE LA POSTE 77114 GOUAIX ===> 48.4806191,3.292387 (code IRIS = 772080000)
# COEFFRIN 77560 AUGERS-EN-BRIE ===> 48.649118,3.3575774 (code IRIS = 770120000)
# 1  COEFFRIN 77560 AUGERS-EN-BRIE ===> , (code IRIS = 770120000)
# LA FOSSE LAMBERT 77560 AUGERS-EN-BRIE ===> , (code IRIS = 770120000)
# LE NEPLAN 77320 BETON-BAZOCHES ===> , (code IRIS = 770320000)
# 21 RUE DE LA PORTE DE MELUN 77520 DONNEMARIE-DONTILLY ===> 48.4785071,3.1304757 (code IRIS = 771590000)
# 11 RTE DES JAVELOTTES 77520 DONNEMARIE-DONTILLY ===> , (code IRIS = 771590000)
# 9 LOT CHAPELLE SAINT GOND 77520 DONNEMARIE-DONTILLY ===> , (code IRIS = 771590000)
# 10 RUE DE L'ECHELLE 77650 SAVINS ===> 48.5102073,3.1983015 (code IRIS = 774460000)
# LES LONGUES RAIES 77160 CHENOISE-CUCHARMOY ===> , (code IRIS = 771090000)
# LE NOEUD COULON 77160 CHENOISE-CUCHARMOY ===> , (code IRIS = 771090000)
# LES POIRIERS D'OR 77160 ROUILLY ===> , (code IRIS = 773910000)
# 9 RUE DE LAGOURD 77520 DONNEMARIE-DONTILLY ===> 48.4805979,3.1248705 (code IRIS = 771590000)
# SUR LE RU DE LAVAL 77520 DONNEMARIE-DONTILLY ===> , (code IRIS = 771590000)
# 43 RUE NOAS DAUMESNIL 77370 NANGIS ===> 48.5563011,3.0159388 (code IRIS = 773270101)
# 4 RES DU VIEUX MOULIN 77370 FONTAINS ===> , (code IRIS = 771900000)
# 4 RUE DE GURCY 77520 MONTIGNY-LENCOUP ===> 48.4588219,3.0627516 (code IRIS = 773110000)
# 3 IMP DE LA CROYOTTE 77114 HERME ===> 48.4852844,3.365693 (code IRIS = 772270000)
# 1 IMP SAINT MAURICE 77118 GRAVON ===> 48.3990346,3.1212169 (code IRIS = 772120000)
# LE VILLAGE 77118 GRAVON ===> 48.3989764,3.1199592 (code IRIS = 772120000)
# LES MARAIS 77118 GRAVON ===> , (code IRIS = 772120000)
# 5538  LA LONGUE RAIE 77114 GOUAIX ===> , (code IRIS = 772080000)
# 4 RUE DES PRES 77160 PROVINS ===> 48.5640006,3.294241 (code IRIS = 773790103)
# 7 RUE DU MARAIS 77126 CHATENAY-SUR-SEINE ===> 48.4259443,3.0962099 (code IRIS = 771010000)
# LE HAMEAU DE CHAUPRY 77126 CHATENAY-SUR-SEINE ===> , (code IRIS = 771010000)
# NEUVRY 77480 JAULNES ===> 48.4338713,3.2819866 (code IRIS = 772360000)
# 6 RUE PRINCIPALE 77480 JAULNES ===> 48.4346753,3.2845225 (code IRIS = 772360000)
# 16 RUE DU DOCTEUR SCHWEITZER 77160 PROVINS ===> 48.5568868,3.3063521 (code IRIS = 773790201)
# 54 RUE JULES FERRY 77171 SOURDUN ===> 48.5358967,3.3480685 (code IRIS = 774590000)
# LE DESSUS DE FLAMBOIN 77114 GOUAIX ===> , (code IRIS = 772080000)
# 6 RUE DU GRAND BOISSY 77160 SAINT-HILLIERS ===> 48.6144639,3.2468967 (code IRIS = 774140000)
# 8 PL DE L'EGLISE 77171 SOURDUN ===> 48.5372866,3.3481873 (code IRIS = 774590000)
# 1 RUE DE LA CHAUDRONNERIE 77370 CHAPELLE-RABLAIS (LA) ===> 48.5117194,2.9662875 (code IRIS = 770890000)
# LA RUE AUX MULETS 77650 SAINTE-COLOMBE ===> , (code IRIS = 774040000)
# SEPTVEILLES LE HAUT 77650 SAINTE-COLOMBE ===> , (code IRIS = 774040000)
# 73 RUE DES FONTAINES 77370 NANGIS ===> 48.5581016,3.0106424 (code IRIS = 773270101)
# 6 RUE DES ECOLES 77370 CROIX-EN-BRIE (LA) ===> 48.5938216,3.0756823 (code IRIS = 771470000)
# 1 RUE DU MOULIN 77970 JOUY-LE-CHATEL ===> 48.6649853,3.1360262 (code IRIS = 772390000)
# LA DIMERESSE 77970 JOUY-LE-CHATEL ===> , (code IRIS = 772390000)
# 49 RUE DU VAL 77160 PROVINS ===> 48.5607688,3.2965592 (code IRIS = 773790103)
# 2 RUE DU CHATEAU D'EAU 77320 BETON-BAZOCHES ===> 48.6997869,3.245757 (code IRIS = 770320000)
# 18 RUE DES FONTAINES 77370 NANGIS ===> 48.5581016,3.0106424 (code IRIS = 773270101)
# 3 AV GAMBETTA 77370 NANGIS ===> , (code IRIS = 773270101)
# 16 PL CLOITRE NOTRE DAME 77160 PROVINS ===> , (code IRIS = 773790103)
# 9 RUE GRANDE 77520 THENISY ===> 48.4903079,3.1756797 (code IRIS = 774610000)
# LE PETIT THENISY 77520 THENISY ===> 48.486792,3.1793813 (code IRIS = 774610000)
# LES PIERRES DE JAULNES 77480 JAULNES ===> , (code IRIS = 772360000)
#
#
# Etape : 200
# 15:20:04
# Temps pour 100 : 69.8747410774231 sec
#
#
# 1  DOMAINE DE BECHERET 77560 VILLIERS-SAINT-GEORGES ===> 48.648434,3.4103608 (code IRIS = 775190000)
# 2 RUE MARCEL MOUGENOT 77160 PROVINS ===> 48.5704207,3.2916997 (code IRIS = 773790101)
# RUE MARCEL MOUGENOT 77160 PROVINS ===> 48.5704207,3.2916997 (code IRIS = 773790101)
# COURCHAMP 77560 COURCHAMP ===> 48.634943,3.288519 (code IRIS = 771340000)
# 9 RUE FORT A FAIRE 77560 COURCHAMP ===> , (code IRIS = 771340000)
# 2 RUE DE LA PLACE DES FETES 77114 VILLIERS-SUR-SEINE ===> 48.4555624,3.3750678 (code IRIS = 775220000)
# 18 RUE CREUSE 77160 ROUILLY ===> 48.5881478,3.2860148 (code IRIS = 773910000)
# 8 RUE DU GENERAL LECLERC 77480 BRAY-SUR-SEINE ===> 48.4164106,3.2379724 (code IRIS = 770510000)
# 10 RUE DES REMPARTS 77480 BRAY-SUR-SEINE ===> 48.4171595,3.2360749 (code IRIS = 770510000)
# RTE DE BRAY 77160 PROVINS ===> 48.5562205,3.2877408 (code IRIS = 773790102)
# VEAU GUERIN 77118 BALLOY ===> , (code IRIS = 770190000)
# 12 RUE DU GROS CAILLOU 77520 DONNEMARIE-DONTILLY ===> 48.4783622,3.1380892 (code IRIS = 771590000)
# 4 RUE DE L'EGLISE 77520 MONS-EN-MONTOIS ===> 48.4886404,3.1457775 (code IRIS = 772980000)
# 33 RUE DE VILLENEUVE 77154 COUTENCON ===> 48.4725774,3.0001978 (code IRIS = 771400000)
# LE CHAMP DE LA CROIX 77970 BANNOST-VILLEGAGNON ===> , (code IRIS = 770200000)
# LA GARE 77970 BANNOST-VILLEGAGNON ===> 48.6798318,3.1902549 (code IRIS = 770200000)
# LA MARE ADROT 77560 VILLIERS-SAINT-GEORGES ===> , (code IRIS = 775190000)
# LES BOULEAUX 77520 CESSOY-EN-MONTOIS ===> , (code IRIS = 770680000)
# CARREFOUR DES BANCS 77520 DONNEMARIE-DONTILLY ===> , (code IRIS = 771590000)
# 32 RUE DES ECOLES 77520 DONNEMARIE-DONTILLY ===> 48.4759474,3.1282023 (code IRIS = 771590000)
# RUE DES FOSSES 77520 DONNEMARIE-DONTILLY ===> 48.475236,3.1315152 (code IRIS = 771590000)
# 1 RLE STE QUINETTE 77520 DONNEMARIE-DONTILLY ===> , (code IRIS = 771590000)
# RLE STE QUINETTE 77520 DONNEMARIE-DONTILLY ===> , (code IRIS = 771590000)
# 7 RUE DE LA COMMUNE DE PARIS 77370 NANGIS ===> 48.5613511,3.0339982 (code IRIS = 773270101)
# RUE DE LA COMMUNE DE PARIS 77370 NANGIS ===> 48.5613511,3.0339982 (code IRIS = 773270101)
# 56 RUE DES FONTAINES 77370 NANGIS ===> 48.5581016,3.0106424 (code IRIS = 773270101)
# 17 RUE LAMARTINE 77520 GURCY-LE-CHATEL ===> 48.4810085,3.0917845 (code IRIS = 772230000)
# CHALAUTRE 77520 GURCY-LE-CHATEL ===> 48.4807089,3.0923599 (code IRIS = 772230000)
# CHALAUTRE 77171 CHALAUTRE-LA-GRANDE ===> 48.5418032,3.4595997 (code IRIS = 770720000)
# 27 RUE DE NANGIS 77970 BANNOST-VILLEGAGNON ===> 48.6632935,3.1744317 (code IRIS = 770200000)
# 10 RUE DU VIEUX MOULIN 77114 HERME ===> 48.4831881,3.3591355 (code IRIS = 772270000)
# 1 AV LEON BINET 77160 PROVINS ===> 48.5471835,3.297867 (code IRIS = 773790202)
# 6 ALL ALLEE DES VIGNES 77157 EVERLY ===> , (code IRIS = 771740000)
# L ETANG GENTIL 77160 CHALAUTRE-LA-PETITE ===> , (code IRIS = 770730000)
# CHAMP GUIGNARD 77970 JOUY-LE-CHATEL ===> , (code IRIS = 772390000)
# 8 RUE RES LE CLOS DU CHATEL 77970 JOUY-LE-CHATEL ===> , (code IRIS = 772390000)
# 2 SEN DES FONTAINES 77154 VILLENEUVE-LES-BORDES ===> , (code IRIS = 775090000)
# 5381 RUE DE LA CROIX BROUILLARD 77650 LONGUEVILLE ===> 48.5192445,3.239127 (code IRIS = 772600000)
# LES NEUF ARPENTS 77650 LONGUEVILLE ===> , (code IRIS = 772600000)
# 2 RUE JOSEPH BARA 77480 BRAY-SUR-SEINE ===> 48.4151973,3.2385012 (code IRIS = 770510000)
# 13 RUE GRANDE 77480 BRAY-SUR-SEINE ===> 48.4157029,3.2380945 (code IRIS = 770510000)
# LA PLAINE DE LA BOULOIE 77520 CESSOY-EN-MONTOIS ===> , (code IRIS = 770680000)
# LE CHAMP DU CARREAU 77520 MONS-EN-MONTOIS ===> , (code IRIS = 772980000)
# LE CLOS GRENOST 77520 MONS-EN-MONTOIS ===> , (code IRIS = 772980000)
# LA MALADRERIE 77520 MONS-EN-MONTOIS ===> , (code IRIS = 772980000)
# LES FILASSES MERILLY 77520 THENISY ===> , (code IRIS = 774610000)
# LE FETE NORD 77520 THENISY ===> , (code IRIS = 774610000)
# CHAMPORE 77520 THENISY ===> , (code IRIS = 774610000)
# LE CHAMP DES GENETS 77520 GURCY-LE-CHATEL ===> , (code IRIS = 772230000)
# LE CHEMIN DE LA MAROTTE 77520 GURCY-LE-CHATEL ===> , (code IRIS = 772230000)
# LE CHARDONNERET 77520 GURCY-LE-CHATEL ===> , (code IRIS = 772230000)
# 23 RUE RES LE CLOS DU CHATEL 77970 JOUY-LE-CHATEL ===> , (code IRIS = 772390000)
# RUE DU GENERAL LECLERC 77370 NANGIS ===> 48.5563029,3.011918 (code IRIS = 773270101)
# 58 RUE DU GENERAL LECLERC 77370 NANGIS ===> 48.5563029,3.011918 (code IRIS = 773270101)
# 8 RUE DE L'ABREUVOIR 77134 ORMES-SUR-VOULZIE (LES) ===> 48.4649501,3.2325574 (code IRIS = 773470000)
# 6 ALL MARTIN LUTHER KING 77370 NANGIS ===> 48.5509094,3.0095252 (code IRIS = 773270103)
# 7 RUE D HEURTEBIZE 77520 VIMPELLES ===> , (code IRIS = 775240000)
# 5004  CERNEUX 77320 CERNEUX ===> 48.6934482,3.3452005 (code IRIS = 770660000)
# LE MEZ 77320 CERNEUX ===> , (code IRIS = 770660000)
# 20 RUE DU CHATEAU 77114 GOUAIX ===> 48.4738016,3.2987454 (code IRIS = 772080000)
# RUE DU CHATEAU 77114 GOUAIX ===> 48.4738016,3.2987454 (code IRIS = 772080000)
# 15 RUE REBAIS 77160 PROVINS ===> 48.5622436,3.3020723 (code IRIS = 773790103)
# 4 RUE DES TOURNELLES 77560 VILLIERS-SAINT-GEORGES ===> 48.6476307,3.4081967 (code IRIS = 775190000)
# 16 RUE DU TEMPLE 77160 PROVINS ===> 48.5620475,3.3030333 (code IRIS = 773790103)
# 1 CHEM DE LA FERME 77370 NANGIS ===> , (code IRIS = 773270101)
# LE GRAND CHAMP 77370 NANGIS ===> , (code IRIS = 773270101)
# LA PIECE DES SIX ARPENTS 77650 SAINT-LOUP-DE-NAUD ===> , (code IRIS = 774180000)
# LES MOULINEAUX 77370 CHAPELLE-RABLAIS (LA) ===> 48.5128288,2.9719804 (code IRIS = 770890000)
# 18 RUE DES MOULINEAUX 77370 CHAPELLE-RABLAIS (LA) ===> 48.5128288,2.9719804 (code IRIS = 770890000)
# 24 RUE DE LA TUILERIE 77370 NANGIS ===> 48.5519904,3.0084274 (code IRIS = 773270103)
# LES MAZIETTES 77520 MONS-EN-MONTOIS ===> , (code IRIS = 772980000)
# DERRIERE LE PETIT CESSOY 77520 CESSOY-EN-MONTOIS ===> , (code IRIS = 770680000)
# LA MARE GOBIN 77520 DONNEMARIE-DONTILLY ===> , (code IRIS = 771590000)
# 45 AV DE CHAMPABON 77520 DONNEMARIE-DONTILLY ===> , (code IRIS = 771590000)
# 5 IMP DE LA BORDE 77126 EGLIGNY ===> 48.4263044,3.1197851 (code IRIS = 771670000)
# 43 RUE DU MOULIN D'OCLE 77134 ORMES-SUR-VOULZIE (LES) ===> 48.4675715,3.2293691 (code IRIS = 773470000)
# HAMEAU DU MOULIN D'OCLE 77134 ORMES-SUR-VOULZIE (LES) ===> , (code IRIS = 773470000)
# 11 RUE DU CALVAIRE 77520 MONS-EN-MONTOIS ===> 48.4875336,3.1432547 (code IRIS = 772980000)
# LE PETIT CLOS BOUARD 77520 MONS-EN-MONTOIS ===> , (code IRIS = 772980000)
# 14 RUE DU MONTGRAS 77520 DONNEMARIE-DONTILLY ===> 48.4813334,3.1210175 (code IRIS = 771590000)
# LE PRE AU DIABLE 77134 ORMES-SUR-VOULZIE (LES) ===> , (code IRIS = 773470000)
# 4 CHE DE LA CHARDONNERIE 77520 DONNEMARIE-DONTILLY ===> , (code IRIS = 771590000)
# LA CHARDONNERIE 77520 DONNEMARIE-DONTILLY ===> , (code IRIS = 771590000)
# 2 RUE DE CHAUPRY 77126 CHATENAY-SUR-SEINE ===> 48.4255871,3.0935648 (code IRIS = 771010000)
# LES BELLES VERGES 77160 PROVINS ===> , (code IRIS = 773790103)
# 50 AV PATTON 77160 SAINT-BRICE ===> 48.5638322,3.3170983 (code IRIS = 774030000)
# LA BRETONNIERE 77160 ROUILLY ===> 48.584012,3.2884633 (code IRIS = 773910000)
# 16 RUE GRANDE 77160 ROUILLY ===> 48.5830652,3.2862978 (code IRIS = 773910000)
# 14 AV DE LA LIBERATION 77650 SAINTE-COLOMBE ===> 48.5337729,3.2641416 (code IRIS = 774040000)
# BEAUJARD 77650 SAINTE-COLOMBE ===> 48.539746,3.2671102 (code IRIS = 774040000)
# NORD DE VARAILLE 77650 SAINTE-COLOMBE ===> , (code IRIS = 774040000)
# 2 RUE DE L'OUCHE 77320 SANCY LES PROVINS ===> 48.6968895,3.3904658 (code IRIS = 774440000)
# PRES DESMALLETONS 77114 HERME ===> , (code IRIS = 772270000)
# 3 PL HONORE DE BALZAC 77160 PROVINS ===> 48.5593696,3.297577329407234 (code IRIS = 773790103)
# LA PIECE DU BOURG 77134 ORMES-SUR-VOULZIE (LES) ===> , (code IRIS = 773470000)
# 1 SEN DE LA MESSE 77134 ORMES-SUR-VOULZIE (LES) ===> , (code IRIS = 773470000)
# FLAMBOIN 77114 GOUAIX ===> 48.4735267,3.2946669 (code IRIS = 772080000)
# 49 RUE DU CHATEAU 77114 GOUAIX ===> 48.4738016,3.2987454 (code IRIS = 772080000)
# 4 RUE DE LA FORET 77970 BANNOST-VILLEGAGNON ===> 48.6758872,3.1931802 (code IRIS = 770200000)
# 7 RUE DE LA SABLIERE 77520 DONNEMARIE-DONTILLY ===> 48.4766042,3.1229659 (code IRIS = 771590000)
#
#
# Etape : 300
# 15:21:16
# Temps pour 100 : 71.97156524658203 sec
#
#
# LES JAULIETTES 77520 DONNEMARIE-DONTILLY ===> , (code IRIS = 771590000)
# 35 SEN DE LA FONTAINE 77160 PROVINS ===> , (code IRIS = 773790103)
# 23 SEN DE LA FONTAINE 77160 PROVINS ===> , (code IRIS = 773790103)
# 17 CHE DES FOSSES EST 77118 BAZOCHES LES BRAY ===> 48.400688,3.1916143 (code IRIS = 770250000)
# 20 RUE DE LA LIBERATION 77370 NANGIS ===> 48.5564585,3.0076293 (code IRIS = 773270103)
# 6 RUE DU MOULIN DES FORGES 77160 POIGNY ===> 48.5478746,3.2892414 (code IRIS = 773680000)
# LES GRANDS CLOS 77480 MOUSSEAUX-LES-BRAY ===> , (code IRIS = 773210000)
# 35 RUE DE LA TOUR 77171 LECHELLE ===> 48.5774236,3.3893187 (code IRIS = 772460000)
# LE BOURG 77171 LECHELLE ===> 49.190591,1.2344055 (code IRIS = )
# RUE DU DOCTEUR SCHWEITZER 77650 SAINTE-COLOMBE ===> 48.5298128,3.2608112 (code IRIS = 774040000)
# 34 RUE DU DOCTEUR SCHWEITZER 77650 SAINTE-COLOMBE ===> 48.5298128,3.2608112 (code IRIS = 774040000)
# MOUSSEAUX LES BRAY 77480 MOUSSEAUX-LES-BRAY ===> 48.4170599,3.230666927122895 (code IRIS = 773210000)
# 151 CITE DE LA SUCRERIE 77480 MOUSSEAUX-LES-BRAY ===> 48.4147395,3.2303215 (code IRIS = 773210000)
# 5 CHE DES ORMES 77520 VIMPELLES ===> 48.4597325,3.1647684 (code IRIS = 775240000)
# 15 RUE DE LA PORTE DE PROVINS 77520 DONNEMARIE-DONTILLY ===> 48.4786514,3.1353627 (code IRIS = 771590000)
# 25 ALL LIONEL TERRAY 77370 NANGIS ===> 48.5537178,3.0214768 (code IRIS = 773270102)
# 4 RUE DE LA REPUBLIQUE 77370 NANGIS ===> 48.5546389,3.016545 (code IRIS = 773270101)
# LA MORT PLANTY 77118 BAZOCHES LES BRAY ===> , (code IRIS = 770250000)
# 8 CHE DU BOUT DES VOIES 77118 BAZOCHES LES BRAY ===> 48.4004265,3.178479 (code IRIS = 770250000)
# 9 RUE AU BEURRE 77520 MONTIGNY-LENCOUP ===> 48.4526671,3.0612636 (code IRIS = 773110000)
# 5 RUE DU CHATEL 77370 NANGIS ===> 48.5603369,3.0170253 (code IRIS = 773270101)
# 6 CHE DES MARAIS 77650 SAINTE-COLOMBE ===> 48.5301081,3.2531491 (code IRIS = 774040000)
# 25 RUE DES FILASSES 77160 CHAPELLE-SAINT-SULPICE (LA) ===> 48.5557805,3.1802752 (code IRIS = 770900000)
# 29 RUE DE L'ORMURION 77171 SOURDUN ===> 48.5388691,3.3562514 (code IRIS = 774590000)
# 22 N ROUTE NATIONALE 4 77151 MONTCEAUX-LES-PROVINS ===> , (code IRIS = 773010000)
# MONTCEAUX 77151 MONTCEAUX-LES-PROVINS ===> 48.694653,3.438183 (code IRIS = 773010000)
# 11 RUE FARION 77160 PROVINS ===> 48.5436678,3.290823 (code IRIS = 773790202)
# 31 RUE JOLY 77160 PROVINS ===> 48.5577175,3.2962274 (code IRIS = 773790103)
# 3 RUE DES TYRACHIENS 77171 LECHELLE ===> 48.5767083,3.3822334 (code IRIS = 772460000)
# 4 RUE LOUISE MUNAUT 77160 PROVINS ===> 48.5575785,3.2987596 (code IRIS = 773790103)
# 1 RUE GRANDE 77171 LECHELLE ===> 48.5625149,3.4013518 (code IRIS = 772460000)
# LES PATURES DU GUE 77370 NANGIS ===> , (code IRIS = 773270101)
# 10 RUE BERTIE ALBRECHT 77370 NANGIS ===> 48.5547929,3.0034604 (code IRIS = 773270103)
# 12 RUE JOSEPH BARA 77480 BRAY-SUR-SEINE ===> 48.4151973,3.2385012 (code IRIS = 770510000)
# 9 RUE DU GENERAL DE GAULLE 77970 PECY ===> 48.6564812,3.0772359 (code IRIS = 773570000)
# PECY NORD 77970 PECY ===> , (code IRIS = 773570000)
# LE PETIT EPINEE 77480 MOUY-SUR-SEINE ===> , (code IRIS = 773250000)
# LA COURTINE 77480 MOUY-SUR-SEINE ===> 48.4322079,3.2503922 (code IRIS = 773250000)
# LES CHAMPS FLEURIS 77480 MOUY-SUR-SEINE ===> , (code IRIS = 773250000)
# 5 RUE DE L'EGLANTIER 77160 PROVINS ===> 48.5455256,3.2956293 (code IRIS = 773790202)
# 19 VTE VIEILLE RTE DE MONS 77520 DONNEMARIE-DONTILLY ===> , (code IRIS = 771590000)
# LE POIRIER 77520 DONNEMARIE-DONTILLY ===> 48.4793547,3.1288116 (code IRIS = 771590000)
# 5 PL DES CHARMES 77160 CHENOISE-CUCHARMOY ===> 48.6119548,3.1951344 (code IRIS = 771090000)
# 7 RUE VALENTIN ABEILLE 77160 PROVINS ===> 48.5619675,3.2969187 (code IRIS = 773790102)
# 9 RTE DE SAVIGNY 77160 SAINT-HILLIERS ===> 48.6208207,3.2594801 (code IRIS = 774140000)
# 8  MELENFROY 77970 PECY ===> 48.6483975,3.0582509 (code IRIS = 773570000)
# BAS DE MELENFROY 77970 PECY ===> , (code IRIS = 773570000)
# 7 RUE MAL DE LATTRE DE TASSIGNY 77370 NANGIS ===> , (code IRIS = 773270101)
# 6 RUE DU POIRIER 77160 PROVINS ===> 48.5717587,3.2891339 (code IRIS = 773790101)
# 6 SEN DES AUGES 77160 PROVINS ===> , (code IRIS = 773790103)
# 11 AV DE LA LIBERATION 77160 PROVINS ===> 48.5615151,3.308169 (code IRIS = 773790201)
# CHAMP SAINT LAURENT 77320 BETON-BAZOCHES ===> , (code IRIS = 770320000)
# LE BOIS AUX DAMES 77160 CHALAUTRE-LA-PETITE ===> 48.511816100000004,3.3285776951016004 (code IRIS = 770730000)
# LES PRES VIGNY 77650 SOISY-BOUY ===> , (code IRIS = 774560000)
# LES FRAIS-CULS 77650 SOISY-BOUY ===> , (code IRIS = 774560000)
# LE BOIS DES GROS GRES 77650 SOISY-BOUY ===> , (code IRIS = 774560000)
# MAISON-ROUGE 77370 MAISON-ROUGE ===> 49.4961165,3.7802627 (code IRIS = )
# 16 RUE DE LA CROIX BLANCHE 77370 MAISON-ROUGE ===> 48.55863,3.1486361 (code IRIS = 772720000)
# 7 RUE DU BOIS AUX DAMES 77650 SOISY-BOUY ===> 48.5114828,3.3002422 (code IRIS = 774560000)
# 6 RUE DES MERLES 77160 SAINT-BRICE ===> 48.566762,3.3164816 (code IRIS = 774030000)
# 2 RUE DE LA MAIRIE 77520 VIMPELLES ===> 48.439088,3.1668804 (code IRIS = 775240000)
# CHAUMARD 77480 VILLENAUXE-LA-PETITE ===> 48.4267119,3.2998114 (code IRIS = 775070000)
# LE CHAMP BURIN 77480 VILLENAUXE-LA-PETITE ===> , (code IRIS = 775070000)
# 30 RUE DES GEMEAUX 77114 GOUAIX ===> 48.47809,3.2922171 (code IRIS = 772080000)
# 10 RUE NOAS DAUMESNIL 77370 NANGIS ===> 48.5563011,3.0159388 (code IRIS = 773270101)
# 5 ALL LIONEL TERRAY 77370 NANGIS ===> 48.5537178,3.0214768 (code IRIS = 773270102)
# 13 RUE DES PERVENCHES 77370 NANGIS ===> 48.554617,3.0195956 (code IRIS = 773270102)
# 12 FG NOTAIRE 77370 NANGIS ===> 48.5547201,3.0255185 (code IRIS = 773270101)
# 5118  LE COURTIL DES CHAMPS 77970 BANNOST-VILLEGAGNON ===> , (code IRIS = 770200000)
# 16 GR GRANDE RUE 77520 MONTIGNY-LENCOUP ===> , (code IRIS = 773110000)
# LE VILLAGE 77520 MONTIGNY-LENCOUP ===> 48.4541416,3.0602601 (code IRIS = 773110000)
# 4 RUE DE LA MARE A LA CANE 77370 CHAPELLE-RABLAIS (LA) ===> 48.512636,2.9700069 (code IRIS = 770890000)
# LA CHAPELLE 77370 CHAPELLE-RABLAIS (LA) ===> 48.5119093,2.9717314 (code IRIS = 770890000)
# 7 RUE BERTHIER 77520 SOGNOLLES-EN-MONTOIS ===> 48.513245,3.1663502 (code IRIS = 774540000)
# 8 RUE RAYMOND EVRARD 77171 SOURDUN ===> 48.5371661,3.3597103 (code IRIS = 774590000)
# 6 RUE JEAN MOULIN 77370 NANGIS ===> 48.5560627,3.0224017 (code IRIS = 773270101)
# 3 RUE DE MIRVAUX 77970 PECY ===> 48.6468368,3.0869159 (code IRIS = 773570000)
# MOULIN DU PONT BENOIST 77650 SAINTE-COLOMBE ===> , (code IRIS = 774040000)
# 61 AV DU GENERAL LECLERC 77650 SAINTE-COLOMBE ===> 48.5238927,3.2469092 (code IRIS = 774040000)
# LE CORBIER 77970 JOUY-LE-CHATEL ===> 48.689258,3.1258142 (code IRIS = 772390000)
# 18 ALL LIONEL TERRAY 77370 NANGIS ===> 48.5537178,3.0214768 (code IRIS = 773270102)
# FAUBOURG SAINT-ANTOINE 77370 NANGIS ===> , (code IRIS = 773270101)
# 10 ALL LIONEL TERRAY 77370 NANGIS ===> 48.5537178,3.0214768 (code IRIS = 773270102)
# LE PRE DE PEUGNY 77480 MOUY-SUR-SEINE ===> , (code IRIS = 773250000)
# LES PATURES DE LA VOIE NEU 77118 BAZOCHES LES BRAY ===> , (code IRIS = 770250000)
# LES GRANDS ET PETITS MARAI 77480 VILLUIS ===> , (code IRIS = 775230000)
# LE MOULIN 77480 VILLUIS ===> , (code IRIS = 775230000)
# 24 RUE DES FORGES 77480 VILLUIS ===> 48.4087463,3.3564353 (code IRIS = 775230000)
# LES PIERRERIES 77480 FONTAINE-FOURCHES ===> , (code IRIS = 771870000)
# 757 RTE DE SENS 77480 BRAY-SUR-SEINE ===> 48.4164431,3.2350686 (code IRIS = 770510000)
# 790 RTE DE SENS 77480 MOUSSEAUX-LES-BRAY ===> 48.4164431,3.2350686 (code IRIS = 773210000)
# PENTE DU BOIS BLOQUET 77970 PECY ===> , (code IRIS = 773570000)
# GIVRY 77970 PECY ===> 48.6349615,3.0673304 (code IRIS = 773570000)
# 8 IMP DE GIVRY 77970 PECY ===> 48.6346046,3.0668785 (code IRIS = 773570000)
# 10 IMP DE GIVRY 77970 PECY ===> 48.6346046,3.0668785 (code IRIS = 773570000)
# 6 IMP DE GIVRY 77970 PECY ===> 48.6346046,3.0668785 (code IRIS = 773570000)
# 4 CHE DES CLOS 77480 MONTIGNY-LE-GUESDIER ===> 48.3807393,3.2558799 (code IRIS = 773100000)
# 13 AV DE LA LIBERATION 77160 PROVINS ===> 48.5615151,3.308169 (code IRIS = 773790201)
# 15 RUE MEROT 77480 FONTAINE-FOURCHES ===> 48.4159221,3.3872081 (code IRIS = 771870000)
#
#
# Etape : 400
# 15:22:21
# Temps pour 100 : 65.06285214424133 sec
#
#
# FOURCHES 77480 FONTAINE-FOURCHES ===> 48.4139155,3.3915957 (code IRIS = 771870000)
# 4 RUE DES FILASSES 77160 CHAPELLE-SAINT-SULPICE (LA) ===> 48.5557805,3.1802752 (code IRIS = 770900000)
# 15 RUE SAINT BONNET 77370 CHAPELLE-RABLAIS (LA) ===> 48.5115392,2.9688541 (code IRIS = 770890000)
# 22 RUE DE LA FORET 77370 SAINT-JUST-EN-BRIE ===> 48.6088543,3.1253707 (code IRIS = 774160000)
# L HUILIER 77370 GASTINS ===> , (code IRIS = 772010000)
# LE MARAIS DE FOURCHES 77480 FONTAINE-FOURCHES ===> , (code IRIS = 771870000)
# LA POINTE PIQUET 77480 MONTIGNY-LE-GUESDIER ===> , (code IRIS = 773100000)
# 15 RTE NATIONALE 77134 ORMES-SUR-VOULZIE (LES) ===> 48.4645476,3.2266749 (code IRIS = 773470000)
# 6 RUE PERREE 77370 MAISON-ROUGE ===> 48.5575252,3.1513352 (code IRIS = 772720000)
# 7 RUE GRANDE 77560 AUGERS-EN-BRIE ===> 48.68035,3.3565038 (code IRIS = 770120000)
# 5248  LA GRANDE BOSSE 77118 BAZOCHES LES BRAY ===> , (code IRIS = 770250000)
# 6 RUE PIERRE EUGENE CLAIRIN 77160 PROVINS ===> 48.5546635,3.2904222 (code IRIS = 773790201)
# PRAIRIE ENTRE DEUX EAUX 77160 PROVINS ===> , (code IRIS = 773790103)
# 420 RUE DE VILLENEUVE 77154 COUTENCON ===> 48.4725774,3.0001978 (code IRIS = 771400000)
# 13 RTE DE PROVINS 77560 COURTACON ===> 48.6913242,3.290132 (code IRIS = 771370000)
# 3 RUE DE LA FONTAINE 77520 MEIGNEUX ===> 48.51185815,3.103558177040677 (code IRIS = 772860000)
# 11 PL DE L'EGLISE 77370 FONTAINS ===> 48.52638,3.0012484 (code IRIS = 771900000)
# 3 RUE ESTIENNE D'ORVES 77370 NANGIS ===> , (code IRIS = 773270101)
# 17 RUE DES PRES HAUTS 77370 MAISON-ROUGE ===> 48.5552308,3.1500165 (code IRIS = 772720000)
# 19 RUE DU GRAND BOISSY 77160 SAINT-HILLIERS ===> 48.6144639,3.2468967 (code IRIS = 774140000)
# 17 RUE DE VILLEFLON 77970 BANNOST-VILLEGAGNON ===> , (code IRIS = 770200000)
# SEN DU HT DE LA FONTAINE RIAN 77160 PROVINS ===> , (code IRIS = 773790103)
# 8 SEN DU HT DE LA FONTAINE RIAN 77160 PROVINS ===> , (code IRIS = 773790103)
# 6 SEN DU HT DE LA FONTAINE RIAN 77160 PROVINS ===> , (code IRIS = 773790103)
# 13 RUE DES BUTTES 77480 BRAY-SUR-SEINE ===> 48.4146588,3.2362363 (code IRIS = 770510000)
# MORTERY 77160 MORTERY ===> 48.5989683,3.259951 (code IRIS = 773190000)
# 16 RUE DE PROVINS 77160 MORTERY ===> 48.5973995,3.2625481 (code IRIS = 773190000)
# 11 RUE MONTMART 77520 MONTIGNY-LENCOUP ===> 48.4538524,3.0603788 (code IRIS = 773110000)
# 2 RUE AMPERE 77370 NANGIS ===> 48.5566212,3.0214629 (code IRIS = 773270101)
# 4 RUE DE PARIS 77970 BOISDON ===> 48.6845993,3.2214029 (code IRIS = 770360000)
# 25 RUE DE LA FORET 77160 CHENOISE-CUCHARMOY ===> 48.618391,3.1946083 (code IRIS = 771090000)
# 14 RUE DE LA PLAINE 77160 CHENOISE-CUCHARMOY ===> 48.6177366,3.1987161 (code IRIS = 771090000)
# 28 RUE GRANDE 77130 TOMBE (LA) ===> 48.3883018,3.0898598 (code IRIS = 774670000)
# 9 BD D HAUSSONVILLE 77520 DONNEMARIE-DONTILLY ===> , (code IRIS = 771590000)
# LE PRE PADOU 77520 DONNEMARIE-DONTILLY ===> 48.4777976,3.1283498 (code IRIS = 771590000)
# 15 RUE PASTEUR 77370 NANGIS ===> 48.5572736,3.0124131 (code IRIS = 773270101)
# 23 GR GRANDE RUE 77560 MARETS (LES) ===> 48.6642535,3.3123126 (code IRIS = 772750000)
# 8 RUE DE COURTENOT 77320 SAINT-MARTIN-DU-BOSCHET ===> 48.7404705,3.4311913 (code IRIS = 774240000)
# 28 RUE DE PROVINS 77650 SAINT-LOUP-DE-NAUD ===> 48.534596,3.2282117 (code IRIS = 774180000)
# 11 RUE DE L'EGLANTIER 77160 PROVINS ===> 48.5455256,3.2956293 (code IRIS = 773790202)
# 19 RUE FELIX BOURQUELOT 77160 PROVINS ===> 48.5611957,3.3047887 (code IRIS = 773790103)
# RUE DE PARIS 77970 JOUY-LE-CHATEL ===> 48.6682929,3.1258886 (code IRIS = 772390000)
# 7 RUE DE PARIS 77970 JOUY-LE-CHATEL ===> 48.6682929,3.1258886 (code IRIS = 772390000)
# 7 RUE DE PROVINS 77560 VILLIERS-SAINT-GEORGES ===> 48.6474855,3.4059328 (code IRIS = 775190000)
# 3 RUE RAYMOND EVRARD 77171 SOURDUN ===> 48.5371661,3.3597103 (code IRIS = 774590000)
# 5 IMP DE BAALE 77560 COURCHAMP ===> , (code IRIS = 771340000)
# 1 RUE RAPIN 77650 SOISY-BOUY ===> 48.5128307,3.3011682 (code IRIS = 774560000)
# BOUY 77650 SOISY-BOUY ===> 48.509863,3.2899593 (code IRIS = 774560000)
# 5001 RTE NATIONALE 19 77171 SOURDUN ===> , (code IRIS = 774590000)
# 57 ALL DES COQUELICOTS 77480 BRAY-SUR-SEINE ===> 48.4084957,3.2391787 (code IRIS = 770510000)
# 599 RUE GRANDE 77480 MOUSSEAUX-LES-BRAY ===> , (code IRIS = 773210000)
# 9 RES LE CLOS DU DOME 77160 PROVINS ===> , (code IRIS = 773790103)
# 6 PL DE L'EGLISE 77320 SANCY LES PROVINS ===> 48.6965171,3.3924676 (code IRIS = 774440000)
# SANCY 77320 SANCY LES PROVINS ===> 48.6965174,3.3921 (code IRIS = 774440000)
# 9 RUE DE LA GARE 77171 LECHELLE ===> 48.5793782,3.3943243 (code IRIS = 772460000)
# LES PRES DU ROI 77650 LONGUEVILLE ===> , (code IRIS = 772600000)
# 8 RUE DES PRES DU ROY 77650 LONGUEVILLE ===> 48.5115434,3.2498075 (code IRIS = 772600000)
# 5 RUE AUX PORCELETS 77160 PROVINS ===> , (code IRIS = 773790103)
# 5 RUE DU CLOS DE LA FERME 77560 VILLIERS-SAINT-GEORGES ===> 48.645905,3.407349 (code IRIS = 775190000)
# 24 RUE DE LA GARE 77970 BANNOST-VILLEGAGNON ===> 48.6798318,3.1902549 (code IRIS = 770200000)
# 7 RUE DES THUYAS 77560 VOULTON ===> 48.6152765,3.3291437 (code IRIS = 775300000)
# 2 RUE DES THUYAS 77560 VOULTON ===> 48.6152765,3.3291437 (code IRIS = 775300000)
# 9 RTE DE BRAY 77480 MONTIGNY-LE-GUESDIER ===> 48.3874334,3.2528042 (code IRIS = 773100000)
# LA VIEILLE VIGNE 77320 CERNEUX ===> , (code IRIS = 770660000)
# 12 RUE SAINTE CROIX 77160 PROVINS ===> 48.5610415,3.2978581 (code IRIS = 773790103)
# 38 RUE SAINT LAURENT 77320 SAINT-MARTIN-DU-BOSCHET ===> 48.716426,3.4257479 (code IRIS = 774240000)
# 20 RUE DES VIEUX PRES 77370 CHAPELLE-RABLAIS (LA) ===> 48.5078901,2.9519569 (code IRIS = 770890000)
# 7 RUE DE LA FONTAINE GEOFFROY 77520 MONTIGNY-LENCOUP ===> 48.4561987,3.0531827 (code IRIS = 773110000)
# VIEUX CHATEAU 77520 MONTIGNY-LENCOUP ===> , (code IRIS = 773110000)
# 11 PL TRUDAINE 77520 MONTIGNY-LENCOUP ===> 48.4526565,3.0622417 (code IRIS = 773110000)
# PL TRUDAINE 77520 MONTIGNY-LENCOUP ===> 48.45258015,3.0619996324960814 (code IRIS = 773110000)
# 5 RUE DES FOSSES 77970 JOUY-LE-CHATEL ===> 48.6654648,3.1301832 (code IRIS = 772390000)
# RUE DES FOSSES 77970 JOUY-LE-CHATEL ===> 48.6654648,3.1301832 (code IRIS = 772390000)
# 8 RPT BLAISE 77126 CHATENAY-SUR-SEINE ===> , (code IRIS = 771010000)
# 4 RUE AUX PAVIS 77520 MONS-EN-MONTOIS ===> 48.4914834,3.1525902 (code IRIS = 772980000)
# LE BOUT DE LA RUE 77520 MONS-EN-MONTOIS ===> , (code IRIS = 772980000)
# 6 RUE DE LA MUETTE 77126 CHATENAY-SUR-SEINE ===> 48.4144428,3.0968651 (code IRIS = 771010000)
# 12 RUE GABRIEL GARNIER 77650 CHALMAISON ===> 48.5065695,3.2509174 (code IRIS = 770760000)
# 8 RUE DE LAGOURD 77520 DONNEMARIE-DONTILLY ===> 48.4805979,3.1248705 (code IRIS = 771590000)
# 12 RUE DES GRAVIERS 77118 BALLOY ===> 48.3974666,3.145743 (code IRIS = 770190000)
# 15 GR GRANDE RUE A CUTRELLES 77520 VIMPELLES ===> , (code IRIS = 775240000)
# 38 RUE RAYMOND EVRARD 77171 SOURDUN ===> 48.5371661,3.3597103 (code IRIS = 774590000)
# 7 RUE DU FOUR 77520 DONNEMARIE-DONTILLY ===> 48.4778239,3.1337018 (code IRIS = 771590000)
# 5063  LARRAY 77114 GOUAIX ===> , (code IRIS = 772080000)
# LES PRES DES FLESHES 77650 SOISY-BOUY ===> , (code IRIS = 774560000)
# VILLENEUVE-LES-BORDES 77154 VILLENEUVE-LES-BORDES ===> 48.4969509,3.0169874 (code IRIS = 775090000)
# 1 RUE DU PRESBYTERE 77154 VILLENEUVE-LES-BORDES ===> 48.4860952,3.0445223 (code IRIS = 775090000)
# 3 RUE SERGE VEAU 77650 SAINT-LOUP-DE-NAUD ===> 48.5359988,3.2091543 (code IRIS = 774180000)
# 19 RUE DU PONT AUX DAMES 77560 VILLIERS-SAINT-GEORGES ===> 48.6490584,3.4079349 (code IRIS = 775190000)
# 6 GR GRANDE RUE 77480 GRISY-SUR-SEINE ===> 48.4368358,3.3171963 (code IRIS = 772180000)
# GR GRANDE RUE 77480 GRISY-SUR-SEINE ===> 48.4368358,3.3171963 (code IRIS = 772180000)
# 2 RUE DES GROUETTES 77650 JUTIGNY ===> 48.4997506,3.2329874 (code IRIS = 772420000)
# 8 RUE DES CAPUCINS 77160 PROVINS ===> 48.5594778,3.2946831 (code IRIS = 773790102)
# 23 RUE DE L'ORMURION 77171 SOURDUN ===> 48.5388691,3.3562514 (code IRIS = 774590000)
# 4 CHE DE LA PAVOTTE 77650 JUTIGNY ===> 48.4962018,3.2298728 (code IRIS = 772420000)
# 2 RUE DU PRESSOIR 77370 RAMPILLON ===> 48.5489693,3.064218 (code IRIS = 773830000)
# 1 IMP DE LA GRANGE AUX DIMES 77126 CHATENAY-SUR-SEINE ===> 48.4157171,3.0984676 (code IRIS = 771010000)
# 15 QUAI DE LA VOULZIE 77160 PROVINS ===> 48.5572369,3.3026289 (code IRIS = 773790103)
# 24 GR GRANDE RUE 77520 MONTIGNY-LENCOUP ===> , (code IRIS = 773110000)
#
#
# Etape : 500
# 15:23:24
# Temps pour 100 : 62.91595268249512 sec
#
#
# 15 RUE DU PETIT PARIS 77970 JOUY-LE-CHATEL ===> 48.6644308,3.1285245 (code IRIS = 772390000)
# SOUS LA BOISSIERE 77520 GURCY-LE-CHATEL ===> , (code IRIS = 772230000)
# LA BOISSIERE 77520 GURCY-LE-CHATEL ===> , (code IRIS = 772230000)
# BASSES LANDRES 77154 VILLENEUVE-LES-BORDES ===> , (code IRIS = 775090000)
# LE CLOS 77114 VILLIERS-SUR-SEINE ===> 48.645905,3.407349 (code IRIS = )
# 5 RUE NEUVE 77114 VILLIERS-SUR-SEINE ===> 48.4579564,3.3736838 (code IRIS = 775220000)
# 1 RUE DES FORGES 77480 VILLUIS ===> 48.4087463,3.3564353 (code IRIS = 775230000)
# 2 RUE DE LA CLOTURE 77126 CHATENAY-SUR-SEINE ===> 48.4206518,3.1002086 (code IRIS = 771010000)
# LE VILLAGE 77126 CHATENAY-SUR-SEINE ===> 48.4176813,3.0961472 (code IRIS = 771010000)
# 36 RUE ARISTIDE BRIAND 77160 PROVINS ===> 48.557298,3.2982815 (code IRIS = 773790103)
# CHENE DE LA FEUCHELLE 77114 NOYEN-SUR-SEINE ===> , (code IRIS = 773410000)
# 7  MOULIN DES PRES 77160 ROUILLY ===> , (code IRIS = 773910000)
# 1 RLE DE LA GROUE 77320 BETON-BAZOCHES ===> , (code IRIS = 770320000)
# LA GROUE 77320 BETON-BAZOCHES ===> 48.697187,3.237937 (code IRIS = 770320000)
# 21 RUE BLANCHE 77480 MONTIGNY-LE-GUESDIER ===> 48.380881,3.2533979 (code IRIS = 773100000)
# 1 CHE DE VILLECRAN 77160 PROVINS ===> 48.5598984,3.2786837 (code IRIS = 773790102)
# 18 RUE DU PAVE DU ROY 77370 MAISON-ROUGE ===> 48.5592068,3.1530625 (code IRIS = 772720000)
# 13 RUE DU MONTOIS 77370 MAISON-ROUGE ===> 48.5412337,3.1424748 (code IRIS = 772720000)
# LEUDON-GARE 77370 MAISON-ROUGE ===> , (code IRIS = 772720000)
# 2 RUE DE BRIE 77520 MEIGNEUX ===> 48.5114176,3.1036983 (code IRIS = 772860000)
# RUE DES FONTAINES HLM 77370 NANGIS ===> , (code IRIS = 773270101)
# RUE DES FONTAINES 77370 NANGIS ===> 48.5613088,3.010131 (code IRIS = 773270101)
# 54 RUE DES FONTAINES 77370 NANGIS ===> 48.5581016,3.0106424 (code IRIS = 773270101)
# 2 IMP GUINGUAN 77970 PECY ===> 48.6477932,3.0580627 (code IRIS = 773570000)
# LE PRE BOUCHARD 77370 CROIX-EN-BRIE (LA) ===> , (code IRIS = 771470000)
# 6 AV DE VERDUN 77370 NANGIS ===> 48.5574314,3.0233214 (code IRIS = 773270101)
# 9 RUE HUGUES LE GRAND 77160 PROVINS ===> 48.5593994,3.3010536 (code IRIS = 773790103)
# 5 RUE HUGUES LE GRAND 77160 PROVINS ===> 48.5593994,3.3010536 (code IRIS = 773790103)
# 39 RUE DU MOULIN 77370 GASTINS ===> 48.6299597,3.019385 (code IRIS = 772010000)
# 2 RUE DES PRAILLONS 77970 PECY ===> 48.6541233,3.0820952 (code IRIS = 773570000)
# 1 RUE DE LA FORET 77970 JOUY-LE-CHATEL ===> , (code IRIS = 772390000)
# 10 RUE DU LANDY 77370 GASTINS ===> 48.6250157,3.0175149 (code IRIS = 772010000)
# 10 RUE GRANDE 77160 SAINT-HILLIERS ===> 48.6218637,3.2589849 (code IRIS = 774140000)
# 54 RUE DU CARROUGE 77650 SAVINS ===> 48.5080372,3.1975183 (code IRIS = 774460000)
# 112  DOMAINE DE LA GOUJONNE 77480 SAINT-SAUVEUR-LES-BRAY ===> 48.4272874,3.2192545 (code IRIS = 774340000)
# 22 RUE DU PUITS 77160 MORTERY ===> 48.5818434,3.2457191 (code IRIS = 773190000)
# 6 RUE DE LA FONTAINE 77118 BALLOY ===> 48.3977733,3.1511884 (code IRIS = 770190000)
# LA PISSEROTTE 77650 SAINTE-COLOMBE ===> 48.5273989,3.2590142 (code IRIS = 774040000)
# LES FOSSES JAMBEAUX 77126 CHATENAY-SUR-SEINE ===> , (code IRIS = 771010000)
# 12 RTE DE MONTEREAU 77126 CHATENAY-SUR-SEINE ===> 48.4176046,3.0916772 (code IRIS = 771010000)
# 8 RUE DU VILLE 77520 MONS-EN-MONTOIS ===> 48.4858845,3.1501241 (code IRIS = 772980000)
# LE VILLE 77520 MONS-EN-MONTOIS ===> 48.48635,3.148079 (code IRIS = 772980000)
# 2 RUE DU PORT AUX RALES 77126 EGLIGNY ===> 48.4265112,3.1221369 (code IRIS = 771670000)
# 10 RUE DE L'EGLISE 77171 LECHELLE ===> 48.5773668,3.3880956 (code IRIS = 772460000)
# RUE DES JARDINS 77520 DONNEMARIE-DONTILLY ===> 48.4764163,3.1240391 (code IRIS = 771590000)
# 15 VOIE DE LA LIBERTE 77520 MONTIGNY-LENCOUP ===> 48.4510098,3.0582438 (code IRIS = 773110000)
# LE TOMBEREAU 77520 DONNEMARIE-DONTILLY ===> , (code IRIS = 771590000)
# 16 RUE MARIUS BILLARD 77520 DONNEMARIE-DONTILLY ===> 48.4764448,3.1278963 (code IRIS = 771590000)
# 3 CHE MALADRERIE 77520 DONNEMARIE-DONTILLY ===> , (code IRIS = 771590000)
# 3 RUE DE LA BERTAUCHE 77370 NANGIS ===> 48.5573026,3.0188524 (code IRIS = 773270101)
# LE CARCAN 77370 CROIX-EN-BRIE (LA) ===> , (code IRIS = 771470000)
# 7 CHE DES FOURNEAUX 77520 DONNEMARIE-DONTILLY ===> , (code IRIS = 771590000)
# BECHERELLES 77520 DONNEMARIE-DONTILLY ===> , (code IRIS = 771590000)
# BEAUREGARD 77970 BEZALLES ===> 48.661809,3.246713 (code IRIS = 770330000)
# 20 RUE GRANDE 77970 BEZALLES ===> 48.6607882,3.2450573 (code IRIS = 770330000)
# 18 RUE GRANDE 77970 BEZALLES ===> 48.6607882,3.2450573 (code IRIS = 770330000)
# 1 RUE DES MOEURS 77970 BANNOST-VILLEGAGNON ===> 48.6623666,3.2215078 (code IRIS = 770200000)
# LA CONQUILLIE 77970 BANNOST-VILLEGAGNON ===> , (code IRIS = 770200000)
# 30 RUE DE LA CAVE 77520 MONTIGNY-LENCOUP ===> 48.4594431,3.0694374 (code IRIS = 773110000)
# RUE DE LA MAROTTE 77520 MONTIGNY-LENCOUP ===> 48.4589806,3.0706349 (code IRIS = 773110000)
# RUE DE LA CAVE 77520 MONTIGNY-LENCOUP ===> 48.4594431,3.0694374 (code IRIS = 773110000)
# 20 RUE DE LA BECELLE 77970 BANNOST-VILLEGAGNON ===> 48.6806187,3.1917618 (code IRIS = 770200000)
# 7 RUE DU PETIT LUBOIN 77160 SAINT-BRICE ===> 48.5694754,3.350004 (code IRIS = 774030000)
# LE PETIT LUBOUIN 77160 SAINT-BRICE ===> , (code IRIS = 774030000)
# 39 RUE VICTOR GARNIER 77160 PROVINS ===> 48.5596178,3.2986968 (code IRIS = 773790103)
# LES HUCHES 77114 HERME ===> , (code IRIS = 772270000)
# 37 AV DU MARECHAL FOCH 77370 NANGIS ===> 48.5609609,3.0133417 (code IRIS = 773270101)
# 9 RUE FELIX BOURQUELOT 77160 PROVINS ===> 48.5611957,3.3047887 (code IRIS = 773790103)
# 16 RUE DU PARC 77560 VILLIERS-SAINT-GEORGES ===> 48.6508944,3.4026985 (code IRIS = 775190000)
# 8 RUE DES JARDINS 77520 DONNEMARIE-DONTILLY ===> 48.4764163,3.1240391 (code IRIS = 771590000)
# 3 RUE DE L'AUDITOIRE 77118 BAZOCHES LES BRAY ===> 48.3981209,3.1885716 (code IRIS = 770250000)
# LES AIGUILLERES 77560 CHAMPCENEST ===> , (code IRIS = 770800000)
# 79 RUE D HERME 77160 CHALAUTRE-LA-PETITE ===> , (code IRIS = 770730000)
# 25 SEN DE LA FONTAINE 77160 PROVINS ===> , (code IRIS = 773790103)
# 5 RUE DES THUYAS 77160 CHENOISE-CUCHARMOY ===> 48.6141239,3.1897044 (code IRIS = 771090000)
# 5 RUE AUX AULX 77160 PROVINS ===> 48.5602511,3.2969913 (code IRIS = 773790103)
# 20 ALL LIONEL TERRAY 77370 NANGIS ===> 48.5537178,3.0214768 (code IRIS = 773270102)
# 19 RUE DU PONT DE L'AUBETIN 77320 BETON-BAZOCHES ===> 48.7019131,3.2439196 (code IRIS = 770320000)
# 3 CHE DES DEMOISELLES 77970 PECY ===> 48.6498248,3.0595911 (code IRIS = 773570000)
# LES ETANGS 77320 BETON-BAZOCHES ===> , (code IRIS = 770320000)
# 9 RUE DU BARREAU 77160 PROVINS ===> 48.5654694,3.3029712 (code IRIS = 773790101)
# 36 RUE SERGE VEAU 77650 SAINT-LOUP-DE-NAUD ===> 48.5359988,3.2091543 (code IRIS = 774180000)
# RUE SERGE VEAU 77650 SAINT-LOUP-DE-NAUD ===> 48.5359988,3.2091543 (code IRIS = 774180000)
# 48 RUE GRANDE 77157 EVERLY ===> 48.4651352,3.2476619 (code IRIS = 771740000)
# 2 RUE MOULIN DE LA RUELLE 77160 PROVINS ===> , (code IRIS = 773790103)
# 9 RUE DES CASTORS 77370 NANGIS ===> 48.5558613,3.0234074 (code IRIS = 773270101)
# RUE DE PROVINS 77970 JOUY-LE-CHATEL ===> 48.6644076,3.1344339 (code IRIS = 772390000)
# 5 RUE DE PROVINS 77970 JOUY-LE-CHATEL ===> 48.6644076,3.1344339 (code IRIS = 772390000)
# ...
# RTE DE LA BRUYERE 79160 SAINT-LAURS ===> 46.5239244,-0.5844753 (code IRIS = 792630000)
# 64 RTE DE LA BRUYERE 79160 SAINT-LAURS ===> 46.5239244,-0.5844753 (code IRIS = 792630000)
# 5 RUE DE LA PAITRAIE 79290 BRION-PRES-THOUET ===> 47.051137,-0.1899213 (code IRIS = 790560000)
# LA GRIPPIERE 79150 SAINT MAURICE ETUSSON ===> , (code IRIS = 792800000)
# 5014  LA GRIPPIERE 79150 SAINT MAURICE ETUSSON ===> , (code IRIS = 792800000)
# LA VERDRIE 79150 SAINT MAURICE ETUSSON ===> , (code IRIS = 792800000)
# 5176  LA VERDRIE 79150 SAINT MAURICE ETUSSON ===> , (code IRIS = 792800000)
# 5175  LA VERDRIE 79150 SAINT MAURICE ETUSSON ===> , (code IRIS = 792800000)
# 10 RUE ST MELAINE 79700 MAULEON ===> 46.9235062,-0.751539 (code IRIS = 790790101)
# 8 RUE ST MELAINE 79700 MAULEON ===> 46.9238885,-0.7510699 (code IRIS = 790790101)
# 8 RUE DE LA TREILLE 79500 MELLE ===> 46.2198095,-0.1474162 (code IRIS = 791740000)
# 118 RUE PATRICE COIRAULT 79220 SURIN ===> 46.463872,-0.4615798 (code IRIS = 793200000)
# 16 RUE CHARLES MARTEL ST SAUVEUR 79300 BRESSUIRE ===> 46.822268,-0.4186307 (code IRIS = 790490111)
# 25 RUE DE BEL AIR 79300 BRESSUIRE ===> 46.8422236,-0.5048796 (code IRIS = 790490105)
# 1 RUE GERICAULT 79100 THOUARS ===> 46.9894664,-0.2148359 (code IRIS = 793290105)
# 40 RUE DES GUIGNES 79250 NUEIL-LES-AUBIERS ===> , (code IRIS = 791950000)
# 2 RUE DE LA LAITERIE 79150 VAL EN VIGNES ===> 47.0046062,-0.3405564 (code IRIS = 790630000)
# 4 RUE DE LA LAITERIE 79150 VAL EN VIGNES ===> 47.0046062,-0.3405564 (code IRIS = 790630000)
# LE BOURG - MASSAIS 79150 VAL EN VIGNES ===> 47.00143725,-0.35794113893332846 (code IRIS = 790630000)
# LE BOIS NEUF 79320 MONCOUTANT-SUR-SEVRE ===> 46.722614,-0.6101716 (code IRIS = 791790000)
# 25 RTE DE LA CHAUVERIE MIAURAY 79260 ROMANS ===> 46.3647297,-0.2334344 (code IRIS = 792310000)
# 8 RUE DES SEPT PERRONS MONTIGNE 79370 CELLES-SUR-BELLE ===> 46.21463,-0.2387758 (code IRIS = 790610000)
# LA GRELIERE 79430 LA CHAPELLE-SAINT-LAURENT ===> , (code IRIS = 790760000)
# 40 RUE DES LAVANDIERES 79430 LA CHAPELLE-SAINT-LAURENT ===> 46.7419782,-0.4938048 (code IRIS = 790760000)
# LA LEONIERE 79290 VAL EN VIGNES ===> , (code IRIS = 790630000)
# 37 AV DU 25 AOUT 1944 79140 CERIZAY ===> , (code IRIS = 790620000)
# 5022  LA BOUTINIERE 79380 SAINT-ANDRE-SUR-SEVRE ===> , (code IRIS = 792360000)
# 7 SQ DE BELFORT 79400 ST MAIXENT L ECOLE ===> , (code IRIS = )
# LES GRANGES 79400 ST MAIXENT L ECOLE ===> , (code IRIS = )
# 2 CLOS DE LA GALINIERE 79370 FRESSINES ===> 46.3209382,-0.2949414 (code IRIS = 791290000)
# 56 RUE DES VIEILLES VIGNES 79190 SAUZE-VAUSSAIS ===> 46.1298336,0.115832 (code IRIS = 793070000)
# LE BOURG EST 79200 GOURGE ===> 49.3152287,4.2655935 (code IRIS = )
# 19 RUE DE LA COMMANDERIE 79200 GOURGE ===> 46.7265747,-0.1690083 (code IRIS = 791350000)
# 5001  BOIS VERT 79140 COMBRAND ===> 46.8813954,-0.7238405 (code IRIS = 790960000)
# RIPERE 79600 LOUIN ===> 46.7697487,-0.2377186 (code IRIS = 791560000)
# 5210  RIPERE 79600 LOUIN ===> 46.7697487,-0.2377186 (code IRIS = 791560000)
# BOIS DE L'ANGEVINIERE 79120 MESSE ===> , (code IRIS = 791770000)
# 5 IMP DU PETIT LAC 79120 MESSE ===> 46.2535649,0.0903852 (code IRIS = 791770000)
# LE PLESSIS GARREAU ETUSSON 79150 SAINT MAURICE ETUSSON ===> 47.0036422,-0.5227321 (code IRIS = 792800000)
# 1  LE PLESSIS GARREAU ETUSSON 79150 SAINT MAURICE ETUSSON ===> 47.0036422,-0.5227321 (code IRIS = 792800000)
# LES GROIES DE CHARZAY 79500 MELLE ===> , (code IRIS = 791740000)
# CHAMP DERRIERE LES VIGNES 79500 MELLE ===> , (code IRIS = 791740000)
#
#
# Etape : 28100
# 20:12:15
# Temps pour 100 : 72.03147602081299 sec
#
#
# LE PUY BOURRASSIER 79500 MELLE ===> 46.1736094,-0.1805596 (code IRIS = 791740000)
# 2 RTE DE ST JEAN D'ANGELY CHARZA 79500 MELLE ===> , (code IRIS = 791740000)
# 5121  PATRE SUD 79600 AVAILLES-THOUARSAIS ===> , (code IRIS = 790220000)
# 10 IMP GASPARD MONGE 79000 NIORT ===> 46.3096655,-0.4646122 (code IRIS = 791910302)
# 7  VENELLE MEDIANE 79000 NIORT ===> 46.3282677,-0.4525457814999999 (code IRIS = 791910201)
# 8  VENELLE DU LEVANT 79000 NIORT ===> 46.3282472,-0.4524622 (code IRIS = 791910201)
# 27 RUE DE SAINT ANDRE 79380 LA FORET-SUR-SEVRE ===> , (code IRIS = 791230000)
# 5596  LES TERRIERES 79400 SAIVRES ===> 46.4223962,-0.2132636 (code IRIS = 793020000)
# LA COURSAUDIERE OUEST 79340 VASLES ===> , (code IRIS = 793390000)
# 7000  LA COURSAUDIERE 79340 VASLES ===> 46.6069795,-0.051229 (code IRIS = 793390000)
# LES TERRES DE LA BERLIERE 79400 NANTEUIL ===> , (code IRIS = 791890000)
# 46 IMP BEL AIR 79230 AIFFRES ===> 46.3008972,-0.4240123 (code IRIS = 790030101)
# 6 RUE PIERRE DE RONSARD 79200 PARTHENAY ===> 46.637650199999996,-0.24954750408163612 (code IRIS = 792020104)
# RUE DE LA ROUTIERE 79000 NIORT ===> 46.3514413,-0.4720766 (code IRIS = 791910503)
# LA GRANDE PALOUBE 79270 LE VANNEAU-IRLEAU ===> 46.2935153,-0.6666631 (code IRIS = 793370000)
# 6 RUE STE SABINE 79270 LE VANNEAU-IRLEAU ===> 46.2993066,-0.6642952 (code IRIS = 793370000)
# 124 AV ST-JEAN D'ANGELY 79000 NIORT ===> , (code IRIS = 791910101)
# FAUGERIT 79340 VASLES ===> 46.6122798,-0.0304028 (code IRIS = 793390000)
# 4  FAUGERIT 79340 VASLES ===> 46.6122798,-0.0304028 (code IRIS = 793390000)
# 12 PL DE L'EGLISE 79200 LE TALLUD ===> 46.6295462,-0.2974877133002604 (code IRIS = 793220000)
# 9 RUE CHAURAY 79400 ST MAIXENT L ECOLE ===> , (code IRIS = )
# 32 RTE DE LA SCIERIE 79170 PERIGNE ===> 46.1932938,-0.2578647 (code IRIS = 792040000)
# 30 RTE DE LA SCIERIE 79170 PERIGNE ===> 46.1929413,-0.2559666 (code IRIS = 792040000)
# CHAMP BOUCHER 79170 PERIGNE ===> 46.1942806,-0.2565013 (code IRIS = 792040000)
# 7 IMP DES FIAUGES 79180 CHAURAY ===> 46.3565328,-0.3666874 (code IRIS = 790810102)
# 7 ALL DU CLOS DE RIBRAY 79000 NIORT ===> , (code IRIS = 791910101)
# 9 RUE MARIA CALLAS 79000 NIORT ===> 46.3501743,-0.4532721 (code IRIS = 791910601)
# 10 RUE JULES FERRY 79000 NIORT ===> 46.3310943,-0.4581888 (code IRIS = 791910202)
# 15 RUE JEAN PERRIN 79000 NIORT ===> 46.31501230000001,-0.4393380842017881 (code IRIS = 791910701)
# 17 RUE DE LA CITE JARDIN 79400 ST MAIXENT L ECOLE ===> , (code IRIS = )
# 20 RUE DES HERPINIERES 79370 AIGONDIGNE ===> 46.2977988,-0.2951406 (code IRIS = 791850000)
# LES MOULINS 79270 LA ROCHENARD ===> 46.2047509,-0.5838324 (code IRIS = 792290000)
# 65  GRANDE RUE 79270 LA ROCHENARD ===> 46.2037637,-0.5868022 (code IRIS = 792290000)
# 8 RUE DE LA SABLIERE 79600 SAINT-LOUP-LAMAIRE ===> 46.7902917,-0.1646048 (code IRIS = 792680000)
# RUE DE LA SABLIERE 79600 SAINT-LOUP-LAMAIRE ===> 46.7902917,-0.1646048 (code IRIS = 792680000)
# 12 RUE DE LA SABLIERE 79600 SAINT-LOUP-LAMAIRE ===> 46.7902917,-0.1646048 (code IRIS = 792680000)
# 16 RUE DE BRETAGNE 79600 AIRVAULT ===> 46.8269813,-0.1390907 (code IRIS = 790050000)
# 15 RUE BOILEAU 79100 THOUARS ===> 46.9781287,-0.2001655 (code IRIS = 793290101)
# 74 RUE DE PARTHENAY 79160 COULONGES-SUR-L AUTIZE ===> , (code IRIS = 791010000)
# 110 RUE DE LA PETITE GENESVE 79410 SAINT GELAIS ===> 46.3847585,-0.3943441 (code IRIS = 792490000)
# 105 IMP DU CERISIER 79230 JUSCORPS ===> 46.2044389,-0.3731382 (code IRIS = 791440000)
# BIAROUE 79230 JUSCORPS ===> 46.2047305,-0.3717326 (code IRIS = 791440000)
# 157 AV DE LIMOGES 79000 NIORT ===> 46.3183691,-0.4472464 (code IRIS = 791910604)
# RUE DE LA LAITERIE SOIGNON 79400 ST MARTIN DE ST MAIXENT ===> 46.3877819,-0.1872819 (code IRIS = 792760000)
# GR GRANDE RUE 79350 AMAILLOUX ===> 46.7459372,-0.3125457 (code IRIS = 790080000)
# 9 RUE DU PORTAIL 79340 VASLES ===> 46.5764653,-0.0206338 (code IRIS = 793390000)
# 6  LA TILLEROLLE 79200 POMPAIRE ===> 46.6231944,-0.2253571 (code IRIS = 792130000)
# 5 ALL DES LILAS 79230 PRAHECQ ===> 46.2618362,-0.3393216 (code IRIS = 792160000)
# 215 RTE DE CHIZE 79360 PLAINE-D'ARGENSON ===> 46.1521045,-0.4725401 (code IRIS = 790780000)
# LES GRANDS NOYERS 79360 PLAINE-D'ARGENSON ===> 46.1484643,-0.4594741 (code IRIS = 790780000)
# 6129  LA GRILIERE 79210 MAUZE-SUR-LE-MIGNON ===> , (code IRIS = 791700000)
# 6130  LA GRILIERE 79210 MAUZE-SUR-LE-MIGNON ===> , (code IRIS = 791700000)
# LA GRILIERE 79210 MAUZE-SUR-LE-MIGNON ===> , (code IRIS = 791700000)
# 84 RUE DE NIORT 79230 PRAHECQ ===> 46.2627707,-0.357802 (code IRIS = 792160000)
# 10 RUE DES LEVRIES 79230 VOUILLE ===> 46.3045627,-0.3349151 (code IRIS = 793550000)
# 20 RTE DU CLOS BARDIEN 79290 SAINT-MARTIN-DE-SANZAY ===> 47.0636982,-0.1990521 (code IRIS = 792770000)
# 47 RUE DU DOCTEUR BASSET 79100 SAINTE-VERGE ===> 47.0020889,-0.2159848 (code IRIS = 793000000)
# RUE DU DOCTEUR BASSET 79100 SAINTE-VERGE ===> 47.0006311,-0.2156623 (code IRIS = 793000000)
# 113 RUE DUGUESCLIN 79290 LORETZ-D ARGENTON ===> 47.0451526,-0.2595644 (code IRIS = 790140000)
# LE BOURG D'ARGENTON L'EGLI 79290 LORETZ-D ARGENTON ===> , (code IRIS = 790140000)
# 35 IMP DE CHEY 79000 NIORT ===> 46.3344533,-0.4946318 (code IRIS = 791910501)
# 7 ALL DU CLOS DE CHEY 79000 NIORT ===> , (code IRIS = 791910101)
# JUGE CORBIN 79000 NIORT ===> , (code IRIS = 791910101)
# 69 RUE SAINT-GELAIS 79000 NIORT ===> 46.3253172,-0.460401 (code IRIS = 791910101)
# 10 RUE DU DETOUR 79000 NIORT ===> 46.0788574,-0.1740025 (code IRIS = )
# 1 RUE BEAUCHAMP 79000 NIORT ===> 46.3275654,-0.4602813 (code IRIS = 791910101)
# 142 RTE DES DEUX GREVES 79460 MAGNE ===> 46.3109323,-0.543624 (code IRIS = 791620000)
# 90  GRAND'RUE 79410 ECHIRE ===> 46.3922629,-0.4166797 (code IRIS = 791090000)
# 5354  LA POUGE EST 79160 FENIOUX ===> , (code IRIS = 791190000)
# LA POUGE 79160 FENIOUX ===> 46.5371816,-0.5163972 (code IRIS = 791190000)
# 3 LOT DU CLOS BRIANT 79100 PLAINE-ET-VALLEES ===> , (code IRIS = )
# BAS FOLLET 79250 NUEIL-LES-AUBIERS ===> 46.9424262,-0.5888594 (code IRIS = 791950000)
# 21 AV EDMOND ROSTAND 79200 CHATILLON SUR THOUET ===> 46.66196995,-0.23435039124815382 (code IRIS = 790800000)
# LA PETITE PLAINE DE JADRE 79600 ASSAIS-LES-JUMEAUX ===> , (code IRIS = 790160000)
# LE GAUTIER 79600 ASSAIS-LES-JUMEAUX ===> 46.7867571,-0.036757 (code IRIS = 790160000)
# 5  LA CHAGNEE 79450 SAINT-AUBIN-LE-CLOUD ===> 46.6419271,-0.3484365 (code IRIS = 792390000)
# 3  LA CHAGNEE 79450 SAINT-AUBIN-LE-CLOUD ===> 46.6419271,-0.3484365 (code IRIS = 792390000)
# LA CHAGNEE 79450 SAINT-AUBIN-LE-CLOUD ===> 46.6419271,-0.3484365 (code IRIS = 792390000)
# 5751  LA CHAGNEE 79450 SAINT-AUBIN-LE-CLOUD ===> 46.6419271,-0.3484365 (code IRIS = 792390000)
# 5765  LA CHAGNEE 79450 SAINT-AUBIN-LE-CLOUD ===> 46.6419271,-0.3484365 (code IRIS = 792390000)
# RUE ERNEST PEROCHON 79290 LORETZ-D ARGENTON ===> 47.0420602,-0.2630953 (code IRIS = 790140000)
# 178 RUE PICHAULT DE LA MARTINIERE 79290 LORETZ-D ARGENTON ===> 47.044448,-0.2623572 (code IRIS = 790140000)
# L ARDONNIERE 79350 CHICHE ===> , (code IRIS = 790880000)
# 5000  L ARDONNIERE 79350 CHICHE ===> , (code IRIS = 790880000)
# 14 RUE DE LA PLANCHE ETUSSON 79150 SAINT MAURICE ETUSSON ===> 47.0159299,-0.5159537 (code IRIS = 792800000)
# 1  VERNOU 79200 GOURGE ===> , (code IRIS = 791350000)
# VERNOU 79200 GOURGE ===> , (code IRIS = 791350000)
# 25 RUE DU MOULIN BLANC 79800 LA MOTHE SAINT HERAY ===> 46.357108249999996,-0.1125098366524816 (code IRIS = 791840000)
# 291 AV DU MARAIS POITEVIN 79460 MAGNE ===> 46.3153588,-0.5493511 (code IRIS = 791620000)
# 38 RUE DES GRANDS CHAMPS 79000 NIORT ===> 46.3234973,-0.4852563 (code IRIS = 791910402)
# 18 RUE DES TULIPES 79200 VIENNAY ===> 46.6879093,-0.2481927 (code IRIS = 793470000)
# 16 CHE DU GRAND LAC 79290 SAINT-MARTIN-DE-SANZAY ===> 47.0806467,-0.1948169 (code IRIS = 792770000)
# 11 RUE SAINT MARTIN 79360 PLAINE-D'ARGENSON ===> 46.1121829,-0.4716436 (code IRIS = 790780000)
# LA METAIRIE DE NUEIL 79250 NUEIL-LES-AUBIERS ===> 46.9700532,-0.5717904 (code IRIS = 791950000)
# 52 RTE DE RORTHAIS 79250 NUEIL-LES-AUBIERS ===> , (code IRIS = 791950000)
# 4 IMP DU CHATEAU D'EAU 79360 LA FOYE MONJAULT ===> 46.1978419,-0.495455 (code IRIS = 791270000)
# 1 IMP DES JARDINS BREUIL 79150 ARGENTONNAY ===> 46.9915317,-0.4300779 (code IRIS = 790130000)
#
#
# Etape : 28200
# 20:13:19
# Temps pour 100 : 63.540873289108276 sec
#
#
# LE BOURG BREUIL S ARGENTON 79150 ARGENTONNAY ===> 46.988891,-0.4313514 (code IRIS = 790130000)
# BORDEVAIRE 79300 BRESSUIRE ===> 46.833583,-0.4663375 (code IRIS = 790490103)
# 165 BD DE POITIERS 79300 BRESSUIRE ===> 46.8394268,-0.4882835 (code IRIS = 790490102)
# LES CHAMPS DU BOIS ROBINEL 79600 AIRVAULT ===> , (code IRIS = 790050000)
# 36 RUE DU STADE 79600 BOUSSAIS ===> 46.8081116,-0.2767941 (code IRIS = 790470000)
# 53 RUE LOUISE MICHEL 79000 NIORT ===> 46.3361809,-0.4381175 (code IRIS = 791910603)
# 3 CHE DES OUCHETTES 79410 CHERVEUX ===> 46.4122171,-0.3613911 (code IRIS = 790860000)
# 6 RTE DE L'ARCEAU 79150 SAINT MAURICE ETUSSON ===> 47.0322238,-0.5039379 (code IRIS = 792800000)
# 140 RTE DES PUITS 79140 BRETIGNOLLES ===> 46.8657497,-0.5925782 (code IRIS = 790500000)
# D HOLLEAU 79150 VOULMENTIN ===> , (code IRIS = 792420000)
# FRANGEUSE 79150 VOULMENTIN ===> 46.938908,-0.5049166 (code IRIS = 792420000)
# PONT GROLLEAU 79150 VOULMENTIN ===> , (code IRIS = 792420000)
# 5058  FRANGEUSE 79150 VOULMENTIN ===> 46.938908,-0.5049166 (code IRIS = 792420000)
# 12 RUE DU TAILLIS 79140 CERIZAY ===> , (code IRIS = 790620000)
# 18 CHE DES OUCHETTES 79410 CHERVEUX ===> 46.4122171,-0.3613911 (code IRIS = 790860000)
# 24 BD EDGARD QUINET 79200 PARTHENAY ===> 46.6473101,-0.2380786780821919 (code IRIS = 792020105)
# 49 AV DE LIMOGES 79000 NIORT ===> 46.3212332,-0.4533154 (code IRIS = 791910102)
# 5334  LA SOTTERIE EST 79510 COULON ===> 46.316184,-0.6152183 (code IRIS = 791000000)
# 32 RTE DE CONTREMARCHE 79360 PLAINE-D'ARGENSON ===> 46.1564442,-0.5021888 (code IRIS = 790780000)
# 4 RUE DES CHATAIGNIERS LES TOUCH 79190 SAUZE-VAUSSAIS ===> , (code IRIS = 793070000)
# LA FOND DES TOUCHES 79190 SAUZE-VAUSSAIS ===> , (code IRIS = 793070000)
# LES TOUCHES 79190 SAUZE-VAUSSAIS ===> , (code IRIS = 793070000)
# 16 AV LOUIS PROUST 79110 CHEF-BOUTONNE ===> 46.1084629,-0.0803056 (code IRIS = 790830000)
# 62  LES AJONCS CHAP LARGEAU 79700 MAULEON ===> , (code IRIS = 790790101)
# LA CHIRONERIE CH LARGEAU 79700 MAULEON ===> 46.96033,-0.8801334 (code IRIS = 790790105)
# LE PETIT PRILLET 79290 LORETZ-D ARGENTON ===> , (code IRIS = 790140000)
# 18  GOUTTEVIVE 79300 BOISME ===> 46.7633204,-0.4643485 (code IRIS = 790380000)
# GOUTTEVIVE 79300 BOISME ===> 46.7633204,-0.4643485 (code IRIS = 790380000)
# 1 ALL DE GATINE 79310 VERRUYES ===> 46.5170498,-0.2954533 (code IRIS = 793450000)
# SAZAIS 79100 PLAINE-ET-VALLEES ===> 46.9221293,-0.033018 (code IRIS = 791960000)
# BEL AIR 79200 LE TALLUD ===> 46.6396161,-0.2724209 (code IRIS = 793220000)
# 96 RUE DES SELLIERS 79230 VOUILLE ===> 46.3245904,-0.3281427 (code IRIS = 793550000)
# 23 RUE DE PARTHENAY VILLAGE 79200 PARTHENAY ===> 46.483462,-0.5984461 (code IRIS = )
# CHAUME ELIE 79510 COULON ===> 46.3587833,-0.5564082 (code IRIS = 791000000)
# 54 RUE D AQUITAINE 79200 PARTHENAY ===> 46.6481266,-0.2472687 (code IRIS = 792020101)
# 1  LES HAUTES ROUSSELIERES 79130 ALLONNE ===> , (code IRIS = 790070000)
# 5197  LES HAUTES ROUSSELIERES 79130 ALLONNE ===> , (code IRIS = 790070000)
# LES HAUTES ROUSSELIERES 79130 ALLONNE ===> , (code IRIS = 790070000)
# 6 RUE DES GRIPPEAUX 79200 PARTHENAY ===> 46.638642,-0.2625027130032126 (code IRIS = 792020103)
# 3 RUE DE L'AUDIENCE 79400 ST MAIXENT L ECOLE ===> , (code IRIS = )
# LA BATONNIERE 79310 VOUHE ===> 46.5613068,-0.2604785 (code IRIS = 793540000)
# 5094  LA BATONNIERE 79310 VOUHE ===> 46.5613068,-0.2604785 (code IRIS = 793540000)
# 33 RUE DU PRIEURE 79130 ALLONNE ===> 46.5836765,-0.3810859 (code IRIS = 790070000)
# RUE DU PRIEURE 79130 ALLONNE ===> 46.5833722,-0.3817464 (code IRIS = 790070000)
# LA NIQUIERE 79510 COULON ===> 46.3273945,-0.5837077 (code IRIS = 791000000)
# 18 RTE DE BRESSUIRE 79160 COULONGES-SUR-L AUTIZE ===> , (code IRIS = 791010000)
# 29  GRAND RUE 79210 MAUZE-SUR-LE-MIGNON ===> 46.1961368,-0.6660884 (code IRIS = 791700000)
# 25  GRAND RUE 79210 MAUZE-SUR-LE-MIGNON ===> 46.1961368,-0.6660884 (code IRIS = 791700000)
# LES DANDILIERES 79240 SCILLE ===> , (code IRIS = 793090000)
# LA CRETINIERE 79240 SCILLE ===> , (code IRIS = 793090000)
# LES CHAMPS DE LA FOLIE 79240 SCILLE ===> , (code IRIS = 793090000)
# 2  LE PORTEAU 79340 VASLES ===> 46.6061265,-0.041968 (code IRIS = 793390000)
# LE SORLIOUME 79340 VASLES ===> , (code IRIS = 793390000)
# 8 ALL DES LILAS 79000 NIORT ===> 46.3211242,-0.4390845 (code IRIS = 791910604)

# %%
selec.head()

# %%
selec.shape

# %% [markdown]
# ## Export de la totalité de la sélection d'adresses après la fin du job

# %%
selec.to_csv('export_gps_iris_' + str(row_first) + "-" + str(row_last)+'.csv')
