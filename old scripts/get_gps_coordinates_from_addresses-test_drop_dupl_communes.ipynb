# %%
import warnings
from pandas.core.common import SettingWithCopyWarning
warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)

# %%
import pandas as pd
import numpy as np
from geopy.geocoders import Nominatim
import json
import requests
import time

# %%
# Renseigner ici la première ligne et la dernière ligne de la base adresses qui vont être utilisées
row_first = 979200
row_last = 1058649

# %%
# Chargement du jeu de données
df = pd.read_csv('valeursfoncieres-2020.txt',sep="|",decimal=",")
df.head()
#print(df.columns)
# Out:
# C:\Users\Charles\anaconda3\envs\CDV-perso\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (14,18,23,24,26,28,41) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    Code service CH  Reference document  1 Articles CGI  2 Articles CGI  \
# 0              NaN                 NaN             NaN             NaN
# 1              NaN                 NaN             NaN             NaN
# 2              NaN                 NaN             NaN             NaN
# 3              NaN                 NaN             NaN             NaN
# 4              NaN                 NaN             NaN             NaN
#
#    3 Articles CGI  4 Articles CGI  5 Articles CGI  No disposition  \
# 0             NaN             NaN             NaN               1
# 1             NaN             NaN             NaN               1
# 2             NaN             NaN             NaN               1
# 3             NaN             NaN             NaN               1
# 4             NaN             NaN             NaN               1
#
#   Date mutation Nature mutation  ...  Surface Carrez du 5eme lot  \
# 0    07/01/2020           Vente  ...                         NaN
# 1    02/01/2020           Vente  ...                         NaN
# 2    02/01/2020           Vente  ...                         NaN
# 3    02/01/2020           Vente  ...                         NaN
# 4    02/01/2020           Vente  ...                         NaN
#
#    Nombre de lots Code type local Type local Identifiant local  \
# 0               0             NaN        NaN               NaN
# 1               0             NaN        NaN               NaN
# 2               0             NaN        NaN               NaN
# 3               0             NaN        NaN               NaN
# 4               0             NaN        NaN               NaN
#
#   Surface reelle bati  Nombre pieces principales Nature culture  \
# 0                 NaN                        NaN              T
# 1                 NaN                        NaN             BT
# 2                 NaN                        NaN              T
# 3                 NaN                        NaN              T
# 4                 NaN                        NaN              T
#
#   Nature culture speciale  Surface terrain
# 0                     NaN           1061.0
# 1                     NaN             85.0
# 2                     NaN           1115.0
# 3                     NaN           1940.0
# 4                     NaN           1148.0
#
# [5 rows x 43 columns]

# %%
# focus on the address datas
ad = df[['No voie', 'Type de voie', 'Voie', 'Code postal','Commune']]
ad.shape
# Out:
# (2459560, 5)

# %%
ad.head()
# Out:
#    No voie Type de voie                    Voie  Code postal    Commune
# 0      NaN          NaN                FORTUNAT       1250.0  CEYZERIAT
# 1      NaN          NaN  TERRES DES CINQ SAULES       1290.0       LAIZ
# 2      NaN          NaN      BOIS DU CHAMP RION       1290.0       LAIZ
# 3      NaN          NaN             EN COROBERT       1290.0       LAIZ
# 4      NaN          NaN  TERRES DES CINQ SAULES       1290.0       LAIZ

# %%
# On supprime les adresses dupliquées pour éviter d'interroger les API plusieurs fois avec exactement la même adresse
ad = ad.drop_duplicates()
ad.shape
# Out:
# (1058649, 5)

# %%
# Sélection des adresses à partir de row_first et row_last définies plus haut
selec = ad.iloc[row_first:row_last, :]
selec.shape
# Out:
# (79449, 5)

# %%
selec.head(10)
# Out:
#          No voie Type de voie                Voie  Code postal  \
# 2225019     53.0           AV            GALLIENI      92400.0
# 2225021      2.0           AV  GEORGES CLEMENCEAU      92500.0
# 2225022     31.0          RUE         JEAN JAURES      92800.0
# 2225027      7.0          RUE             DIDEROT      92000.0
# 2225029      4.0          ALL         DES CHARMES      92500.0
# 2225038     83.0          RUE           DE VERDUN      92150.0
# 2225057     22.0          RUE            VOLTAIRE      92500.0
# 2225058     66.0          RUE            SEGOFFIN      92400.0
# 2225069     14.0          RUE    DE LA MELONNIERE      92500.0
# 2225072    243.0           BD         SAINT DENIS      92400.0
#
#                  Commune
# 2225019       COURBEVOIE
# 2225021  RUEIL-MALMAISON
# 2225022          PUTEAUX
# 2225027         NANTERRE
# 2225029  RUEIL-MALMAISON
# 2225038         SURESNES
# 2225057  RUEIL-MALMAISON
# 2225058       COURBEVOIE
# 2225069  RUEIL-MALMAISON
# 2225072       COURBEVOIE

# %%
# Traitement des codes postaux (transformés en INT sauf les NA)

selec['Code postal'] = selec['Code postal'].fillna(-1).astype(int).astype(str).replace('-1', np.nan)
selec.head()
# Out:
#          No voie Type de voie                Voie Code postal          Commune
# 2225019     53.0           AV            GALLIENI       92400       COURBEVOIE
# 2225021      2.0           AV  GEORGES CLEMENCEAU       92500  RUEIL-MALMAISON
# 2225022     31.0          RUE         JEAN JAURES       92800          PUTEAUX
# 2225027      7.0          RUE             DIDEROT       92000         NANTERRE
# 2225029      4.0          ALL         DES CHARMES       92500  RUEIL-MALMAISON

# %%
# On formate les adresses
# tools functions : nan values management
def escapeNan(row):
    val = str(row)
    if val == "nan":
        val = " "
    else:
        val = val.replace('.0','') # if from float values
        val = val + " "
    return val

# %%
# Création d'un champ "Ville" pour interroger les coordonnées GPS lorsque le champ Adresse ne donne rien
selec['Ville'] = selec['Code postal'] + " " + selec['Commune']
selec.head()
# Out:
#          No voie Type de voie                Voie Code postal  \
# 2225019     53.0           AV            GALLIENI       92400
# 2225021      2.0           AV  GEORGES CLEMENCEAU       92500
# 2225022     31.0          RUE         JEAN JAURES       92800
# 2225027      7.0          RUE             DIDEROT       92000
# 2225029      4.0          ALL         DES CHARMES       92500
#
#                  Commune                  Ville
# 2225019       COURBEVOIE       92400 COURBEVOIE
# 2225021  RUEIL-MALMAISON  92500 RUEIL-MALMAISON
# 2225022          PUTEAUX          92800 PUTEAUX
# 2225027         NANTERRE         92000 NANTERRE
# 2225029  RUEIL-MALMAISON  92500 RUEIL-MALMAISON

# %%
# Création du champ "addressName" qui sera utilisée dans la requête API
selec['Adresse'] = selec.apply(lambda row: 
    escapeNan(row['No voie'])
    + escapeNan(row['Type de voie'])         
    + escapeNan(row['Voie'])
    + escapeNan(row['Code postal']).zfill(5) # pour respecter le format des codes postaux
    + str(row['Commune'])
    , axis = 1).str.strip()

# %%
selec.head()
# Out:
#          No voie Type de voie                Voie Code postal  \
# 2225019     53.0           AV            GALLIENI       92400
# 2225021      2.0           AV  GEORGES CLEMENCEAU       92500
# 2225022     31.0          RUE         JEAN JAURES       92800
# 2225027      7.0          RUE             DIDEROT       92000
# 2225029      4.0          ALL         DES CHARMES       92500
#
#                  Commune                  Ville  \
# 2225019       COURBEVOIE       92400 COURBEVOIE
# 2225021  RUEIL-MALMAISON  92500 RUEIL-MALMAISON
# 2225022          PUTEAUX          92800 PUTEAUX
# 2225027         NANTERRE         92000 NANTERRE
# 2225029  RUEIL-MALMAISON  92500 RUEIL-MALMAISON
#
#                                                Adresse
# 2225019                53 AV GALLIENI 92400 COURBEVOIE
# 2225021  2 AV GEORGES CLEMENCEAU 92500 RUEIL-MALMAISON
# 2225022               31 RUE JEAN JAURES 92800 PUTEAUX
# 2225027                   7 RUE DIDEROT 92000 NANTERRE
# 2225029        4 ALL DES CHARMES 92500 RUEIL-MALMAISON

# %%
selec.iloc[0:200, :]
# Out:
#          No voie Type de voie                Voie Code postal  \
# 2225019     53.0           AV            GALLIENI       92400
# 2225021      2.0           AV  GEORGES CLEMENCEAU       92500
# 2225022     31.0          RUE         JEAN JAURES       92800
# 2225027      7.0          RUE             DIDEROT       92000
# 2225029      4.0          ALL         DES CHARMES       92500
# ...          ...          ...                 ...         ...
# 2225535     36.0           BD    DE LA REPUBLIQUE       92250
# 2225537      9.0           AV       MICHEL RICARD       92270
# 2225538      5.0           AV       MICHEL RICARD       92270
# 2225539     58.0           AV      DES GRESILLONS       92600
# 2225540     37.0           AV                FOCH       92250
#
#                      Commune                      Ville  \
# 2225019           COURBEVOIE           92400 COURBEVOIE
# 2225021      RUEIL-MALMAISON      92500 RUEIL-MALMAISON
# 2225022              PUTEAUX              92800 PUTEAUX
# 2225027             NANTERRE             92000 NANTERRE
# 2225029      RUEIL-MALMAISON      92500 RUEIL-MALMAISON
# ...                      ...                        ...
# 2225535  LA GARENNE-COLOMBES  92250 LA GARENNE-COLOMBES
# 2225537        BOIS-COLOMBES        92270 BOIS-COLOMBES
# 2225538        BOIS-COLOMBES        92270 BOIS-COLOMBES
# 2225539   ASNIERES-SUR-SEINE   92600 ASNIERES-SUR-SEINE
# 2225540  LA GARENNE-COLOMBES  92250 LA GARENNE-COLOMBES
#
#                                                   Adresse
# 2225019                   53 AV GALLIENI 92400 COURBEVOIE
# 2225021     2 AV GEORGES CLEMENCEAU 92500 RUEIL-MALMAISON
# 2225022                  31 RUE JEAN JAURES 92800 PUTEAUX
# 2225027                      7 RUE DIDEROT 92000 NANTERRE
# 2225029           4 ALL DES CHARMES 92500 RUEIL-MALMAISON
# ...                                                   ...
# 2225535  36 BD DE LA REPUBLIQUE 92250 LA GARENNE-COLOMBES
# 2225537            9 AV MICHEL RICARD 92270 BOIS-COLOMBES
# 2225538            5 AV MICHEL RICARD 92270 BOIS-COLOMBES
# 2225539     58 AV DES GRESILLONS 92600 ASNIERES-SUR-SEINE
# 2225540              37 AV FOCH 92250 LA GARENNE-COLOMBES
#
# [200 rows x 7 columns]

# %%
selec['Ville'] = selec['Ville'].replace('-', ' ', regex=True).astype(str)
selec.head()
# Out:
#          No voie Type de voie                Voie Code postal  \
# 2225019     53.0           AV            GALLIENI       92400
# 2225021      2.0           AV  GEORGES CLEMENCEAU       92500
# 2225022     31.0          RUE         JEAN JAURES       92800
# 2225027      7.0          RUE             DIDEROT       92000
# 2225029      4.0          ALL         DES CHARMES       92500
#
#                  Commune                  Ville  \
# 2225019       COURBEVOIE       92400 COURBEVOIE
# 2225021  RUEIL-MALMAISON  92500 RUEIL MALMAISON
# 2225022          PUTEAUX          92800 PUTEAUX
# 2225027         NANTERRE         92000 NANTERRE
# 2225029  RUEIL-MALMAISON  92500 RUEIL MALMAISON
#
#                                                Adresse
# 2225019                53 AV GALLIENI 92400 COURBEVOIE
# 2225021  2 AV GEORGES CLEMENCEAU 92500 RUEIL-MALMAISON
# 2225022               31 RUE JEAN JAURES 92800 PUTEAUX
# 2225027                   7 RUE DIDEROT 92000 NANTERRE
# 2225029        4 ALL DES CHARMES 92500 RUEIL-MALMAISON

# %%
# Instanciation de la BDD de correspondance entre Code Postal / Communes et Code INSEE (nécessaire pour code IRIS)
# La BDD se trouve ici : https://data.opendatasoft.com/explore/dataset/code-postal-code-insee-2015@public/download/?format=csv&timezone=Europe/Berlin&lang=fr&use_labels_for_header=true&csv_separator=%3B
communes = pd.read_csv('databases/code-postal-code-insee-2015.csv', sep = ";")
communes.head()
# Out:
#                       Geo Point  \
# 0  49.0097923668,0.696073334129
# 1  49.0521199676,0.412267826158
# 2  48.7896521776,0.276557382012
# 3  48.8470682746,0.643176111978
# 4  48.8662500091,0.559682765078
#
#                                            Geo Shape  CODE_COM INSEE_COM  \
# 0  {"type": "Polygon", "coordinates": [[[0.682900...        49     27049
# 1  {"type": "Polygon", "coordinates": [[[0.409543...       547     27547
# 2  {"type": "Polygon", "coordinates": [[[0.260047...       347     61347
# 3  {"type": "Polygon", "coordinates": [[[0.628763...       359     27359
# 4  {"type": "Polygon", "coordinates": [[[0.553791...       136     61136
#
#                      NOM_COM          STATUT  X_CENTROID  Y_CENTROID  Z_MOYEN  \
# 0                 BEAUMESNIL  Commune simple      531927     6881409      162
# 1  SAINT-GERMAIN-LA-CAMPAGNE  Commune simple      510734     6886673      176
# 2                  RESENLIEU  Commune simple      500194     6858135      231
# 3                 JUIGNETTES  Commune simple      527172     6863726      228
# 4                   COUVAINS  Commune simple      521103     6865598      236
#
#    SUPERFICIE  POPULATION  CODE_CANT  CODE_ARR CODE_DEPT NOM_DEPT  \
# 0        1264         562        2.0       2.0        27     EURE
# 1        2231         895        3.0       2.0        27     EURE
# 2         504         210       21.0       2.0        61     ORNE
# 3        1302         243        6.0       3.0        27     EURE
# 4        1788         167       18.0       2.0        61     ORNE
#
#    Code_postal             Nom_commune               coordonnees_gps  \
# 0      27330.0         MESNIL EN OUCHE  49.0090520551,0.696415474297
# 1      27230.0  ST GERMAIN LA CAMPAGNE  49.0522921876,0.412852228157
# 2      61230.0               RESENLIEU  48.7900887821,0.276930426076
# 3      27250.0              JUIGNETTES   48.8472706788,0.64345379282
# 4          NaN                     NaN                           NaN
#
#    Unnamed: 18
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
# On ne garde que les colonnes qui nous intéressent 
# (On a les coordonnees gps dedans, ce sera intéressant pour faire un check des coordonnees qu'on récupère plus bas)

communes = communes[['INSEE_COM', 'NOM_COM', 'Code_postal', 'Nom_commune', 'coordonnees_gps']]
communes = communes.rename(columns = {'NOM_COM': "Commune"})
communes.head()
# Out:
#   INSEE_COM                    Commune  Code_postal             Nom_commune  \
# 0     27049                 BEAUMESNIL      27330.0         MESNIL EN OUCHE
# 1     27547  SAINT-GERMAIN-LA-CAMPAGNE      27230.0  ST GERMAIN LA CAMPAGNE
# 2     61347                  RESENLIEU      61230.0               RESENLIEU
# 3     27359                 JUIGNETTES      27250.0              JUIGNETTES
# 4     61136                   COUVAINS          NaN                     NaN
#
#                 coordonnees_gps
# 0  49.0090520551,0.696415474297
# 1  49.0522921876,0.412852228157
# 2  48.7900887821,0.276930426076
# 3   48.8472706788,0.64345379282
# 4                           NaN

# %%
# Instanciation d'un dataframe communes_ville qui ne conserve que le code INSEE, les coordonnés, et la ville
communes_ville = communes
communes_ville['Code_postal'] = communes_ville['Code_postal'].fillna(-1).astype(int).astype(str).replace('-1', np.nan)
communes_ville['Ville'] = communes_ville['Code_postal'] + " " + communes_ville['Commune']
communes_ville['Ville'] = communes_ville['Ville'].where(-communes_ville['Code_postal'].isna(), communes_ville['Commune'])
communes_ville = communes_ville.drop(columns = {'Commune', 'Code_postal', 'Nom_commune'})
communes_ville['Ville'] = communes_ville['Ville'].replace('-', ' ', regex=True).astype(str)
communes_ville.head()
# Out:
#   INSEE_COM               coordonnees_gps                            Ville
# 0     27049  49.0090520551,0.696415474297                 27330 BEAUMESNIL
# 1     27547  49.0522921876,0.412852228157  27230 SAINT GERMAIN LA CAMPAGNE
# 2     61347  48.7900887821,0.276930426076                  61230 RESENLIEU
# 3     27359   48.8472706788,0.64345379282                 27250 JUIGNETTES
# 4     61136                           NaN                         COUVAINS

# %%
# Ajout du code commune INSEE au dataframe test
selec = selec.merge(communes_ville, on = "Ville", how = "left")
selec.head()
# Out:
#    No voie Type de voie                Voie Code postal          Commune  \
# 0     53.0           AV            GALLIENI       92400       COURBEVOIE
# 1      2.0           AV  GEORGES CLEMENCEAU       92500  RUEIL-MALMAISON
# 2     31.0          RUE         JEAN JAURES       92800          PUTEAUX
# 3      7.0          RUE             DIDEROT       92000         NANTERRE
# 4      4.0          ALL         DES CHARMES       92500  RUEIL-MALMAISON
#
#                    Ville                                        Adresse  \
# 0       92400 COURBEVOIE                53 AV GALLIENI 92400 COURBEVOIE
# 1  92500 RUEIL MALMAISON  2 AV GEORGES CLEMENCEAU 92500 RUEIL-MALMAISON
# 2          92800 PUTEAUX               31 RUE JEAN JAURES 92800 PUTEAUX
# 3         92000 NANTERRE                   7 RUE DIDEROT 92000 NANTERRE
# 4  92500 RUEIL MALMAISON        4 ALL DES CHARMES 92500 RUEIL-MALMAISON
#
#   INSEE_COM              coordonnees_gps
# 0     92026  48.8984504771,2.25570587289
# 1     92063   48.8691897371,2.1773406315
# 2     92062  48.8837094969,2.23834178314
# 3     92050  48.8960701282,2.20671346353
# 4     92063   48.8691897371,2.1773406315

# %%
selec['Commune_Lat'] = selec['coordonnees_gps'].str.split(",", expand = True)[0]
selec['Commune_Lon'] = selec['coordonnees_gps'].str.split(",", expand = True)[1]
selec = selec.drop(columns = {'coordonnees_gps'})
selec.head(15)
# Out:
#     No voie Type de voie                Voie Code postal          Commune  \
# 0      53.0           AV            GALLIENI       92400       COURBEVOIE
# 1       2.0           AV  GEORGES CLEMENCEAU       92500  RUEIL-MALMAISON
# 2      31.0          RUE         JEAN JAURES       92800          PUTEAUX
# 3       7.0          RUE             DIDEROT       92000         NANTERRE
# 4       4.0          ALL         DES CHARMES       92500  RUEIL-MALMAISON
# 5      83.0          RUE           DE VERDUN       92150         SURESNES
# 6      22.0          RUE            VOLTAIRE       92500  RUEIL-MALMAISON
# 7      66.0          RUE            SEGOFFIN       92400       COURBEVOIE
# 8      14.0          RUE    DE LA MELONNIERE       92500  RUEIL-MALMAISON
# 9     243.0           BD         SAINT DENIS       92400       COURBEVOIE
# 10      2.0           AV            MALVESIN       92400       COURBEVOIE
# 11      9.0          RUE    EDOUARD VAILLANT       92800          PUTEAUX
# 12     65.0           AV  PUVIS DE CHAVANNES       92400       COURBEVOIE
# 13      4.0           AV           ALEXANDRE       92000         NANTERRE
# 14     23.0           BD         DE LA SEINE       92000         NANTERRE
#
#                     Ville                                        Adresse  \
# 0        92400 COURBEVOIE                53 AV GALLIENI 92400 COURBEVOIE
# 1   92500 RUEIL MALMAISON  2 AV GEORGES CLEMENCEAU 92500 RUEIL-MALMAISON
# 2           92800 PUTEAUX               31 RUE JEAN JAURES 92800 PUTEAUX
# 3          92000 NANTERRE                   7 RUE DIDEROT 92000 NANTERRE
# 4   92500 RUEIL MALMAISON        4 ALL DES CHARMES 92500 RUEIL-MALMAISON
# 5          92150 SURESNES                83 RUE DE VERDUN 92150 SURESNES
# 6   92500 RUEIL MALMAISON          22 RUE VOLTAIRE 92500 RUEIL-MALMAISON
# 7        92400 COURBEVOIE               66 RUE SEGOFFIN 92400 COURBEVOIE
# 8   92500 RUEIL MALMAISON  14 RUE DE LA MELONNIERE 92500 RUEIL-MALMAISON
# 9        92400 COURBEVOIE            243 BD SAINT DENIS 92400 COURBEVOIE
# 10       92400 COURBEVOIE                 2 AV MALVESIN 92400 COURBEVOIE
# 11          92800 PUTEAUX           9 RUE EDOUARD VAILLANT 92800 PUTEAUX
# 12       92400 COURBEVOIE      65 AV PUVIS DE CHAVANNES 92400 COURBEVOIE
# 13         92000 NANTERRE                  4 AV ALEXANDRE 92000 NANTERRE
# 14         92000 NANTERRE               23 BD DE LA SEINE 92000 NANTERRE
#
#    INSEE_COM    Commune_Lat    Commune_Lon
# 0      92026  48.8984504771  2.25570587289
# 1      92063  48.8691897371   2.1773406315
# 2      92062  48.8837094969  2.23834178314
# 3      92050  48.8960701282  2.20671346353
# 4      92063  48.8691897371   2.1773406315
# 5      92073  48.8698479132  2.21965517625
# 6      92063  48.8691897371   2.1773406315
# 7      92026  48.8984504771  2.25570587289
# 8      92063  48.8691897371   2.1773406315
# 9      92026  48.8984504771  2.25570587289
# 10     92026  48.8984504771  2.25570587289
# 11     92062  48.8837094969  2.23834178314
# 12     92026  48.8984504771  2.25570587289
# 13     92050  48.8960701282  2.20671346353
# 14     92050  48.8960701282  2.20671346353

# %%
selec['code_iris'] = ""
selec['lon'] = ""
selec['lat'] = ""
selec.head()
# Out:
#    No voie Type de voie                Voie Code postal          Commune  \
# 0     53.0           AV            GALLIENI       92400       COURBEVOIE
# 1      2.0           AV  GEORGES CLEMENCEAU       92500  RUEIL-MALMAISON
# 2     31.0          RUE         JEAN JAURES       92800          PUTEAUX
# 3      7.0          RUE             DIDEROT       92000         NANTERRE
# 4      4.0          ALL         DES CHARMES       92500  RUEIL-MALMAISON
#
#                    Ville                                        Adresse  \
# 0       92400 COURBEVOIE                53 AV GALLIENI 92400 COURBEVOIE
# 1  92500 RUEIL MALMAISON  2 AV GEORGES CLEMENCEAU 92500 RUEIL-MALMAISON
# 2          92800 PUTEAUX               31 RUE JEAN JAURES 92800 PUTEAUX
# 3         92000 NANTERRE                   7 RUE DIDEROT 92000 NANTERRE
# 4  92500 RUEIL MALMAISON        4 ALL DES CHARMES 92500 RUEIL-MALMAISON
#
#   INSEE_COM    Commune_Lat    Commune_Lon code_iris lon lat
# 0     92026  48.8984504771  2.25570587289
# 1     92063  48.8691897371   2.1773406315
# 2     92062  48.8837094969  2.23834178314
# 3     92050  48.8960701282  2.20671346353
# 4     92063  48.8691897371   2.1773406315

# %%
selec.shape
# Out:
# (79449, 13)

# %%
# Get GPS Coordinates + IRIS Code from addresses

geolocator = Nominatim(user_agent="ImmoPy")

start = time.time()
etape = time.time()
print("Heure début : ")
print(time.strftime('%H:%M:%S', time.gmtime(start)))
print("\n")
n=0

for row in range(0, row_last - row_first):
    
    iris = ""
    longitude = ""
    latitude = ""
    
    adresse = selec['Adresse'][row]
    ville = selec['Ville'][row]
    code_INSEE = selec['INSEE_COM'][row]
    
    
    location = geolocator.geocode(adresse, country_codes = 'fr', timeout = 100) # On récup GPS from adresse
    
    if location is None: 
        location = geolocator.geocode(ville, country_codes = 'fr', timeout = 100) # Sinon on récup GPS from ville
        
    if location is None:                      # Sinon on prend les coordonnées GPS de la base INSEE Communes
        latitude = ""
        longitude = ""
    
    else:
        latitude = location.latitude
        longitude = location.longitude
        
        if isinstance(code_INSEE, float):     # Si pas de code commune
            print(adresse + ': pas de code commune INSEE')
            iris = ""
        elif latitude == "":               # Si pas de coordonnées GPS
            print(adresse + ": pas de coordonnees GPS")
            iris = ""
        else:                              # Sinon on interroge l'API du gouv pour récupérer le code IRIS
            result = requests.get('https://geo.api.gouv.fr/iris?lon=' + str(longitude) + '&lat=' 
                                  + str(latitude) + '&codeCommune=' + str(code_INSEE), timeout = 5)
            if result.ok == True:
                obj = json.loads(result.text)
                iris = obj['codeIris']
                #print(obj['codeIris'])
            else:
                result.close()
            print(adresse + " ===> " + str(latitude) + "," + str(longitude) + " (code IRIS = " + str(iris) + ")")
        
    selec['code_iris'][row] = iris
    selec['lon'][row] = longitude
    selec['lat'][row] = latitude
    
    n = n + 1
    
    if (n % 100 == 0):
        print("\n")
        print("Etape : " + str(n))
        print(time.strftime('%H:%M:%S', time.gmtime(time.time())))
        print("Temps pour 100 : " + str(time.time() - etape) + " sec")
        print("\n")
        etape = time.time()
        
    if (n % 10000 == 0):
        selec.iloc[(n - 10000) : n, :].to_csv(
            'export_gps_iris_' + str(row_first + n - 10000) + "-" + str(row_first + n)+'.csv')

        
end = time.time()
print("\n")
print("Heure fin : ")
print(time.strftime('%H:%M:%S', time.gmtime(end)))
print("\n")

print("Temps de calcul : ")
print(str(end - start) + ' sec')
# Out:
# Heure début :
# 06:20:27
#
#
# 53 AV GALLIENI 92400 COURBEVOIE ===> 48.9054446,2.2716728 (code IRIS = 920260303)
# 2 AV GEORGES CLEMENCEAU 92500 RUEIL-MALMAISON ===> 48.8791246,2.1796436 (code IRIS = 920630803)
# 31 RUE JEAN JAURES 92800 PUTEAUX ===> 48.8840483,2.2456132 (code IRIS = 920620403)
# 7 RUE DIDEROT 92000 NANTERRE ===> 48.8873277,2.2104218 (code IRIS = 920500509)
# 4 ALL DES CHARMES 92500 RUEIL-MALMAISON ===> 48.8669815,2.1971079 (code IRIS = 920630601)
# 83 RUE DE VERDUN 92150 SURESNES ===> 48.8738683,2.2300827 (code IRIS = 920730102)
# 22 RUE VOLTAIRE 92500 RUEIL-MALMAISON ===> 48.8765241,2.1981622 (code IRIS = 920630706)
# 66 RUE SEGOFFIN 92400 COURBEVOIE ===> 48.8958014,2.2462267 (code IRIS = 920260502)
# 14 RUE DE LA MELONNIERE 92500 RUEIL-MALMAISON ===> 48.8574016,2.1889702 (code IRIS = 920630503)
# 243 BD SAINT DENIS 92400 COURBEVOIE ===> 48.8966609,2.2599144 (code IRIS = 920260704)
# 2 AV MALVESIN 92400 COURBEVOIE ===> 48.9031001,2.2704882 (code IRIS = 920260304)
# 9 RUE EDOUARD VAILLANT 92800 PUTEAUX ===> 48.8860389,2.2430916 (code IRIS = 920620401)
# 65 AV PUVIS DE CHAVANNES 92400 COURBEVOIE ===> 48.89964,2.2375468 (code IRIS = 920260404)
# 4 AV ALEXANDRE 92000 NANTERRE ===> 48.8855518,2.2123895 (code IRIS = 920500102)
# 23 BD DE LA SEINE 92000 NANTERRE ===> 48.8960758,2.1963119 (code IRIS = 920500802)
# 14 RUE DU BICENTENAIRE 92800 PUTEAUX ===> 48.8811637,2.2350832 (code IRIS = 920620301)
# 2 RUE DE ZILINA 92000 NANTERRE ===> 48.8963801,2.1938715 (code IRIS = 920500803)
# 53 BD DU COUCHANT 92000 NANTERRE ===> 48.8948454,2.1951732 (code IRIS = 920500401)
# 60 RUE DE STRASBOURG 92400 COURBEVOIE ===> 48.8925776,2.2499513 (code IRIS = 920260505)
# 27 RUE DU BOIS ST PERE 92500 RUEIL-MALMAISON ===> 48.8632336,2.1681199 (code IRIS = 920630401)
# 82 RUE SEGOFFIN 92400 COURBEVOIE ===> 48.8964703,2.2478131 (code IRIS = 920260502)
# 5 RUE EDOUARD MANET 92500 RUEIL-MALMAISON ===> 48.8744871,2.1639889 (code IRIS = 920630301)
# 15 RUE VICTOR HUGO 92400 COURBEVOIE ===> 48.8927841,2.2546774 (code IRIS = 920260703)
# 30 RUE FABRE D EGLANTINE 92500 RUEIL-MALMAISON ===> 48.87778,2.1802832 (code IRIS = 920630803)
# 191 RUE DE VERDUN 92150 SURESNES ===> 48.8738683,2.2300827 (code IRIS = 920730102)
# 77 RUE DU TIR 92000 NANTERRE ===> 48.8826398,2.2184878 (code IRIS = 920500103)
# 46 RUE JP TIMBAUD 92400 COURBEVOIE ===> 48.8953328,2.2561602 (code IRIS = 920260702)
# 25 RTE FUSILLES RESISTANCE 92150 SURESNES ===> 48.8812809,2.2213354 (code IRIS = 920730113)
# 93 RTE FUSILLES RESISTANCE 92150 SURESNES ===> 48.8812809,2.2213354 (code IRIS = 920730113)
# 68 RUE DANIEL BECKER 92000 NANTERRE ===> 48.882972,2.2091557 (code IRIS = 920500101)
# 52 RUE JEAN JACQUES ROUSSEAU 92150 SURESNES ===> 48.8658567,2.2236801 (code IRIS = 920730114)
# 17 RUE DU SERGENT BOBILLOT 92000 NANTERRE ===> 48.8945265,2.200263 (code IRIS = 920500403)
# 5 RUE PAUL BERT 92000 NANTERRE ===> 48.8962509,2.2021441 (code IRIS = 920500403)
# 67 RUE DE LA SOURCE 92000 NANTERRE ===> 48.8866053,2.2054093 (code IRIS = 920500101)
# 7 RUE SILVY 92000 NANTERRE ===> 48.8941553,2.1952988 (code IRIS = 920500406)
# 17 RUE DU CHEMIN VERT 92400 COURBEVOIE ===> 48.9040553,2.2824352 (code IRIS = 920260305)
# 18 RUE EUGENE EICHENBERGER 92800 PUTEAUX ===> 48.8805106,2.2365134 (code IRIS = 920620302)
# 16 RUE PAUL GIMONT 92500 RUEIL-MALMAISON ===> 48.8661838,2.1959432 (code IRIS = 920630601)
# 67 RUE LAKANAL 92500 RUEIL-MALMAISON ===> 48.8693745,2.2066412 (code IRIS = 920630704)
# 63 RUE PIERRE BROSSOLETTE 92500 RUEIL-MALMAISON ===> 48.8833832,2.1856114 (code IRIS = 920630106)
# 6 PAS DU QUIGNON 92000 NANTERRE ===> 48.893571,2.1941885 (code IRIS = 920500401)
# 97 RUE DES SUISSES 92000 NANTERRE ===> 48.884207,2.1970974 (code IRIS = 920500206)
# 133 RUE DES VIGNES 92000 NANTERRE ===> 48.8846021,2.1970301 (code IRIS = 920500206)
# 109 AV DE LA REPUBLIQUE 92400 COURBEVOIE ===> 48.901544,2.2513919 (code IRIS = 920260102)
# 17 RUE EMILIEN COLIN 92150 SURESNES ===> 48.8795732,2.2230621 (code IRIS = 920730113)
# 2 ALL DE LA CASCADE 92500 RUEIL-MALMAISON ===> 48.867225000000005,2.1919998575748822 (code IRIS = 920630603)
# 11 RUE RIGAULT 92000 NANTERRE ===> 48.894029,2.1977573 (code IRIS = 920500401)
# 1 RUE DES LOUVETIERS 92000 NANTERRE ===> 48.8805673,2.2120122 (code IRIS = 920500103)
# 13 RUE DES FUSILLES 92800 PUTEAUX ===> 48.8841522,2.2368863 (code IRIS = 920620303)
# 67 RUE CRAMAIL 92500 RUEIL-MALMAISON ===> 48.882557,2.1731634 (code IRIS = 920630202)
# 59 RUE DE LA REPUBLIQUE 92800 PUTEAUX ===> 48.8863075,2.244093 (code IRIS = 920620401)
# 13 RUE DES RAGUIDELLES 92150 SURESNES ===> 48.8683128,2.2194426 (code IRIS = 920730104)
# 14 RUE MARTIGNON 92500 RUEIL-MALMAISON ===> 48.8849563,2.1793006 (code IRIS = 920630105)
# 67 RUE DES ALOUETTES 92000 NANTERRE ===> 48.8833422,2.2119892 (code IRIS = 920500103)
# 5 RUE LEON RAIMON 92000 NANTERRE ===> 48.8914506,2.1938712 (code IRIS = 920500401)
# 12 RUE MARCEL MONGE 92150 SURESNES ===> 48.8615736,2.222255 (code IRIS = 920730103)
# 11 RUE DE L'INDUSTRIE 92000 NANTERRE ===> 48.8987812,2.2023958 (code IRIS = 920500801)
# 59 RUE PASTEUR 92800 PUTEAUX ===> 48.8824631,2.2267497 (code IRIS = 920620205)
# 79 AV HOCHE 92000 NANTERRE ===> 48.9020704,2.1973238 (code IRIS = 920500802)
# 65 RUE ANDRE DOUCET 92000 NANTERRE ===> 48.9013111,2.1969949 (code IRIS = 920500802)
# 31 BD RICHARD WALLACE 92800 PUTEAUX ===> 48.8800035,2.2393636 (code IRIS = 920620302)
# 22 RUE KILFORD 92400 COURBEVOIE ===> 48.9010316,2.2535731 (code IRIS = 920260102)
# 91 RUE DES SUISSES 92000 NANTERRE ===> 48.8843568,2.1975291 (code IRIS = 920500206)
# 68 RUE DES OMBRAIES 92000 NANTERRE ===> 48.884336,2.2001266 (code IRIS = 920500206)
# 24 RUE THOMAS LEMAITRE 92000 NANTERRE ===> 48.8894993,2.1922827 (code IRIS = 920500302)
# 13 RUE DES SALLES 92400 COURBEVOIE ===> 48.8973624,2.2523822 (code IRIS = 920260601)
# 16 RUE PIERRE LHOMME 92400 COURBEVOIE ===> 48.8974272,2.2506777 (code IRIS = 920260601)
# 11 QUAI DU PRESIDENT PAUL DOUMER 92400 COURBEVOIE ===> 48.891004,2.2573897 (code IRIS = 920260705)
# 24 RUE VOLTA PROLONGEE 92400 COURBEVOIE ===> 48.9023037,2.2704233 (code IRIS = 920260203)
# 109 BD DE VERDUN 92400 COURBEVOIE ===> 48.9029942,2.2582228 (code IRIS = 920260103)
# 41 RUE LAVOISIER 92800 PUTEAUX ===> 48.8866057,2.2351124 (code IRIS = 920620201)
# 50 AV DU DIX HUIT JUIN 1940 92500 RUEIL-MALMAISON ===> 48.87778,2.1802832 (code IRIS = 920630803)
# RUE DES BOCHOUX 92150 SURESNES ===> 48.8809271,2.2222756 (code IRIS = 920730113)
# 106 AV DU DIX HUIT JUIN 1940 92500 RUEIL-MALMAISON ===> 48.87778,2.1802832 (code IRIS = 920630803)
# 157 AV FELIX FAURE 92800 PUTEAUX ===> 48.8842838,2.2186441 (code IRIS = 920620205)
# 5 RUE DES CHENES 92000 NANTERRE ===> 48.9100148,2.2171015 (code IRIS = 920500701)
# 29 BD HENRI SELLIER 92150 SURESNES ===> 48.8679347,2.2248773 (code IRIS = 920730114)
# 7 RUE LEROY 92150 SURESNES ===> 48.873229,2.2209514 (code IRIS = 920730106)
# 29 AV FRANKLIN ROOSEVELT 92150 SURESNES ===> 48.8755202,2.2180281 (code IRIS = 920730106)
# 41 AV DE SEINE 92500 RUEIL-MALMAISON ===> 48.8867927,2.1702997 (code IRIS = 920630102)
# 45 RUE VICTOR HUGO 92800 PUTEAUX ===> 48.8812883,2.2332425 (code IRIS = 920620301)
# 37 RUE CHARLES LORILLEUX 92800 PUTEAUX ===> 48.8855693,2.2345173 (code IRIS = 920620201)
# 28 AV LEONARD DE VINCI 92400 COURBEVOIE ===> 48.8967621,2.237486 (code IRIS = 920260406)
# 56 BD DE VERDUN 92400 COURBEVOIE ===> 48.9001954,2.2611696 (code IRIS = 920260201)
# 45 AV PUVIS DE CHAVANNES 92400 COURBEVOIE ===> 48.8993898,2.2364305 (code IRIS = 920260404)
# 9 RUE PAUL GIMONT 92500 RUEIL-MALMAISON ===> 48.865905,2.1970138 (code IRIS = 920630601)
# 24 AV MARCEAU 92400 COURBEVOIE ===> 48.89931285,2.2464174576362765 (code IRIS = 920260101)
# 18 RUE PIERRE CURIE 92800 PUTEAUX ===> 48.8839484,2.2241246 (code IRIS = 920620205)
# 14 RUE PERRONET 92150 SURESNES ===> 48.8719274,2.2261782 (code IRIS = 920730102)
# 89 RUE DES ALOUETTES 92000 NANTERRE ===> 48.8833422,2.2119892 (code IRIS = 920500103)
# 36 RUE JEAN JAURES 92800 PUTEAUX ===> 48.884525,2.2467482 (code IRIS = 920620403)
# 24 RUE ARAGO 92800 PUTEAUX ===> 48.884679,2.2461443 (code IRIS = 920620403)
# 33 AV PASTEUR 92400 COURBEVOIE ===> 48.9029221,2.2701141 (code IRIS = 920260203)
# 35 AV PASTEUR 92400 COURBEVOIE ===> 48.9029221,2.2701141 (code IRIS = 920260203)
# 20 RUE DES SALLES 92400 COURBEVOIE ===> 48.8973624,2.2523822 (code IRIS = 920260601)
# 1 RUE DE BRIENNE 92500 RUEIL-MALMAISON ===> 48.8596641,2.1865937 (code IRIS = 920630502)
# 54 AV PUVIS DE CHAVANNES 92400 COURBEVOIE ===> 48.8993146,2.2371535 (code IRIS = 920260406)
# 16 RUE DU GEN DE MIRIBEL 92500 RUEIL-MALMAISON ===> 48.87778,2.1802832 (code IRIS = 920630803)
# 3 RUE DE STRASBOURG 92600 ASNIERES-SUR-SEINE ===> 48.906622,2.2684623 (code IRIS = 920040105)
# 76 RUE SOLFERINO 92700 COLOMBES ===> 48.9300883,2.2609242 (code IRIS = 920250204)
#
#
# Etape : 100
# 06:21:20
# Temps pour 100 : 52.8574013710022 sec
#
#
# 23 RUE PAUL DEROULEDE 92270 BOIS-COLOMBES ===> 48.9130693,2.2703142 (code IRIS = 920090108)
# 21 RUE PAUL DEROULEDE 92270 BOIS-COLOMBES ===> 48.9130693,2.2703142 (code IRIS = 920090108)
# 50 RUE PIERRE JOIGNEAUX 92270 BOIS-COLOMBES ===> 48.9105852,2.2681378 (code IRIS = 920090110)
# 9 RUE PARMENTIER 92600 ASNIERES-SUR-SEINE ===> 48.9092405,2.2757751 (code IRIS = 920040102)
# 7 ALL DE L ILE MARANTE 92700 COLOMBES ===> 48.922788,2.2543577 (code IRIS = 920250106)
# 9 ALL DE L ILE MARANTE 92700 COLOMBES ===> 48.922788,2.2543577 (code IRIS = 920250106)
# 102 RUE PIERRE JOIGNEAUX 92270 BOIS-COLOMBES ===> 48.9105852,2.2681378 (code IRIS = 920090110)
# 10 AV FAIDHERBE 92600 ASNIERES-SUR-SEINE ===> 48.9097074,2.2724485 (code IRIS = 920040103)
# 33 BD GALLIENI 92390 VILLENEUVE-LA-GARENNE ===> 48.9355177,2.3329082 (code IRIS = 920780109)
# 21 RUE JEAN JAURES 92270 BOIS-COLOMBES ===> 48.9114251,2.2688435 (code IRIS = 920090110)
# 7 AV GAL LECLERC 92250 LA GARENNE-COLOMBES ===> 48.9069349,2.2465748 (code IRIS = 920350108)
# 20 AV DE VERDUN 92270 BOIS-COLOMBES ===> 48.9163533,2.2688243 (code IRIS = 920090107)
# 19 RUE DES BOURGUIGNONS 92270 BOIS-COLOMBES ===> 48.9122113,2.2721516 (code IRIS = 920090108)
# 7 AV DES ELECTRICIENS 92700 COLOMBES ===> 48.9198851,2.2473378 (code IRIS = 920250113)
# 9 PL DE LA LIBERTE 92250 LA GARENNE-COLOMBES ===> 48.9088179,2.2466486 (code IRIS = 920350105)
# 54 RUE PIERRE SEMART 92250 LA GARENNE-COLOMBES ===> 48.9069349,2.2465748 (code IRIS = 920350108)
# 39 RUE JEAN BONAL 92250 LA GARENNE-COLOMBES ===> 48.9067672,2.2500838 (code IRIS = 920350108)
# 82 RUE DU GENERAL LECLERC 92270 BOIS-COLOMBES ===> 48.914212,2.2712641 (code IRIS = 920090108)
# 101 RUE DU CHATEAU 92600 ASNIERES-SUR-SEINE ===> 48.9106147,2.2944707 (code IRIS = 920040401)
# 90 AV D ARGENTEUIL 92600 ASNIERES-SUR-SEINE ===> 48.9105948,2.2890454 (code IRIS = 920040305)
# 9 BD D ACHERES 92700 COLOMBES ===> 48.922788,2.2543577 (code IRIS = 920250106)
# 8 RUE DE PLAISANCE 92250 LA GARENNE-COLOMBES ===> 48.9104469,2.2505466 (code IRIS = 920350104)
# 44 RUE LEON BOURGEOIS 92700 COLOMBES ===> 48.9150126,2.2436509 (code IRIS = 920250111)
# 11 RUE DU HUIT MAI 1945 92250 LA GARENNE-COLOMBES ===> 48.9069349,2.2465748 (code IRIS = 920350108)
# 9 RUE PAUL BERT 92700 COLOMBES ===> 48.9262002,2.2471808 (code IRIS = 920250211)
# 42 RUE GODON 92700 COLOMBES ===> 48.9162649,2.2432592 (code IRIS = 920250111)
# 2 ALL EDOUARD MANET 92230 GENNEVILLIERS ===> 48.9340039,2.2923975 (code IRIS = 920360104)
# 4 ALL EDOUARD MANET 92230 GENNEVILLIERS ===> 48.9332398,2.2921961 (code IRIS = 920360104)
# 9 AV AUBENNE 92700 COLOMBES ===> 48.9108252,2.2333138 (code IRIS = 920250401)
# 73 BD CHARLES DE GAULLE 92700 COLOMBES ===> 48.9110647,2.2330798 (code IRIS = 920250401)
# 41 BD CHARLES DE GAULLE 92700 COLOMBES ===> 48.9090194,2.2367777 (code IRIS = 920250401)
# 15 AV PAUL HERBE 92390 VILLENEUVE-LA-GARENNE ===> 48.9402224,2.3273721 (code IRIS = 920780102)
# 35 RUE RASPAIL 92270 BOIS-COLOMBES ===> 48.9172203,2.2694105 (code IRIS = 920090106)
# 17 RUE AMBROISE PARE 92700 COLOMBES ===> 48.9235404,2.2471749 (code IRIS = 920250113)
# 4 SQ PAUL BERT 92600 ASNIERES-SUR-SEINE ===> 48.9104098,2.2726233593277785 (code IRIS = 920040103)
# 74 RUE VICTOR HUGO 92270 BOIS-COLOMBES ===> 48.9207784,2.2642954 (code IRIS = 920090106)
# 32 BD DE FINLANDE 92700 COLOMBES ===> 48.9317539,2.257031 (code IRIS = 920250205)
# 17 RUE DU GENERAL MANGIN 92600 ASNIERES-SUR-SEINE ===> 48.9090877,2.2885047 (code IRIS = 920040303)
# 18 AV DU PONANT 92390 VILLENEUVE-LA-GARENNE ===> 48.9434505,2.3292095 (code IRIS = 920780103)
# 21 AV DE LA REDOUTE 92600 ASNIERES-SUR-SEINE ===> 48.929928,2.2833987 (code IRIS = 920040601)
# 28 RUE DU CHALET 92600 ASNIERES-SUR-SEINE ===> 48.9140774,2.2755754 (code IRIS = 920040201)
# 22 RUE DU CHALET 92600 ASNIERES-SUR-SEINE ===> 48.9140774,2.2755754 (code IRIS = 920040201)
# 33 BD DE VALMY 92700 COLOMBES ===> 48.9248394,2.2527444 (code IRIS = 920250212)
# 68 RUE DE LA SABLIERE 92600 ASNIERES-SUR-SEINE ===> 48.9074334,2.2720197 (code IRIS = 920040103)
# 41 RUE ABBE LEMIRE 92600 ASNIERES-SUR-SEINE ===> 48.9105948,2.2890454 (code IRIS = 920040305)
# 153 QUAI AULAGNIER 92600 ASNIERES-SUR-SEINE ===> 48.918593,2.32101 (code IRIS = 920040502)
# 57 RUE DU GENERAL LECLERC 92270 BOIS-COLOMBES ===> 48.914212,2.2712641 (code IRIS = 920090108)
# 61 RUE VEUVE LACROIX 92250 LA GARENNE-COLOMBES ===> 48.9043339,2.2353194 (code IRIS = 920350102)
# 2 IMP JEAN MOULIN 92390 VILLENEUVE-LA-GARENNE ===> 48.9350488,2.3324727 (code IRIS = 920780110)
# 12 IMP JEAN MOULIN 92390 VILLENEUVE-LA-GARENNE ===> 48.9350488,2.3324727 (code IRIS = 920780110)
# 21 RUE GALLIENI 92600 ASNIERES-SUR-SEINE ===> 48.9094414,2.2864802 (code IRIS = 920040403)
# 53 BD VOLTAIRE 92600 ASNIERES-SUR-SEINE ===> 48.915708,2.2917854 (code IRIS = 920040302)
# 4 AV FLACHAT 92600 ASNIERES-SUR-SEINE ===> 48.906551,2.2810923 (code IRIS = 920040102)
# 139 RUE VICTOR HUGO 92270 BOIS-COLOMBES ===> 48.9207784,2.2642954 (code IRIS = 920090106)
# 55 BD GALLIENI 92390 VILLENEUVE-LA-GARENNE ===> 48.9355177,2.3329082 (code IRIS = 920780109)
# 37 RUE PARMENTIER 92600 ASNIERES-SUR-SEINE ===> 48.9092405,2.2757751 (code IRIS = 920040102)
# 131 RUE COLBERT 92700 COLOMBES ===> 48.9156059,2.2325393 (code IRIS = 920250403)
# 60 BD VOLTAIRE 92600 ASNIERES-SUR-SEINE ===> 48.9150177,2.2942867 (code IRIS = 920040501)
# 11 RUE DE NORMANDIE 92600 ASNIERES-SUR-SEINE ===> 48.9053273,2.2857104 (code IRIS = 920040402)
# 39 RUE ABBE LEMIRE 92600 ASNIERES-SUR-SEINE ===> 48.9105948,2.2890454 (code IRIS = 920040305)
# 34 RUE ANDRE CHENIER 92270 BOIS-COLOMBES ===> 48.9239198,2.2707246 (code IRIS = 920090102)
# 5 AV DE LA MARNE 92600 ASNIERES-SUR-SEINE ===> 48.9100019,2.2880016 (code IRIS = 920040303)
# 121 AV HENRI BARBUSSE 92700 COLOMBES ===> 48.9141829,2.252951 (code IRIS = 920250109)
# 1 RUE JEAN DUSSOURD 92600 ASNIERES-SUR-SEINE ===> 48.9079008,2.2902562 (code IRIS = 920040401)
# 71 BD DE LA REPUBLIQUE 92250 LA GARENNE-COLOMBES ===> 48.9068185,2.2449687 (code IRIS = 920350109)
# 80 RUE SARTORIS 92250 LA GARENNE-COLOMBES ===> 48.9067624,2.2430803 (code IRIS = 920350109)
# 4 AV DE LA MARNE 92600 ASNIERES-SUR-SEINE ===> 48.9046168,2.2791745 (code IRIS = 920040101)
# 76 RUE SARTORIS 92250 LA GARENNE-COLOMBES ===> 48.9070581,2.2442968 (code IRIS = 920350105)
# 3 RUE DES BLEUETS 92250 LA GARENNE-COLOMBES ===> 48.9023181,2.2331694 (code IRIS = 920350102)
# 14 RUE MARQUET 92700 COLOMBES ===> 48.9181859,2.2561323 (code IRIS = 920250105)
# 66 AV JEAN MOULIN 92390 VILLENEUVE-LA-GARENNE ===> 48.94073305,2.329641227444575 (code IRIS = 920780102)
# 103 RUE HOCHE 92700 COLOMBES ===> 48.9220425,2.2653408 (code IRIS = 920250104)
# 21 RUE VICTOR HUGO 92700 COLOMBES ===> 48.9235287,2.259766 (code IRIS = 920250104)
# 75 BD CHARLES DE GAULLE 92700 COLOMBES ===> 48.9090194,2.2367777 (code IRIS = 920250401)
# 11 RUE DE LA CERISAIE 92700 COLOMBES ===> 48.911443,2.231451 (code IRIS = 920250401)
# 45 AV DE LA REDOUTE 92600 ASNIERES-SUR-SEINE ===> 48.929928,2.2833987 (code IRIS = 920040601)
# 37 AV DE LA REDOUTE 92600 ASNIERES-SUR-SEINE ===> 48.929928,2.2833987 (code IRIS = 920040601)
# 11 RUE DANIEL 92600 ASNIERES-SUR-SEINE ===> 48.9131958,2.2980302 (code IRIS = 920040503)
# 109 AV GAL LECLERC 92250 LA GARENNE-COLOMBES ===> 48.9069349,2.2465748 (code IRIS = 920350108)
# 26 RUE DES BOURGUIGNONS 92600 ASNIERES-SUR-SEINE ===> 48.9121579,2.2724017 (code IRIS = 920040102)
# 17 RUE PAUL BERT 92600 ASNIERES-SUR-SEINE ===> 48.9098956,2.2738825 (code IRIS = 920040102)
# 1 RUE RENAN 92600 ASNIERES-SUR-SEINE ===> 48.9151725,2.2942346 (code IRIS = 920040501)
# 18 RUE HELOISE MICHAUD 92230 GENNEVILLIERS ===> 48.9155571,2.2975101 (code IRIS = 920360402)
# 12 RUE DU R P CH GILBERT 92600 ASNIERES-SUR-SEINE ===> 48.9105948,2.2890454 (code IRIS = 920040305)
# 23 RUE DE BRETAGNE 92600 ASNIERES-SUR-SEINE ===> 48.9055732,2.2824943 (code IRIS = 920040101)
# 29 RUE DE LA GAIETE 92700 COLOMBES ===> 48.9259571,2.2656066 (code IRIS = 920250103)
# 221 AV D ARGENTEUIL 92270 BOIS-COLOMBES ===> 48.9148269,2.2674892 (code IRIS = 920090109)
# 10 RUE GEORGES GUYNEMER 92600 ASNIERES-SUR-SEINE ===> 48.915502,2.2906834 (code IRIS = 920040302)
# 15 RUE ROBERT DUPONT 92600 ASNIERES-SUR-SEINE ===> 48.9216754,2.2843378 (code IRIS = 920040604)
# 1 RUE CLAUDE MIVIERE 92270 BOIS-COLOMBES ===> 48.9219072,2.2724462 (code IRIS = 920090102)
# 23 RUE DE L AIGLE 92250 LA GARENNE-COLOMBES ===> 48.9069349,2.2465748 (code IRIS = 920350108)
# RUE DE L AIGLE 92250 LA GARENNE-COLOMBES ===> 48.9069349,2.2465748 (code IRIS = 920350108)
# 7 RUE DES BAS 92600 ASNIERES-SUR-SEINE ===> 48.9154742,2.295023 (code IRIS = 920040501)
# 87 RUE ROBERT SCHUMANN 92700 COLOMBES ===> 48.922788,2.2543577 (code IRIS = 920250106)
# 9 RUE LEONARD DE VINCI 92230 GENNEVILLIERS ===> 48.9338118,2.2890827 (code IRIS = 920360101)
# 36 BD DE LA REPUBLIQUE 92250 LA GARENNE-COLOMBES ===> 48.9068185,2.2449687 (code IRIS = 920350109)
# 9 AV MICHEL RICARD 92270 BOIS-COLOMBES ===> 48.9053581,2.2647507 (code IRIS = 920090112)
# 5 AV MICHEL RICARD 92270 BOIS-COLOMBES ===> 48.9053581,2.2647507 (code IRIS = 920090112)
# 58 AV DES GRESILLONS 92600 ASNIERES-SUR-SEINE ===> 48.9126768,2.2964255 (code IRIS = 920040503)
# 37 AV FOCH 92250 LA GARENNE-COLOMBES ===> 48.9083291,2.2428327 (code IRIS = 920350103)
#
#
# Etape : 200
# 06:22:19
# Temps pour 100 : 58.49335026741028 sec
#
#
# 104 RUE FELIX FAURE 92700 COLOMBES ===> 48.914778,2.2550965 (code IRIS = 920250109)
# 48 AV CLAUDE DEBUSSY 92230 GENNEVILLIERS ===> 48.927542,2.297534 (code IRIS = 920360502)
# 27 RUE BAPST 92600 ASNIERES-SUR-SEINE ===> 48.9093039,2.2871058 (code IRIS = 920040303)
# 1 AV SAINT JOSEPH 92600 ASNIERES-SUR-SEINE ===> 48.9238323,2.2778048 (code IRIS = 920040707)
# 282 AV D ARGENTEUIL 92600 ASNIERES-SUR-SEINE ===> 48.9105948,2.2890454 (code IRIS = 920040305)
# 25 RUE ANDRE CAYRON 92600 ASNIERES-SUR-SEINE ===> 48.91587,2.2795667 (code IRIS = 920040202)
# 30 RUE GUERLAIN 92700 COLOMBES ===> 48.9269883,2.261703 (code IRIS = 920250102)
# 28 RUE GUERLAIN 92700 COLOMBES ===> 48.9269883,2.261703 (code IRIS = 920250102)
# 32 RUE GUERLAIN 92700 COLOMBES ===> 48.9269883,2.261703 (code IRIS = 920250102)
# 37 RUE DES CHAMPARONS 92700 COLOMBES ===> 48.9260005,2.2631277 (code IRIS = 920250103)
# 6 RUE DU R P CH GILBERT 92600 ASNIERES-SUR-SEINE ===> 48.9105948,2.2890454 (code IRIS = 920040305)
# 25 RUE D ANJOU 92600 ASNIERES-SUR-SEINE ===> 48.9105948,2.2890454 (code IRIS = 920040305)
# 196 AV D ARGENTEUIL 92600 ASNIERES-SUR-SEINE ===> 48.9105948,2.2890454 (code IRIS = 920040305)
# 4 RUE JEANNE D ARC 92250 LA GARENNE-COLOMBES ===> 48.9069349,2.2465748 (code IRIS = 920350108)
# 63 RUE PIERRE JOIGNEAUX 92600 ASNIERES-SUR-SEINE ===> 48.9105852,2.2681378 (code IRIS = 920040104)
# 7 RUE STE SOPHIE 92600 ASNIERES-SUR-SEINE ===> 48.9168392,2.2836772 (code IRIS = 920040301)
# 9 RUE EDOUARD MANET 92600 ASNIERES-SUR-SEINE ===> 48.9162798,2.2902812 (code IRIS = 920040604)
# 2 RUE DE L EGLISE 92600 ASNIERES-SUR-SEINE ===> 48.9105948,2.2890454 (code IRIS = 920040305)
# 133 RUE DU MARECHAL JOFFRE 92700 COLOMBES ===> 48.9220523,2.2527975 (code IRIS = 920250107)
# 31 AV JEAN MOULIN 92390 VILLENEUVE-LA-GARENNE ===> 48.9374488,2.3319582 (code IRIS = 920780102)
# 34 RUE PAUL DEROULEDE 92270 BOIS-COLOMBES ===> 48.9130693,2.2703142 (code IRIS = 920090108)
# 50 AV FLACHAT 92600 ASNIERES-SUR-SEINE ===> 48.9079652,2.2788906 (code IRIS = 920040102)
# 6 RUE DU MAINE 92600 ASNIERES-SUR-SEINE ===> 48.9040547,2.2835147 (code IRIS = 920040101)
# 48 RUE BRASSAT 92700 COLOMBES ===> 48.9177654,2.2462131 (code IRIS = 920250304)
# 20 RUE LOUISE 92600 ASNIERES-SUR-SEINE ===> 48.9171734,2.2945697 (code IRIS = 920040501)
# 245 RUE DU MENIL 92600 ASNIERES-SUR-SEINE ===> 48.9187945,2.2864046 (code IRIS = 920040604)
# 59 AV DE LA MARNE 92600 ASNIERES-SUR-SEINE ===> 48.9081283,2.2840317 (code IRIS = 920040403)
# 42 RUE CHARLES CHEFSON 92270 BOIS-COLOMBES ===> 48.9196088,2.272069 (code IRIS = 920090106)
# 104 AV HENRI BARBUSSE 92700 COLOMBES ===> 48.9164897,2.2526065 (code IRIS = 920250109)
# 41 AV D ARGENTEUIL 92600 ASNIERES-SUR-SEINE ===> 48.9105948,2.2890454 (code IRIS = 920040305)
# 44 BD VOLTAIRE 92600 ASNIERES-SUR-SEINE ===> 48.915708,2.2917854 (code IRIS = 920040302)
# 0000 LA GARENNE COLOMBES: pas de code commune INSEE
# 44 RUE DE L EGALITE 92700 COLOMBES ===> 48.922788,2.2543577 (code IRIS = 920250106)
# 16 AV HENRI BARBUSSE 92700 COLOMBES ===> 48.9215558,2.2525315 (code IRIS = 920250113)
# 32 RUE GEORGES THORETTON 92230 GENNEVILLIERS ===> 48.926409,2.298121 (code IRIS = 920360502)
# 340 RUE D'ESTIENNE D'ORVES 92700 COLOMBES ===> 48.9110649,2.2360788 (code IRIS = 920250401)
# 273 RUE SAINT DENIS 92700 COLOMBES ===> 48.924087,2.2519733 (code IRIS = 920250113)
# 34 RUE GUERLAIN 92700 COLOMBES ===> 48.9269883,2.261703 (code IRIS = 920250102)
# 24 RUE CHARLES DUPORT 92270 BOIS-COLOMBES ===> 48.912699,2.2597736 (code IRIS = 920090111)
# 79 RUE DE VARSOVIE 92700 COLOMBES ===> 48.9146798,2.2493078 (code IRIS = 920250110)
# 17 RUE GERALDY 92270 BOIS-COLOMBES ===> 48.9164338,2.2651804 (code IRIS = 920090109)
# 17 RUE D ESTIENNE D ORVES 92250 LA GARENNE-COLOMBES ===> 48.9069349,2.2465748 (code IRIS = 920350108)
# 7 RUE SAINT DENIS 92700 COLOMBES ===> 48.924087,2.2519733 (code IRIS = 920250113)
# 16 RUE DE CHATEAUDUN 92250 LA GARENNE-COLOMBES ===> 48.9098076,2.245695 (code IRIS = 920350103)
# 10 RUE DES VALLEES 92700 COLOMBES ===> 48.9153056,2.2577893 (code IRIS = 920250108)
# 1 AV JOSEPH FROMENT 92250 LA GARENNE-COLOMBES ===> 48.9123207,2.2565761 (code IRIS = 920350112)
# 7 RUE DU CONTRAT SOCIAL 92600 ASNIERES-SUR-SEINE ===> 48.9147035,2.2902079 (code IRIS = 920040304)
# 104 RUE DU MENIL 92600 ASNIERES-SUR-SEINE ===> 48.9187945,2.2864046 (code IRIS = 920040604)
# 49 AV D ARGENTEUIL 92600 ASNIERES-SUR-SEINE ===> 48.9105948,2.2890454 (code IRIS = 920040305)
# 51 RUE JEAN BONAL 92250 LA GARENNE-COLOMBES ===> 48.9061222,2.2473909 (code IRIS = 920350108)
# 81 RUE DU BAC 92600 ASNIERES-SUR-SEINE ===> 48.9125268,2.2794294 (code IRIS = 920040201)
# 9001 RUE ANDRE DEVEZE 92600 ASNIERES-SUR-SEINE ===> 48.9265158,2.2783791 (code IRIS = 920040707)
# 9 AV ETIENNE AUBERT 92700 COLOMBES ===> 48.916248,2.2454726 (code IRIS = 920250111)
# 22 RUE COLBERT 92700 COLOMBES ===> 48.910522,2.2371883 (code IRIS = 920250306)
# 79 RUE MEDERIC 92250 LA GARENNE-COLOMBES ===> 48.9098819,2.2428426 (code IRIS = 920350103)
# 14 RUE JULES DUMIEN 92230 GENNEVILLIERS ===> 48.9310301,2.3055893 (code IRIS = 920360503)
# 4 RUE DES BRUYERES 92600 ASNIERES-SUR-SEINE ===> 48.9097614,2.2668954 (code IRIS = 920040104)
# 23 RUE ROBERT DUPONT 92600 ASNIERES-SUR-SEINE ===> 48.9216754,2.2843378 (code IRIS = 920040604)
# 29 RUE DES COLLINES 92230 GENNEVILLIERS ===> 48.930511,2.2989086 (code IRIS = 920360502)
# 2 RUE LAURE FIOT 92600 ASNIERES-SUR-SEINE ===> 48.9156512,2.2836451 (code IRIS = 920040301)
# 74 RUE DU GENERAL LECLERC 92270 BOIS-COLOMBES ===> 48.914212,2.2712641 (code IRIS = 920090108)
# 274 RUE D'ESTIENNE D'ORVES 92700 COLOMBES ===> 48.9126291,2.2389247 (code IRIS = 920250306)
# 4 RUE RAPHAEL 92600 ASNIERES-SUR-SEINE ===> 48.906664,2.2672384 (code IRIS = 920040104)
# 13 RUE D'ESTIENNE D'ORVES 92700 COLOMBES ===> 48.9218688,2.2488445 (code IRIS = 920250113)
# 10 AV FLACHAT 92600 ASNIERES-SUR-SEINE ===> 48.9079652,2.2788906 (code IRIS = 920040102)
# 9 RUE EUGENIE CARMIGNAT 92270 BOIS-COLOMBES ===> 48.9253608,2.2733674 (code IRIS = 920090101)
# 24 RUE DE LA REINE HENRIETTE 92700 COLOMBES ===> 48.9251991,2.2492767 (code IRIS = 920250211)
# 52 AV FLACHAT 92600 ASNIERES-SUR-SEINE ===> 48.9079652,2.2788906 (code IRIS = 920040102)
# 5 RUE DE L EGLISE 92600 ASNIERES-SUR-SEINE ===> 48.9105948,2.2890454 (code IRIS = 920040305)
# 17 RUE DES LILAS 92700 COLOMBES ===> 48.9161139,2.2596057 (code IRIS = 920250108)
# 11 RUE GRAMME 92270 BOIS-COLOMBES ===> 48.9241365,2.2715762 (code IRIS = 920090102)
# 7 RUE MOSLARD 92700 COLOMBES ===> 48.9166157,2.2378351 (code IRIS = 920250302)
# 12 RUE DE L AMIRAL COURBET 92270 BOIS-COLOMBES ===> 48.9148269,2.2674892 (code IRIS = 920090109)
# 77 RUE YOURI GAGARINE 92700 COLOMBES ===> 48.9253151,2.2434921 (code IRIS = 920250209)
# 1 AV DE LA GARE 92230 GENNEVILLIERS ===> 48.9336183,2.297945 (code IRIS = 920360503)
# 42 RUE ALEXIS BOUVIER 92700 COLOMBES ===> 48.930102,2.2560835 (code IRIS = 920250206)
# 124 RUE PIERRE JOIGNEAUX 92270 BOIS-COLOMBES ===> 48.9105852,2.2681378 (code IRIS = 920090110)
# 12 RUE CHARLES DUPORT 92270 BOIS-COLOMBES ===> 48.912699,2.2597736 (code IRIS = 920090111)
# 18 AV CHEVREUL 92600 ASNIERES-SUR-SEINE ===> 48.9062418,2.2665255 (code IRIS = 920040104)
# 10 RUE ANDRE CAYRON 92600 ASNIERES-SUR-SEINE ===> 48.91587,2.2795667 (code IRIS = 920040202)
# 156 BD GALLIENI 92390 VILLENEUVE-LA-GARENNE ===> 48.9355177,2.3329082 (code IRIS = 920780109)
# 154 BD GALLIENI 92390 VILLENEUVE-LA-GARENNE ===> 48.9355177,2.3329082 (code IRIS = 920780109)
# 72 RUE SAINT DENIS 92700 COLOMBES ===> 48.924087,2.2519733 (code IRIS = 920250113)
# 25 RUE BASLY 92230 GENNEVILLIERS ===> 48.919318,2.2941949 (code IRIS = 920360302)
# 6 RUE JOSEPH LECLAINCHE 92230 GENNEVILLIERS ===> 48.931090499999996,2.2938792133185455 (code IRIS = 920360204)
# 20 AV DE VERDUN 1916 92250 LA GARENNE-COLOMBES ===> 48.9053796,2.2348182 (code IRIS = 920350101)
# 6 RUE DE SOTTEVILLE 92250 LA GARENNE-COLOMBES ===> 48.905818,2.2338187 (code IRIS = 920350101)
# 4 RUE PIERRE BROSSOLETTE 92250 LA GARENNE-COLOMBES ===> 48.9031703,2.2512073 (code IRIS = 920350110)
# 63 RUE VEUVE LACROIX 92250 LA GARENNE-COLOMBES ===> 48.9043339,2.2353194 (code IRIS = 920350102)
# 22 AV D ARGENTEUIL 92600 ASNIERES-SUR-SEINE ===> 48.9105948,2.2890454 (code IRIS = 920040305)
# 14 RUE RAYMOND RIDEL 92250 LA GARENNE-COLOMBES ===> 48.9039744,2.2497469 (code IRIS = 920350110)
# 12 RUE RAYMOND RIDEL 92250 LA GARENNE-COLOMBES ===> 48.9039744,2.2497469 (code IRIS = 920350110)
# 10 PAS LORNE 92600 ASNIERES-SUR-SEINE ===> 48.9190026,2.2844587 (code IRIS = 920040604)
# 18 ALL MARTIN GAUDIN 92230 GENNEVILLIERS ===> 48.9249446,2.3009947 (code IRIS = 920360503)
# 12 RUE JULES DUMIEN 92230 GENNEVILLIERS ===> 48.9310301,2.3055893 (code IRIS = 920360503)
# 13 RUE VILLEBOIS MAREUIL 92230 GENNEVILLIERS ===> 48.934751,2.2946472 (code IRIS = 920360503)
# 3 AV DES PEUPLIERS 92270 BOIS-COLOMBES ===> 48.9128079,2.2587823 (code IRIS = 920090112)
# 9 RUE GUSTAVE REY 92250 LA GARENNE-COLOMBES ===> 48.9125763,2.2550491 (code IRIS = 920350106)
# 17 RUE DU CHATEAU 92250 LA GARENNE-COLOMBES ===> 48.9047824,2.249132 (code IRIS = 920350108)
# 62 RUE DE PLAISANCE 92250 LA GARENNE-COLOMBES ===> 48.9104469,2.2505466 (code IRIS = 920350104)
#
#
# Etape : 300
# 06:23:15
# Temps pour 100 : 56.4850959777832 sec
#
#
# 29 RUE JEAN JAURES 92230 GENNEVILLIERS ===> 48.93057875,2.295301606852068 (code IRIS = 920360504)
# 8 RUE DU QUATORZE JUILLET 92270 BOIS-COLOMBES ===> 48.9148269,2.2674892 (code IRIS = 920090109)
# 21 RUE YVES LE CAIGNARD 92250 LA GARENNE-COLOMBES ===> 48.9084909,2.2371066 (code IRIS = 920350101)
# 23 RUE BAPST 92600 ASNIERES-SUR-SEINE ===> 48.9093039,2.2871058 (code IRIS = 920040303)
# 1 RUE CHARLES CHEFSON 92270 BOIS-COLOMBES ===> 48.9196088,2.272069 (code IRIS = 920090106)
# 25 RUE LUCIEN JEANNIN 92250 LA GARENNE-COLOMBES ===> 48.9054768,2.2413489 (code IRIS = 920350109)
# 1 RUE EMILE DELSOL 92250 LA GARENNE-COLOMBES ===> 48.9097248,2.241007 (code IRIS = 920350103)
# 7 RUE DES VALLEES 92700 COLOMBES ===> 48.9153056,2.2577893 (code IRIS = 920250108)
# 14 AV AUDRA 92700 COLOMBES ===> 48.9280269,2.2506425 (code IRIS = 920250211)
# 39 RUE DIDEROT 92600 ASNIERES-SUR-SEINE ===> 48.9145368,2.2928891 (code IRIS = 920040304)
# 6 RUE CHARLES DUFLOS 92270 BOIS-COLOMBES ===> 48.9143808,2.2684633 (code IRIS = 920090109)
# 16 RUE JEAN DUSSOURD 92600 ASNIERES-SUR-SEINE ===> 48.9079008,2.2902562 (code IRIS = 920040401)
# 8 RUE GUSTAVE CAILLEBOTTE 92600 ASNIERES-SUR-SEINE ===> 48.9182659,2.2935579394452996 (code IRIS = 920040501)
# 93 RUE DE COLOMBES 92600 ASNIERES-SUR-SEINE ===> 48.9121744,2.2856861 (code IRIS = 920040305)
# 62 RUE DU BAC 92600 ASNIERES-SUR-SEINE ===> 48.9125268,2.2794294 (code IRIS = 920040201)
# 2 AV DU MANOIR 92600 ASNIERES-SUR-SEINE ===> 48.9113251,2.2757192 (code IRIS = 920040201)
# 79 BD CHARLES DE GAULLE 92700 COLOMBES ===> 48.9090194,2.2367777 (code IRIS = 920250401)
# 25 RUE SELLIER 92700 COLOMBES ===> 48.9278534,2.2616214 (code IRIS = 920250102)
# 118 AV DE STALINGRAD 92700 COLOMBES ===> 48.9358372,2.2605574 (code IRIS = 920250205)
# 21 RUE JULIEN GALLE 92700 COLOMBES ===> 48.9231202,2.2585315 (code IRIS = 920250106)
# 8 RUE ANTONIN 92230 GENNEVILLIERS ===> 48.914016,2.2974361 (code IRIS = 920360402)
# 25 AV JOSEPH FROMENT 92250 LA GARENNE-COLOMBES ===> 48.9123207,2.2565761 (code IRIS = 920350112)
# 10 AV DE VERDUN 92270 BOIS-COLOMBES ===> 48.9163533,2.2688243 (code IRIS = 920090107)
# 4 RUE DE LA PAIX 92270 BOIS-COLOMBES ===> 48.9157277,2.2733828 (code IRIS = 920090105)
# 4 RUE BERNARD JUGAULT 92600 ASNIERES-SUR-SEINE ===> 48.9089938,2.284729 (code IRIS = 920040403)
# 11 RUE LAPLACE 92700 COLOMBES ===> 48.9175837,2.2389399 (code IRIS = 920250304)
# 4 RUE SADI CARNOT 92600 ASNIERES-SUR-SEINE ===> 48.9097511,2.2898377 (code IRIS = 920040303)
# 28 RUE CHARLES CHEFSON 92270 BOIS-COLOMBES ===> 48.9196088,2.272069 (code IRIS = 920090106)
# 44 AV CHEVREUL 92600 ASNIERES-SUR-SEINE ===> 48.9059797,2.2681529 (code IRIS = 920040104)
# 8 RUE BAPST 92600 ASNIERES-SUR-SEINE ===> 48.9093039,2.2871058 (code IRIS = 920040303)
# 12 RUE BAPST 92600 ASNIERES-SUR-SEINE ===> 48.9093039,2.2871058 (code IRIS = 920040303)
# 56 BD DE VALMY 92700 COLOMBES ===> 48.9248394,2.2527444 (code IRIS = 920250212)
# 38 RUE JULES FERRY 92250 LA GARENNE-COLOMBES ===> 48.9027164,2.2338354 (code IRIS = 920350102)
# 46 AV DU PONANT 92390 VILLENEUVE-LA-GARENNE ===> 48.9434505,2.3292095 (code IRIS = 920780103)
# 50 AV DU PONANT 92390 VILLENEUVE-LA-GARENNE ===> 48.9434505,2.3292095 (code IRIS = 920780103)
# 6 RUE D ALSACE 92600 ASNIERES-SUR-SEINE ===> 48.9105948,2.2890454 (code IRIS = 920040305)
# 95 RUE VICTOR HUGO 92700 COLOMBES ===> 48.9235287,2.259766 (code IRIS = 920250104)
# 15 RUE AUGUSTINE GUIGNEDOUX 92230 GENNEVILLIERS ===> 48.9151929,2.2976696 (code IRIS = 920360402)
# 45 RUE DE NANTERRE 92600 ASNIERES-SUR-SEINE ===> 48.9100111,2.284741 (code IRIS = 920040203)
# 59 RUE DU GENERAL LECLERC 92270 BOIS-COLOMBES ===> 48.914212,2.2712641 (code IRIS = 920090108)
# 8 AV DE L AGENT SARRE 92700 COLOMBES ===> 48.922788,2.2543577 (code IRIS = 920250106)
# 124 AV DE STALINGRAD 92700 COLOMBES ===> 48.9358372,2.2605574 (code IRIS = 920250205)
# 5 MAIL CAMILLE DU GAST 92600 ASNIERES-SUR-SEINE ===> 48.917569099999994,2.3168590346178046 (code IRIS = 920040502)
# 9 MAIL CAMILLE DU GAST 92600 ASNIERES-SUR-SEINE ===> 48.917718,2.3168028 (code IRIS = 920040502)
# 30 RUE LEHOT 92600 ASNIERES-SUR-SEINE ===> 48.9158508,2.2816727 (code IRIS = 920040202)
# 33 AV FAIDHERBE 92600 ASNIERES-SUR-SEINE ===> 48.9097074,2.2724485 (code IRIS = 920040103)
# 212 AV D ARGENTEUIL 92600 ASNIERES-SUR-SEINE ===> 48.9105948,2.2890454 (code IRIS = 920040305)
# 6 RUE NOVION 92600 ASNIERES-SUR-SEINE ===> 48.9150477,2.3017958 (code IRIS = 920040502)
# 37 RUE GEORGES GUYNEMER 92600 ASNIERES-SUR-SEINE ===> 48.915502,2.2906834 (code IRIS = 920040302)
# 97 BD VOLTAIRE 92600 ASNIERES-SUR-SEINE ===> 48.915708,2.2917854 (code IRIS = 920040302)
# 34 RUE DES CHAMPARONS 92700 COLOMBES ===> 48.9260005,2.2631277 (code IRIS = 920250103)
# 90 RUE CHEVREUL 92230 GENNEVILLIERS ===> 48.9311353,2.2932847 (code IRIS = 920360204)
# 25 PL HENRI NEVEU 92700 COLOMBES ===> 48.92246565,2.255081044547927 (code IRIS = 920250106)
# 8 AV GABRIEL 92700 COLOMBES ===> 48.9194198,2.2534666 (code IRIS = 920250105)
# 26 RUE MAURICE RAVEL 92230 GENNEVILLIERS ===> 48.9330586,2.2925431 (code IRIS = 920360104)
# 30 RUE MAURICE RAVEL 92230 GENNEVILLIERS ===> 48.9330586,2.2925431 (code IRIS = 920360104)
# 153 RUE JULES FERRY 92700 COLOMBES ===> 48.9220346,2.2359041 (code IRIS = 920250303)
# 11 AV LESAGE 92700 COLOMBES ===> 48.9204932,2.231888 (code IRIS = 920250302)
# 5 RUE ROBERT LAVERGNE 92600 ASNIERES-SUR-SEINE ===> 48.9278473,2.2745319 (code IRIS = 920040704)
# 4 AV D ORGEMONT 92600 ASNIERES-SUR-SEINE ===> 48.9105948,2.2890454 (code IRIS = 920040305)
# 101 RUE HOCHE 92700 COLOMBES ===> 48.9220425,2.2653408 (code IRIS = 920250104)
# 57 RUE DE L AGRICULTURE 92700 COLOMBES ===> 48.922788,2.2543577 (code IRIS = 920250106)
# 35 RUE HOCHE 92700 COLOMBES ===> 48.9220425,2.2653408 (code IRIS = 920250104)
# 35 RUE DE L AIGLE 92250 LA GARENNE-COLOMBES ===> 48.9069349,2.2465748 (code IRIS = 920350108)
# 14 AV DE CHARLEBOURG 92250 LA GARENNE-COLOMBES ===> 48.904805,2.2416496 (code IRIS = 920350109)
# 2 RUE DU DOCTEUR ROUX 92700 COLOMBES ===> 48.9149803,2.2316022 (code IRIS = 920250403)
# 28 ALL DU MOULIN JOLY 92700 COLOMBES ===> 48.9124813,2.2462727 (code IRIS = 920250110)
# 2 RUE MARIA MONTESSORI 92600 ASNIERES-SUR-SEINE ===> 48.9190306,2.3156934 (code IRIS = 920040502)
# 17 RUE OLYMPE DE GOUGES 92600 ASNIERES-SUR-SEINE ===> 48.9186377,2.317746 (code IRIS = 920040502)
# 10 BD D ACHERES 92700 COLOMBES ===> 48.922788,2.2543577 (code IRIS = 920250106)
# 59 AV D ARGENTEUIL 92600 ASNIERES-SUR-SEINE ===> 48.9105948,2.2890454 (code IRIS = 920040305)
# 44 RUE MAURICE BOKANOWSKI 92600 ASNIERES-SUR-SEINE ===> 48.9072494,2.2860856 (code IRIS = 920040402)
# RUE DES COTES D AUTY 92700 COLOMBES ===> 48.922788,2.2543577 (code IRIS = 920250106)
# 78 RUE DES COTES D AUTY 92700 COLOMBES ===> 48.922788,2.2543577 (code IRIS = 920250106)
# 6 RUE ANDRE CAYRON 92600 ASNIERES-SUR-SEINE ===> 48.91587,2.2795667 (code IRIS = 920040202)
# 11 RUE FOSSE AUX ASTRES 92390 VILLENEUVE-LA-GARENNE ===> 48.9378124,2.3326555 (code IRIS = 920780109)
# 20 AV JEAN MOULIN 92390 VILLENEUVE-LA-GARENNE ===> 48.9374488,2.3319582 (code IRIS = 920780102)
# 36 AV JEAN MOULIN 92390 VILLENEUVE-LA-GARENNE ===> 48.9374488,2.3319582 (code IRIS = 920780102)
# 0000 COLOMBES: pas de code commune INSEE
# 1 QUAI AULAGNIER 92600 ASNIERES-SUR-SEINE ===> 48.9121555,2.3009799 (code IRIS = 920040504)
# 30 AV DE L'EUROPE 92270 BOIS-COLOMBES ===> 48.907379,2.2655906 (code IRIS = 920090112)
# 23 RUE DU CAPITAINE GUYNEMER 92270 BOIS-COLOMBES ===> 48.9076982,2.2626663 (code IRIS = 920090112)
# 422 RUE GABRIEL PERI 92700 COLOMBES ===> 48.9156311,2.2319354 (code IRIS = 920250403)
# AV GABRIEL PERI 92230 GENNEVILLIERS ===> 48.9266405,2.2946262 (code IRIS = 920360303)
# 14 AV MENELOTTE 92700 COLOMBES ===> 48.9239998,2.2595198 (code IRIS = 920250101)
# 74 RUE MEDERIC 92250 LA GARENNE-COLOMBES ===> 48.9098819,2.2428426 (code IRIS = 920350103)
# 28 RUE GALLIENI 92600 ASNIERES-SUR-SEINE ===> 48.9094414,2.2864802 (code IRIS = 920040403)
# 1 RUE DES TILLEULS 92600 ASNIERES-SUR-SEINE ===> 48.9080617,2.2677013 (code IRIS = 920040104)
# 185 BD VOLTAIRE 92600 ASNIERES-SUR-SEINE ===> 48.91852155,2.282194359801763 (code IRIS = 920040302)
# 2 MAIL CAMILLE DU GAST 92600 ASNIERES-SUR-SEINE ===> 48.9180292,2.3168366 (code IRIS = 920040502)
# 27 AV DU PONANT 92390 VILLENEUVE-LA-GARENNE ===> 48.9434505,2.3292095 (code IRIS = 920780103)
# 2 RUE DE CHAMPAGNE 92600 ASNIERES-SUR-SEINE ===> 48.9087228,2.2666612 (code IRIS = 920040104)
# 1 RUE PIERRE JOIGNEAUX 92600 ASNIERES-SUR-SEINE ===> 48.9105852,2.2681378 (code IRIS = 920040104)
# 9 RUE MEDERIC 92250 LA GARENNE-COLOMBES ===> 48.9098819,2.2428426 (code IRIS = 920350103)
# 11 RUE MEDERIC 92250 LA GARENNE-COLOMBES ===> 48.9098819,2.2428426 (code IRIS = 920350103)
# 82 RUE DU BAC 92600 ASNIERES-SUR-SEINE ===> 48.9125268,2.2794294 (code IRIS = 920040201)
# 49 RUE DU MENIL 92600 ASNIERES-SUR-SEINE ===> 48.9187945,2.2864046 (code IRIS = 920040604)
# 51 RUE DU MENIL 92600 ASNIERES-SUR-SEINE ===> 48.9187945,2.2864046 (code IRIS = 920040604)
# 72 AV DE LA MARNE 92600 ASNIERES-SUR-SEINE ===> 48.9092939,2.2860282 (code IRIS = 920040403)
# 78 AV DU GAL DE GAULLE 92250 LA GARENNE-COLOMBES ===> 48.9069349,2.2465748 (code IRIS = 920350108)
#
#
# Etape : 400
# 06:24:12
# Temps pour 100 : 56.49139904975891 sec
#
#
# 3 RUE DE L UNION 92230 GENNEVILLIERS ===> 48.9254221,2.2940122 (code IRIS = 920360303)
# 5 RUE JULES LAROSE 92230 GENNEVILLIERS ===> 48.9327793,2.3014312 (code IRIS = 920360503)
# 3 VLA ST THIBAULT 92270 BOIS-COLOMBES ===> 48.9148269,2.2674892 (code IRIS = 920090109)
# 5 VLA ST THIBAULT 92270 BOIS-COLOMBES ===> 48.9148269,2.2674892 (code IRIS = 920090109)
# 4 RUE EDMOND ROSTAND 92700 COLOMBES ===> 48.9232392,2.2360556 (code IRIS = 920250303)
# 21 RUE GEORGES 92250 LA GARENNE-COLOMBES ===> 48.906007,2.250773 (code IRIS = 920350108)
# 125 RUE DE L AGRICULTURE 92700 COLOMBES ===> 48.922788,2.2543577 (code IRIS = 920250106)
# 48 RUE CUGNET 92700 COLOMBES ===> 48.9113312,2.2338527 (code IRIS = 920250401)
# 158 RUE GABRIEL PERI 92700 COLOMBES ===> 48.9196161,2.241889 (code IRIS = 920250304)
# 43 RUE MEDERIC 92250 LA GARENNE-COLOMBES ===> 48.9098819,2.2428426 (code IRIS = 920350103)
# 56 RUE DES ECOLES 92700 COLOMBES ===> 48.9267394,2.2672172 (code IRIS = 920250102)
# 38 RUE DU FOND DE LA NOUE 92390 VILLENEUVE-LA-GARENNE ===> 48.9322128,2.3307956 (code IRIS = 920780107)
# 38 RUE VILLEBOIS MAREUIL 92230 GENNEVILLIERS ===> 48.9350787,2.298456 (code IRIS = 920360503)
# 5 RUE KLEBER 92250 LA GARENNE-COLOMBES ===> 48.9057587,2.2395575 (code IRIS = 920350109)
# 11 RUE ADOLPHE BRIFFAULT 92600 ASNIERES-SUR-SEINE ===> 48.9247029,2.2841124 (code IRIS = 920040601)
# 3 RUE DU PUITS GUYON 92230 GENNEVILLIERS ===> 48.9253461,2.2960177 (code IRIS = 920360502)
# 4 RUE BAYARD 92700 COLOMBES ===> 48.9214101,2.2512647 (code IRIS = 920250113)
# 2 RUE BAYARD 92700 COLOMBES ===> 48.9214064,2.2513666 (code IRIS = 920250113)
# 212 BD GALLIENI 92390 VILLENEUVE-LA-GARENNE ===> 48.9355177,2.3329082 (code IRIS = 920780109)
# 35 RUE AUGUSTE BUISSON 92250 LA GARENNE-COLOMBES ===> 48.9092903,2.2533983 (code IRIS = 920350111)
# 7 RUE VOISIN 92600 ASNIERES-SUR-SEINE ===> 48.9188849,2.2952835 (code IRIS = 920040501)
# 160 RUE DES GROS GRES 92700 COLOMBES ===> 48.914118,2.2333271 (code IRIS = 920250403)
# 209 RUE DU MENIL 92600 ASNIERES-SUR-SEINE ===> 48.9187945,2.2864046 (code IRIS = 920040604)
# 15 RUE DUCHESNAY 92600 ASNIERES-SUR-SEINE ===> 48.910268,2.2912033 (code IRIS = 920040303)
# 25 RUE FELIX FAURE 92700 COLOMBES ===> 48.914778,2.2550965 (code IRIS = 920250109)
# 25 RUE HALPHEN 92700 COLOMBES ===> 48.9209499,2.2507882 (code IRIS = 920250113)
# 155 RUE DU MENIL 92600 ASNIERES-SUR-SEINE ===> 48.9187945,2.2864046 (code IRIS = 920040604)
# 7 RUE GEORGES JANIN 92600 ASNIERES-SUR-SEINE ===> 48.9133992,2.2952031 (code IRIS = 920040501)
# 1 AV DE LA REDOUTE 92600 ASNIERES-SUR-SEINE ===> 48.929928,2.2833987 (code IRIS = 920040601)
# 1 RUE DUSSAU 92600 ASNIERES-SUR-SEINE ===> 48.9154242,2.2936387 (code IRIS = 920040501)
# 66 BD VOLTAIRE 92600 ASNIERES-SUR-SEINE ===> 48.915708,2.2917854 (code IRIS = 920040302)
# 13 RUE DUCHESNAY 92600 ASNIERES-SUR-SEINE ===> 48.910268,2.2912033 (code IRIS = 920040303)
# 83 RUE JULES MICHELET 92700 COLOMBES ===> 48.9320631,2.2693152 (code IRIS = 920250202)
# 77 RUE JULES MICHELET 92700 COLOMBES ===> 48.9320631,2.2693152 (code IRIS = 920250202)
# 3 AV DES BAINS 92600 ASNIERES-SUR-SEINE ===> 48.9134916,2.2744636 (code IRIS = 920040201)
# 102 RUE SARTORIS 92250 LA GARENNE-COLOMBES ===> 48.9060106,2.2399931 (code IRIS = 920350109)
# 5 RUE DU CHALET 92600 ASNIERES-SUR-SEINE ===> 48.9140774,2.2755754 (code IRIS = 920040201)
# 21 RUE MORTINAT 92600 ASNIERES-SUR-SEINE ===> 48.9189059,2.2817204 (code IRIS = 920040604)
# 68 RUE PIERRE BROSSOLETTE 92700 COLOMBES ===> 48.909083,2.2370849 (code IRIS = 920250401)
# 107 AV GAL LECLERC 92250 LA GARENNE-COLOMBES ===> 48.9069349,2.2465748 (code IRIS = 920350108)
# 130 AV DU GAL DE GAULLE 92250 LA GARENNE-COLOMBES ===> 48.9069349,2.2465748 (code IRIS = 920350108)
# 2 AV PINEL 92600 ASNIERES-SUR-SEINE ===> 48.9079513,2.2839373 (code IRIS = 920040404)
# 35 RUE PASTEUR 92250 LA GARENNE-COLOMBES ===> 48.9049137,2.2384956 (code IRIS = 920350102)
# 52 AV DU GAL DE GAULLE 92250 LA GARENNE-COLOMBES ===> 48.9069349,2.2465748 (code IRIS = 920350108)
# 96 RUE HENRI LITOLFF 92270 BOIS-COLOMBES ===> 48.9148269,2.2674892 (code IRIS = 920090109)
# 54 AV CHEVREUL 92600 ASNIERES-SUR-SEINE ===> 48.9059797,2.2681529 (code IRIS = 920040104)
# 1 AV AUDRA 92700 COLOMBES ===> 48.9280269,2.2506425 (code IRIS = 920250211)
# 19 RUE DE BELFORT 92600 ASNIERES-SUR-SEINE ===> 48.9099619,2.2676439 (code IRIS = 920040104)
# 38 AV DE VERDUN 92390 VILLENEUVE-LA-GARENNE ===> 48.9352858,2.3304462 (code IRIS = 920780104)
# 53 RUE BOURDARIE LEFURE 92600 ASNIERES-SUR-SEINE ===> 48.9205795,2.283614 (code IRIS = 920040604)
# 12 AV FAIDHERBE 92600 ASNIERES-SUR-SEINE ===> 48.9097074,2.2724485 (code IRIS = 920040103)
# 97 AV GABRIEL PERI 92600 ASNIERES-SUR-SEINE ===> 48.9164119,2.2956932 (code IRIS = 920040501)
# 5 RUE DE LA FERME 92250 LA GARENNE-COLOMBES ===> 48.9044184,2.2431855 (code IRIS = 920350109)
# 11 RUE BASLY 92230 GENNEVILLIERS ===> 48.91874775,2.2928678879755915 (code IRIS = 920360302)
# 40 BD VOLTAIRE 92600 ASNIERES-SUR-SEINE ===> 48.915708,2.2917854 (code IRIS = 920040302)
# 62 RUE FELIX FAURE 92700 COLOMBES ===> 48.914778,2.2550965 (code IRIS = 920250109)
# 53 RUE COLBERT 92700 COLOMBES ===> 48.9111239,2.2367244 (code IRIS = 920250401)
# 57 RUE HENRI DUNANT 92700 COLOMBES ===> 48.9187411,2.2373673 (code IRIS = 920250302)
# 22 RUE PIERRE BROSSOLETTE 92250 LA GARENNE-COLOMBES ===> 48.9031703,2.2512073 (code IRIS = 920350110)
# 9 RUE PAUL ROLLET 92250 LA GARENNE-COLOMBES ===> 48.905951,2.2505422 (code IRIS = 920350108)
# 13 RUE VICTOR HUGO 92270 BOIS-COLOMBES ===> 48.9207784,2.2642954 (code IRIS = 920090106)
# 14 RUE YOURI GAGARINE 92700 COLOMBES ===> 48.9253151,2.2434921 (code IRIS = 920250209)
# 112 RUE COLBERT 92700 COLOMBES ===> 48.9149377,2.2335827 (code IRIS = 920250302)
# 3 RUE PASTEUR 92600 ASNIERES-SUR-SEINE ===> 48.9057088,2.2847059 (code IRIS = 920040402)
# 7 PL GENERAL LECLERC 92700 COLOMBES ===> 48.922788,2.2543577 (code IRIS = 920250106)
# 16 RUE MICHELET 92600 ASNIERES-SUR-SEINE ===> 48.9171654,2.2802189 (code IRIS = 920040202)
# 9 RUE PAUL LECOMTE 92700 COLOMBES ===> 48.9179209,2.2544043 (code IRIS = 920250105)
# 36 RUE GEORGES THORETTON 92230 GENNEVILLIERS ===> 48.926402,2.298376 (code IRIS = 920360502)
# 19 RUE MORTINAT 92600 ASNIERES-SUR-SEINE ===> 48.9189059,2.2817204 (code IRIS = 920040604)
# 13 RUE ELISABETH VIGEE LEBRUN 92230 GENNEVILLIERS ===> 48.931096100000005,2.300426302974647 (code IRIS = 920360504)
# 34 AV D ARGENTEUIL 92600 ASNIERES-SUR-SEINE ===> 48.9105948,2.2890454 (code IRIS = 920040305)
# 7 RUE DE BELFORT 92600 ASNIERES-SUR-SEINE ===> 48.9099619,2.2676439 (code IRIS = 920040104)
# 1 AV MARIE THERESE 92700 COLOMBES ===> 48.9231974,2.2674281 (code IRIS = 920250103)
# 78 RUE DES CHAMPARONS 92700 COLOMBES ===> 48.9260005,2.2631277 (code IRIS = 920250103)
# 1 RUE PASTEUR MARTIN LUTHER KING 92700 COLOMBES ===> 48.922788,2.2543577 (code IRIS = 920250106)
# 41 RUE JULES MICHELET 92700 COLOMBES ===> 48.9320631,2.2693152 (code IRIS = 920250202)
# 318 AV D ARGENTEUIL 92600 ASNIERES-SUR-SEINE ===> 48.9105948,2.2890454 (code IRIS = 920040305)
# 3 AV SAINT JOSEPH 92600 ASNIERES-SUR-SEINE ===> 48.9238323,2.2778048 (code IRIS = 920040707)
# 88 AV HENRI BARBUSSE 92600 ASNIERES-SUR-SEINE ===> 48.9080137,2.2803204 (code IRIS = 920040404)
# 124 RUE EDOUARD VAILLANT 92700 COLOMBES ===> 48.9149724,2.2326158 (code IRIS = 920250403)
# 27 AV DU GAL DE GAULLE 92250 LA GARENNE-COLOMBES ===> 48.9069349,2.2465748 (code IRIS = 920350108)
# 3 AV FAIDHERBE 92600 ASNIERES-SUR-SEINE ===> 48.9097074,2.2724485 (code IRIS = 920040103)
# 17 RUE MALAKOFF 92600 ASNIERES-SUR-SEINE ===> 48.9142361,2.2844943 (code IRIS = 920040301)
# 4 RUE GAMBETTA 92600 ASNIERES-SUR-SEINE ===> 48.9108604,2.2918588 (code IRIS = 920040303)
# 4 RUE DE L ALMA 92600 ASNIERES-SUR-SEINE ===> 48.9105948,2.2890454 (code IRIS = 920040305)
# 27 RUE DES BAS 92600 ASNIERES-SUR-SEINE ===> 48.9164896,2.293933 (code IRIS = 920040501)
# 101 RUE VICTOR HUGO 92700 COLOMBES ===> 48.9235287,2.259766 (code IRIS = 920250104)
# 4 RUE ABBE LEMIRE 92600 ASNIERES-SUR-SEINE ===> 48.9105948,2.2890454 (code IRIS = 920040305)
# 44 RUE DE PLAISANCE 92250 LA GARENNE-COLOMBES ===> 48.9104469,2.2505466 (code IRIS = 920350104)
# 7 RUE ALEXIS BOUVIER 92700 COLOMBES ===> 48.930102,2.2560835 (code IRIS = 920250206)
# 4 RUE LADJI DOUCOURE 92600 ASNIERES-SUR-SEINE ===> 48.9308102,2.2827161 (code IRIS = 920040701)
# 95 AV DES GRESILLONS 92230 GENNEVILLIERS ===> 48.916097,2.3042577 (code IRIS = 920360403)
# 26 RUE DE PRONY 92600 ASNIERES-SUR-SEINE ===> 48.9141107,2.2937948 (code IRIS = 920040501)
# 133 RUE DU GENERAL LECLERC 92270 BOIS-COLOMBES ===> 48.9184771,2.2626306 (code IRIS = 920090107)
# 30 RUE MONTAIGNE 92600 ASNIERES-SUR-SEINE ===> 48.914025,2.2909669 (code IRIS = 920040304)
# 13 RUE DE NORMANDIE 92600 ASNIERES-SUR-SEINE ===> 48.9054764,2.2855543 (code IRIS = 920040402)
# 2 RUE DE BELGIQUE 92700 COLOMBES ===> 48.9286372,2.2658683 (code IRIS = 920250102)
# 25 RUE PAUL BERT 92700 COLOMBES ===> 48.9262002,2.2471808 (code IRIS = 920250211)
# 7 RUE FOCH 92270 BOIS-COLOMBES ===> 48.9115166,2.271311 (code IRIS = 920090110)
# 34 AV DE LA MARNE 92600 ASNIERES-SUR-SEINE ===> 48.9060647,2.2812954 (code IRIS = 920040101)
#
#
# Etape : 500
# 06:25:09
# Temps pour 100 : 57.52556848526001 sec
#
#
# 9 RUE LEPINE MARCEL 92700 COLOMBES ===> 48.9267844,2.2723236 (code IRIS = 920250102)
# 45 GR GR RUE CHARLES DE GAULLE 92600 ASNIERES-SUR-SEINE ===> 48.9105948,2.2890454 (code IRIS = 920040305)
# 41 RUE JEANNE GLEUZER 92700 COLOMBES ===> 48.9167516,2.2279386 (code IRIS = 920250403)
# 83 RUE DE VARSOVIE 92700 COLOMBES ===> 48.9145097,2.2492494 (code IRIS = 920250110)
# 2 RUE CUNY 92270 BOIS-COLOMBES ===> 48.9206222,2.267875 (code IRIS = 920090106)
# 7 PL PRINCESSE PALATINE 92600 ASNIERES-SUR-SEINE ===> 48.9069276,2.28426271733333 (code IRIS = 920040404)
# 41 RUE PIERRE BROSSOLETTE 92600 ASNIERES-SUR-SEINE ===> 48.9111217,2.2928816 (code IRIS = 920040304)
# 98 RUE YOURI GAGARINE 92700 COLOMBES ===> 48.9253151,2.2434921 (code IRIS = 920250209)
# 137 AV DE STALINGRAD 92700 COLOMBES ===> 48.9358372,2.2605574 (code IRIS = 920250205)
# 42 RUE DE NANTERRE 92600 ASNIERES-SUR-SEINE ===> 48.9100111,2.284741 (code IRIS = 920040203)
# 94 AV DES GRESILLONS 92600 ASNIERES-SUR-SEINE ===> 48.9126768,2.2964255 (code IRIS = 920040503)
# 24 RUE DE LA PAIX 92700 COLOMBES ===> 48.9126822,2.2414053 (code IRIS = 920250111)
# 46 GR GR RUE CHARLES DE GAULLE 92600 ASNIERES-SUR-SEINE ===> 48.9105948,2.2890454 (code IRIS = 920040305)
# 22 RUE DE VARSOVIE 92700 COLOMBES ===> 48.9168558,2.2490324 (code IRIS = 920250110)
# 10 RUE TEDDY RINER 92600 ASNIERES-SUR-SEINE ===> 48.9309635,2.2828965 (code IRIS = 920040701)
# 96 AV HENRI BARBUSSE 92700 COLOMBES ===> 48.9170122,2.2525895 (code IRIS = 920250109)
# 61 RUE SARTORIS 92250 LA GARENNE-COLOMBES ===> 48.9071988,2.2453419 (code IRIS = 920350108)
# 15 RUE GERALDY 92270 BOIS-COLOMBES ===> 48.9164338,2.2651804 (code IRIS = 920090109)
# 60 AV FOCH 92250 LA GARENNE-COLOMBES ===> 48.9083291,2.2428327 (code IRIS = 920350103)
# 5 PL DE LA LIBERTE 92250 LA GARENNE-COLOMBES ===> 48.9088179,2.2466486 (code IRIS = 920350105)
# 28 RUE PASTEUR 92700 COLOMBES ===> 48.9143101,2.2504955 (code IRIS = 920250110)
# 19 AV D EPINAY 92700 COLOMBES ===> 48.922788,2.2543577 (code IRIS = 920250106)
# 33 BD NATIONAL 92250 LA GARENNE-COLOMBES ===> 48.9046824,2.239136 (code IRIS = 920350102)
# 4 RUE JEAN JACQUES ROUSSEAU 92700 COLOMBES ===> 48.9318611,2.2605282 (code IRIS = 920250205)
# 62 AV FOCH 92250 LA GARENNE-COLOMBES ===> 48.9091984,2.2459444 (code IRIS = 920350103)
# 30 AV GENEVIEVE BAIN 92700 COLOMBES ===> 48.9294309,2.2669552 (code IRIS = 920250102)
# 5 RUE DE LA CONCORDE 92600 ASNIERES-SUR-SEINE ===> 48.9141337,2.2894236 (code IRIS = 920040305)
# 50 RUE DE L AIGLE 92250 LA GARENNE-COLOMBES ===> 48.9069349,2.2465748 (code IRIS = 920350108)
# 15 AV DU PONANT 92390 VILLENEUVE-LA-GARENNE ===> 48.9434505,2.3292095 (code IRIS = 920780103)
# 74 RUE RASPAIL 92270 BOIS-COLOMBES ===> 48.9172203,2.2694105 (code IRIS = 920090106)
# ...
# 2 CLOS DES QUATRE FEUILLES 95300 PONTOISE ===> 49.0546761,2.0866007 (code IRIS = 955000601)
# 26 RUE JEAN FERRAT 95480 PIERRELAYE ===> 49.0267499,2.1513264 (code IRIS = 954880101)
# 8 RUE CLAUDE DEBUSSY 95630 MERIEL ===> 49.069922,2.1936756 (code IRIS = 953920000)
# 12 PL DES CERCLADES 95000 CERGY ===> 49.0376416,2.0812680111918596 (code IRIS = 951270104)
# 41 RUE DE LA PETITE PLAINE 95290 L'ISLE-ADAM ===> 49.1251462,2.2278501 (code IRIS = 953130104)
# 50 BD LEON BLUM 95260 BEAUMONT-SUR-OISE ===> 49.1468943,2.289942 (code IRIS = 950520101)
# 26 RUE DU PORT 95630 MERIEL ===> 49.0768498,2.2010716 (code IRIS = 953920000)
# 1 RUE SERPENTE 95800 CERGY ===> 49.0464764,2.0512996 (code IRIS = 951270113)
# 54 AV DU HAZAY 95800 CERGY ===> 49.0471346,2.0138917 (code IRIS = 951270125)
# 8 PL DE L EGLISE 95420 GENAINVILLE ===> 49.1252057,1.7518981 (code IRIS = 952700000)
# 9081 RUE DU CHENE 95300 ENNERY ===> 49.0705024,2.1028007 (code IRIS = 952110000)
# 18 ALL DES LILAS 95300 ENNERY ===> 49.0702352,2.1014484 (code IRIS = 952110000)
# LE TROU POULET 95480 PIERRELAYE ===> 49.0192898,2.1486215 (code IRIS = 954880103)
# 24 RUE DES POMMIERS 95480 PIERRELAYE ===> 49.0163927,2.153951 (code IRIS = 954880103)
# 62 RUE DES PILASTRES 95280 JOUY-LE-MOUTIER ===> 49.0068569,2.0485489 (code IRIS = 953230106)
# 2 RUE DE L AISSELETTE 95800 CERGY ===> 49.0527528,2.0388736 (code IRIS = 951270117)
# 9015 AV DU HAZAY 95800 CERGY ===> 49.0471346,2.0138917 (code IRIS = 951270125)
# 5 RUE DES POMMIERS 95480 PIERRELAYE ===> 49.0163927,2.153951 (code IRIS = 954880103)
# RUE BENJAMIN GODARD 95840 VILLIERS-ADAM ===> 49.0648157,2.23287 (code IRIS = 956780000)
# 20 RUE ARISTIDE BRIAND 95840 VILLIERS-ADAM ===> 49.0641399,2.234836 (code IRIS = 956780000)
# 36 RUE PIERRE BROSSOLETTE 95260 BEAUMONT-SUR-OISE ===> 49.1414254,2.2924888 (code IRIS = 950520104)
# 38 RUE DES PATIS 95180 MENUCOURT ===> 49.0308005,1.9868631 (code IRIS = 953880102)
# 8 RUE DU MARECHAL LYAUTEY 95620 PARMAIN ===> 49.117031,2.2085447 (code IRIS = 954800101)
# LE FOND DES VALLEES 95590 PRESLES ===> 49.114721,2.2814878 (code IRIS = 955040000)
# 39 RUE DES VALLEES 95590 PRESLES ===> 49.1132203,2.294384 (code IRIS = 955040000)
# 16 RUE DU GUE 95290 L'ISLE-ADAM ===> 49.1109458,2.2279857 (code IRIS = 953130105)
# ALL JEAN DE SANTEUIL 95690 NESLES-LA-VALLEE ===> 49.1324289,2.1732379 (code IRIS = 954460000)
# 17 RUE BOULARD 95660 CHAMPAGNE SUR-OISE ===> 49.1379422,2.2459213 (code IRIS = 951340000)
# 27 RUE DU GENERAL LECLERC 95450 VIGNY ===> 49.0782618,1.928041 (code IRIS = 956580000)
# 2 CHE DU BUISSON MOINEAUX 95610 ERAGNY-SUR-OISE: pas de code commune INSEE
# RUE REMY 95430 AUVERS-SUR-OISE ===> 49.0718398,2.1550867 (code IRIS = 950390102)
# 82 RUE FRANCOIS VILLON 95430 AUVERS-SUR-OISE ===> 49.0699112,2.1599335 (code IRIS = 950390102)
# 18 RUE FERNAND MAIGNEL 95420 MAGNY-EN-VEXIN ===> 49.1617651,1.8035412 (code IRIS = 953550000)
# LES JARDINS SUD 95610 ERAGNY-SUR-OISE: pas de code commune INSEE
# 8 RUE DE CONFLANS 95610 ERAGNY-SUR-OISE: pas de code commune INSEE
# 9002 RUE DE LA CAPITAINERIE 95290 L'ISLE-ADAM ===> 49.1133593,2.2135286 (code IRIS = 953130104)
# 1 RUE DE LA CAPITAINERIE 95290 L'ISLE-ADAM ===> 49.1133593,2.2135286 (code IRIS = 953130104)
# 2 RUE DES PENDANTS 95280 JOUY-LE-MOUTIER ===> 49.0191283,2.0370492 (code IRIS = 953230105)
# 14 RUE GUICHARD 95620 PARMAIN ===> 49.1142657,2.2080841 (code IRIS = 954800101)
# 22 AV VICTOR HUGO 95630 MERIEL ===> 49.0727867,2.1981491 (code IRIS = 953920000)
# 16 RUE CARNOT 95690 NESLES-LA-VALLEE ===> 49.1236067,2.1820722 (code IRIS = 954460000)
# 1 RUE SAINT LAZARE 95290 L'ISLE-ADAM ===> 49.1113717,2.2172175 (code IRIS = 953130101)
# 4 RUE DU ROSSIGNOL 95290 L'ISLE-ADAM ===> 49.1057952,2.2194515 (code IRIS = 953130101)
# 6 RUE DU ROSSIGNOL 95290 L'ISLE-ADAM ===> 49.1057952,2.2194515 (code IRIS = 953130101)
# 16 RUE GILLES DE MAUPEOU 95450 ABLEIGES ===> 49.087709,1.9809564 (code IRIS = 950020000)
# 20 CHE DUPUIS VERT 95000 CERGY ===> 49.0371395,2.0730244 (code IRIS = 951270105)
# 40 RUE DU GENERAL LECLERC 95310 ST OUEN L AUMONE: pas de code commune INSEE
# 3 ALL FREUNDLICH 95430 AUVERS-SUR-OISE ===> 49.0750292,2.1667855 (code IRIS = 950390101)
# 2  LE PLATEAU DE LA RAVINIERE 95520 OSNY ===> 49.0586305,2.0672798 (code IRIS = 954760105)
# 9002  LE PLATEAU DE LA RAVINIERE 95520 OSNY ===> 49.0586305,2.0672798 (code IRIS = 954760105)
# 33 RUE DE BERNES 95820 BRUYERES-SUR-OISE ===> 49.1567079,2.3254256 (code IRIS = 951160000)
# 19 RUE DHAMELINCOURT 95840 VILLIERS-ADAM ===> 49.0628303,2.2333881 (code IRIS = 956780000)
# 25 RUE DE LA LIBERATION 95540 MERY-SUR-OISE ===> 49.0522353,2.1968792 (code IRIS = 953940109)
# 3 RUE JEAN BRESTEL 95540 MERY-SUR-OISE ===> 49.0539452,2.1870815 (code IRIS = 953940109)
# 6 RUE DU CLOS DU ROI 95310 ST OUEN L AUMONE: pas de code commune INSEE
# LE VILLAGE 95510 SAINT-CYR-EN-ARTHIES ===> 49.0615171,1.7428006 (code IRIS = 955430000)
# 42 RUE DU PARC 95510 SAINT-CYR-EN-ARTHIES ===> 49.0601454,1.7405147 (code IRIS = 955430000)
# 30 RUE DES MOUSSERONS 95800 CERGY ===> 49.0448325,2.0364696 (code IRIS = 951270114)
# 11 RUE MADAME 95340 BERNES-SUR-OISE ===> 49.1583224,2.3027243 (code IRIS = 950580000)
# 23 RUE MACAIGNE FORTIER 95650 BOISSY-L'AILLERIE ===> 49.0766145,2.0255707 (code IRIS = 950780000)
# LE VAUGOULE 95650 BOISSY-L'AILLERIE ===> 49.0800327,2.0261068 (code IRIS = 950780000)
# 20 RUE VICTOR HUGO 95300 PONTOISE ===> 49.0537455,2.1016569 (code IRIS = 955000103)
# CHARDRONVILLE 95450 SAGY ===> 49.0495786,1.9523825 (code IRIS = 955350000)
# SOUS LE CLOS BENOIST 95450 SAGY ===> 49.0471084,1.9547605 (code IRIS = 955350000)
# LE GRAND LOUP PENDU 95450 SAGY ===> 49.0551303,1.9630484 (code IRIS = 955350000)
# LA RENARDIERE 95450 SAGY ===> 49.054365,1.9584711 (code IRIS = 955350000)
# SUR AMBRIMONT 95450 SAGY ===> 49.0615499,1.9528017 (code IRIS = 955350000)
#
#
# Etape : 37500
# 12:18:55
# Temps pour 100 : 57.996394634246826 sec
#
#
# LA COUTURE DU GRAND MESNIL 95450 SAGY ===> 49.0542165,1.9508032 (code IRIS = 955350000)
# LA METAIRIE 95640 MARINES ===> 49.150717,1.9706878 (code IRIS = 953700000)
# 16 RUE DE L ABREUVOIR 95420 MAGNY-EN-VEXIN ===> 49.1554403,1.7864359 (code IRIS = 953550000)
# 75 AV VICTOR HUGO 95630 MERIEL ===> 49.0727867,2.1981491 (code IRIS = 953920000)
# GR GRANDE RUE 95630 MERIEL ===> 49.0783885,2.20486 (code IRIS = 953920000)
# 10 PL DES COLONNES 95800 CERGY ===> 49.0527528,2.0388736 (code IRIS = 951270117)
# 48 RUE DE PIERRELAYE 95610 ERAGNY-SUR-OISE: pas de code commune INSEE
# 20 RUE DE LA GDE PIECE 95180 MENUCOURT ===> 49.027615,1.9815885 (code IRIS = 953880102)
# 2 RUE DE LA BERGERIE 95650 GENICOURT ===> 49.1009724,2.0563412 (code IRIS = 952710000)
# 16 RUE CHARPENTIER D ENNERY 95300 ENNERY ===> 49.0763173,2.1062625 (code IRIS = 952110000)
# 1 RUE DES LARRIS VERTS 95000 PONTOISE ===> 49.0354475,2.0907458 (code IRIS = 955000401)
# 2 ALL DE GIVERNY 95800 CERGY ===> 49.0398464,2.0196991 (code IRIS = 951270132)
# LE CLOS WATTEAU 95430 AUVERS-SUR-OISE ===> 49.0684331,2.1588601 (code IRIS = 950390102)
# 25 RUE FRANCOIS VILLON 95430 AUVERS-SUR-OISE ===> 49.0699112,2.1599335 (code IRIS = 950390102)
# RUE LOUIS GANNE 95430 AUVERS-SUR-OISE ===> 49.0698722,2.1600761 (code IRIS = 950390102)
# 11 RUE LOUIS GANNE 95430 AUVERS-SUR-OISE ===> 49.0698722,2.1600761 (code IRIS = 950390102)
# 3 RUE D ARTHIES 95510 AINCOURT ===> 49.0719037,1.771976 (code IRIS = 950080000)
# 15 RUE DES REGARDS 95420 MAGNY-EN-VEXIN ===> 49.150443,1.7889519 (code IRIS = 953550000)
# SAINT ANTOINE 95420 MAGNY-EN-VEXIN ===> 49.1554403,1.7864359 (code IRIS = 953550000)
# 20 CHE DES BOURSEAUX 95310 ST OUEN L AUMONE: pas de code commune INSEE
# 47 RUE DE LA ROCHE 95300 PONTOISE ===> 49.0502078,2.1006482 (code IRIS = 955000201)
# 25 RUE DE BORAN 95820 BRUYERES-SUR-OISE ===> 49.1585795,2.3354208 (code IRIS = 951160000)
# 30 RUE PARMENTIER 95430 AUVERS-SUR-OISE ===> 49.0712528,2.152077 (code IRIS = 950390103)
# 15 RUE DU PONCEAU 95000 CERGY ===> 49.039386,2.0684649 (code IRIS = 951270110)
# BD DE LA REPUBLIQUE 95420 MAGNY-EN-VEXIN ===> 49.1562072,1.7913515 (code IRIS = 953550000)
# 4 BD DE LA REPUBLIQUE 95420 MAGNY-EN-VEXIN ===> 49.1562072,1.7913515 (code IRIS = 953550000)
# 11 RUE MAURICE FOUQUET 95000 BOISEMONT ===> 49.0223999,2.0026375 (code IRIS = 950740000)
# 5 RUE HYPOLITE CAMILLE DELPY 95430 AUVERS-SUR-OISE ===> 49.0679378,2.1523792 (code IRIS = 950390103)
# 49 RTE DE PARIS A DIEPPE 95520 OSNY ===> 49.072157,2.080466 (code IRIS = 954760103)
# 4 SQ DE LA FRETTE 95420 NUCOURT ===> 49.15842585,1.8557799441412217 (code IRIS = 954590000)
# 13 AV DU GENERAL DE GAULLE 95310 ST OUEN L AUMONE: pas de code commune INSEE
# 4 AV DE PARIS 95620 PARMAIN ===> 49.1014545,2.2079601 (code IRIS = 954800102)
# 20 PL DE LA REPUBLIQUE 95340 PERSAN ===> 49.1525781,2.2700384 (code IRIS = 954870103)
# 39 AV DES GENOTTES 95800 CERGY ===> 49.0524173,2.0384395 (code IRIS = 951270117)
# 80 RUE RAYMOND MARGUET 95340 RONQUEROLLES ===> 49.1732825,2.2132026 (code IRIS = 955290000)
# 2  LES LARRIS ORANGES 95000 PONTOISE ===> 49.0508845,2.1008067 (code IRIS = 955000201)
# ARTIMONT 95830 FREMECOURT ===> 49.1265119,1.9965656 (code IRIS = 952540000)
# 4 RUE DES VIEILLES VIGNES 95830 FREMECOURT ===> 49.1245472,1.9955276 (code IRIS = 952540000)
# 21 RUE DE LA REPUBLIQUE 95650 BOISSY-L'AILLERIE ===> 49.0763529,2.028931 (code IRIS = 950780000)
# 12 RUE DE L AMANDIER 95000 CERGY ===> 49.0527528,2.0388736 (code IRIS = 951270117)
# 54 AV MARCEL PERRIN 95540 MERY-SUR-OISE ===> 49.0637092,2.1861317 (code IRIS = 953940101)
# 19 RUE DU DOCTEUR DUBOIS 95750 CHARS ===> 49.159387,1.936914 (code IRIS = 951420000)
# 13 RUE DU DOCTEUR DUBOIS 95750 CHARS ===> 49.1592999,1.9371494 (code IRIS = 951420000)
# 1 RUE DES CEPAGES 95300 PONTOISE ===> 49.046479,2.0883837 (code IRIS = 955000304)
# 7 RUE DE LA TERMINALE 95800 CERGY ===> 49.0447478,2.0289458 (code IRIS = 951270121)
# 19 QUAI DE L ECLUSE 95310 ST OUEN L AUMONE: pas de code commune INSEE
# 24 RUE DU BOIS DE CHARS 95420 NUCOURT ===> 49.1623426,1.8604299000000002 (code IRIS = 954590000)
# LE JARDIN DU BAS 95420 NUCOURT ===> 49.1584379,1.8535991 (code IRIS = 954590000)
# 201 RUE DES CHENES BRUNS 95000 CERGY ===> 49.0527528,2.0388736 (code IRIS = 951270117)
# 9001 RUE DES CHENES BRUNS 95000 CERGY ===> 49.0527528,2.0388736 (code IRIS = 951270117)
# 30 ALL DU VEXIN 95180 MENUCOURT ===> 49.0271941,1.9824692 (code IRIS = 953880101)
# 204 RUE DES CHENES BRUNS 95000 CERGY ===> 49.0527528,2.0388736 (code IRIS = 951270117)
# 1 RUE DES HUGUENOTS 95000 CERGY ===> 49.0296445,2.0840254 (code IRIS = 951270102)
# 9001 RUE DES HUGUENOTS 95000 CERGY ===> 49.0296445,2.0840254 (code IRIS = 951270102)
# 12 CHT BRULOIRS 95000 CERGY ===> 49.0527528,2.0388736 (code IRIS = 951270117)
# 6 RUE DE LA CORNE 95300 PONTOISE ===> 49.0499537,2.0997015 (code IRIS = 955000201)
# 53 RUE DE LA GDE PIECE 95180 MENUCOURT ===> 49.027615,1.9815885 (code IRIS = 953880102)
# 5 SEN DES COTEAUX 95620 PARMAIN ===> 49.1142087,2.2090453 (code IRIS = 954800101)
# 26 RUE DU VEXIN 95450 COMMENY ===> 49.1254411,1.8946925 (code IRIS = 951690000)
# 17 CHE DUPUIS VERT 95000 CERGY ===> 49.0371395,2.0730244 (code IRIS = 951270105)
# 9 RUE DU MONT LA VILLE 95760 VALMONDOIS ===> 49.098045,2.1854365 (code IRIS = 956280000)
# 42 RUE NATIONALE 95490 VAUREAL ===> 49.0293718,2.0334581 (code IRIS = 956370106)
# LES TROIS ARPENTS 95540 MERY-SUR-OISE ===> 49.0634561,2.1836324 (code IRIS = 953940106)
# 7 RUE LAMARTINE 95540 MERY-SUR-OISE ===> 49.0583611,2.1587647 (code IRIS = 953940110)
# 2 RUE JEAN JAURES 95310 ST OUEN L AUMONE: pas de code commune INSEE
# 9002 RES DU BOIS BOULOGNE 95290 L'ISLE-ADAM ===> 49.1125294,2.2186324 (code IRIS = 953130102)
# 2 RUE DE LA SOURCE PERDUE 95290 L'ISLE-ADAM ===> 49.117581,2.2303097 (code IRIS = 953130102)
# 72 AV GASTON VERMEIRE 95340 PERSAN ===> 49.1529638,2.2723392 (code IRIS = 954870104)
# 6 AV DE PARIS 95590 NOINTEL ===> 49.126168,2.2872877 (code IRIS = 954520000)
# 7 ALL MESSAGER 95300 ENNERY ===> 49.0720192,2.1017807 (code IRIS = 952110000)
# 8 RUE DU BOIS THIBAULT 95760 VALMONDOIS ===> 49.0967512,2.1889394 (code IRIS = 956280000)
# BOIS THIBAUT 95760 VALMONDOIS ===> 49.0925741,2.192675 (code IRIS = 956280000)
# 3 BD DE LA REPUBLIQUE 95420 MAGNY-EN-VEXIN ===> 49.1562072,1.7913515 (code IRIS = 953550000)
# 61 RUE DU BEL AIR 95590 PRESLES ===> 49.1173637,2.2908922 (code IRIS = 955040000)
# 20 RUE DELAPERSONNE 95290 L'ISLE-ADAM ===> 49.1137107,2.2292636 (code IRIS = 953130103)
# LES BOURSAULTS 95660 CHAMPAGNE SUR-OISE ===> 49.1339431,2.2312397 (code IRIS = 951340000)
# 14 RUE DE VAUX 95620 PARMAIN ===> 49.1352286,2.2061455 (code IRIS = 954800101)
# 5 RUE DE LA FONTAINE DU REGARD 95300 ENNERY ===> 49.0782006,2.0976203 (code IRIS = 952110000)
# 19 RUE DE L OISE 95540 MERY-SUR-OISE ===> 49.0634561,2.1836324 (code IRIS = 953940106)
# 88 RUE PIERRE BUTIN 95300 PONTOISE ===> 49.049511,2.0948602 (code IRIS = 955000201)
# 10 ALL DES COQUELICOTS 95660 CHAMPAGNE SUR-OISE ===> 49.1430647,2.2442909 (code IRIS = 951340000)
# 1 RUE D ARTHIES 95510 AINCOURT ===> 49.0719037,1.771976 (code IRIS = 950080000)
# RUE DE LA BUCAILLE 95510 AINCOURT ===> 49.0735529,1.7712102 (code IRIS = 950080000)
# 51 AV SIMONE SIGNORET 95490 VAUREAL ===> 49.0259245,2.0176542 (code IRIS = 956370102)
# 41 ALL DES MUSARDIERES 95280 JOUY-LE-MOUTIER ===> 49.0109511,2.0397473 (code IRIS = 953230103)
# 3 RUE DU GOULET 95640 MARINES ===> 49.1454757,1.9766301 (code IRIS = 953700000)
# 6 ALL D ALEMBERT 95310 ST OUEN L AUMONE: pas de code commune INSEE
# 5 AV MICHEL PONIATOWSKI 95290 L'ISLE-ADAM ===> 49.1167204,2.2300478 (code IRIS = 953130102)
# 21 RUE RAYMOND POINCARE 95620 PARMAIN ===> 49.1199357,2.2103869 (code IRIS = 954800101)
# 46 RUE DES COTEAUX 95300 PONTOISE ===> 49.0616205,2.1191977 (code IRIS = 955000103)
# 77 RUE DE PONTOISE 95290 L'ISLE-ADAM ===> 49.1021915,2.2171655 (code IRIS = 953130105)
# 38 RUE VICTOR HUGO 95650 BOISSY-L'AILLERIE ===> 49.0751137,2.0257308 (code IRIS = 950780000)
# 1 RTE DE VERNON 95710 BRAY-ET-LU ===> 49.1381412,1.6538228 (code IRIS = 951010000)
# 32 ALL DES BOURSEAUX 95280 JOUY-LE-MOUTIER ===> 49.0114729,2.04058 (code IRIS = 953230103)
# 8 CHS JULES CESAR 95300 PONTOISE ===> 49.0508845,2.1008067 (code IRIS = 955000201)
# 1 RUE DES MIRABELLES 95310 ST OUEN L AUMONE: pas de code commune INSEE
# 1 RUE JEAN BAPTISTE MOLIERE 95280 JOUY-LE-MOUTIER ===> 49.0116,2.03194 (code IRIS = 953230102)
# 41 RUE DES MOULINS 95510 AMENUCOURT ===> 49.1013379,1.6331183 (code IRIS = 950120000)
# LE PETIT ROCONVAL 95510 AMENUCOURT ===> 49.1024965,1.6335037 (code IRIS = 950120000)
# 1 RUE DU BORD DE L EAU 95290 L'ISLE-ADAM ===> 49.1125294,2.2186324 (code IRIS = 953130102)
#
#
# Etape : 37600
# 12:20:01
# Temps pour 100 : 65.98407864570618 sec
#
#
# 4 RUE DU RAIDILLON 95650 MONTGEROULT ===> 49.0816411,2.0044841 (code IRIS = 954220000)
# 16 RUE ERIC DE MARTIMPREY 95300 PONTOISE ===> 49.0479063,2.0874088 (code IRIS = 955000304)
# IMP DES HAYETTES 95520 OSNY ===> 49.0665312,2.0861128 (code IRIS = 954760103)
# 30 RUE DU GENERAL LECLERC 95830 CORMEILLES-EN-VEXIN ===> 49.1196889,2.0127576 (code IRIS = 951770000)
# 9 RUE DES MARADAS ORANGE 95000 PONTOISE ===> 49.0508845,2.1008067 (code IRIS = 955000201)
# 8 RUE DE MAUNOURY 95310 ST OUEN L AUMONE: pas de code commune INSEE
# 302 RUE DES CHENES VERTS 95000 CERGY ===> 49.0411105,2.0705679 (code IRIS = 951270110)
# 9001 RUE DES CHENES VERTS 95000 CERGY ===> 49.0411105,2.0705679 (code IRIS = 951270110)
# 10 RUE DU REPOS 95000 CERGY ===> 49.0386789,2.0630863 (code IRIS = 951270106)
# 3 RUE VAGABONDE 95490 VAUREAL ===> 49.0302373,2.0204433 (code IRIS = 956370101)
# 30 RUE DAUBIGNY 95300 PONTOISE ===> 49.0602604,2.0959514 (code IRIS = 955000801)
# LE BRULOIR 95000 CERGY ===> 49.0313324,2.0657832 (code IRIS = 951270105)
# LA CROIX VILLECOQ 95280 JOUY-LE-MOUTIER ===> 49.0093444,2.0306811 (code IRIS = 953230101)
# 9001 RUE ROSSINI 95280 JOUY-LE-MOUTIER ===> 49.01289725,2.0261638329718794 (code IRIS = 953230101)
# 10 RUE DU CHATEAU BELGER 95300 PONTOISE ===> 49.0550623,2.1075807 (code IRIS = 955000103)
# 42 RUE FELIX ROUGET 95490 VAUREAL ===> 49.0259419,2.0362653 (code IRIS = 956370106)
# 61 RUE DE ROUEN 95300 PONTOISE ===> 49.0492869,2.0846106 (code IRIS = 955000304)
# 47 RUE DES ECOLES 95540 MERY-SUR-OISE ===> 49.0638203,2.1842349 (code IRIS = 953940101)

# %%
selec.head()

# %%
selec.shape

# %%
selec.to_csv('export_gps_iris_' + str(row_first) + "-" + str(row_last)+'.csv')
