# %%
import pandas as pd
import numpy as np
import json
import requests
import time

# %%
# Chargement du jeu de données
df = pd.read_csv('01B - dvf_sans_gps_iris.csv')
df = df.drop(columns = {'Unnamed: 0'})
df = df.rename(columns = {'Commune2': 'Commune Alt'})
df.head()
#print(df.columns)
# Out:
# C:\Users\olivier\anaconda\envs\Geo\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (18,20,22,35) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    No disposition Date mutation Nature mutation  Valeur fonciere  No voie  \
# 0               1    02/01/2020           Vente         268800.0     14.0
# 1               1    06/01/2020           Vente         878378.0      9.0
# 2               1    10/01/2020           Vente         680000.0     10.0
# 3               1    08/01/2020           Vente         370000.0     79.0
# 4               1    09/01/2020           Vente         741500.0    131.0
#
#   B/T/Q Type de voie Code voie             Voie  Code postal  ...  \
# 0   NaN          RUE      0411      DE L'ARCADE      75008.0  ...
# 1   NaN           BD      5888  DE LA MADELEINE      75001.0  ...
# 2   NaN          RUE      1200  DU BOURG L'ABBE      75003.0  ...
# 3   NaN          RUE      0420     DES ARCHIVES      75003.0  ...
# 4   NaN          RUE      8525      SAINT DENIS      75001.0  ...
#
#   Surface terrain  Code commune INSEE           Ville  \
# 0             NaN               75108  75008 PARIS 08
# 1             NaN               75101  75001 PARIS 01
# 2             NaN               75103  75003 PARIS 03
# 3             NaN               75103  75003 PARIS 03
# 4             NaN               75101  75001 PARIS 01
#
#                               Adresse Commune Alt       Prix m2  Paris  \
# 0      14 RUE DE L'ARCADE 75008 PARIS       PARIS  11200.000000      1
# 1    9 BD DE LA MADELEINE 75001 PARIS       PARIS  13308.757576      1
# 2  10 RUE DU BOURG L'ABBE 75003 PARIS       PARIS  13333.333333      1
# 3     79 RUE DES ARCHIVES 75003 PARIS       PARIS  17619.047619      1
# 4     131 RUE SAINT DENIS 75001 PARIS       PARIS  12155.737705      1
#
#   dep_name    region_name Mer
# 0    Paris  Île-de-France   0
# 1    Paris  Île-de-France   0
# 2    Paris  Île-de-France   0
# 3    Paris  Île-de-France   0
# 4    Paris  Île-de-France   0
#
# [5 rows x 45 columns]

# %% [markdown]
# ## Import du fichier adresses avec gps et iris

# %%
adresses = pd.read_csv('03 - export_gps_iris_ALL.csv', dtype = {'code_iris_clean': str,
                                                                                             'Code departement' : str,
                                                                                             'Code postal 5 chiffres' : str,
                                                                                             'Code commune INSEE': str})
adresses.shape
# Out:
# C:\Users\olivier\anaconda\envs\Geo\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (9) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# (1114244, 20)

# %%
adresses[-adresses['code_iris_clean'].isna()].head(40)
# Out:
#     Unnamed: 0  Unnamed: 0.1  No voie Type de voie                      Voie  \
# 0            0             0      NaN          NaN                  FORTUNAT
# 1            1             1      NaN          NaN    TERRES DES CINQ SAULES
# 2            2             2      NaN          NaN        BOIS DU CHAMP RION
# 3            3             3      NaN          NaN               EN COROBERT
# 4            4             4      NaN          RUE          DE LA CHARTREUSE
# 5            5             5      NaN          NaN             CHAMP PORTIER
# 6            6             6      NaN          NaN                   CHAMPEL
# 7            7             7   5367.0          NaN                   LORETTE
# 8            8             8     31.0          RUE  COMTE DE LA TEYSSONNIERE
# 9            9             9      6.0           AV         DU CHAMP DE FOIRE
# 10          10            10    904.0          CHE         DES GDES CADALLES
# 11          11            11      NaN          NaN              LES CADALLES
# 12          12            12      NaN          NaN                LES FOSSES
# 13          13            13   5104.0          NaN            COLIGNY LE BAS
# 14          14            14     16.0          RUE                DES GRAVES
# 15          15            15      2.0          IMP              DU COLOMBIER
# 16          16            16      NaN          NaN              AU COLOMBIER
# 17          17            17    102.0          IMP             DE LA CULOTTE
# 18          18            18      NaN          NaN                LE VILLAGE
# 20          20            20     10.0          ALL    DE LA PETITE REYSSOUZE
# 21          21            21     12.0          ALL    DE LA PETITE REYSSOUZE
# 22          22            22   5090.0          NaN         HAMEAU DES RIPPES
# 23          23            23      NaN          NaN         HAMEAU DES RIPPES
# 24          24            24      NaN          NaN                A LA CROIX
# 25          25            25      NaN          NaN            LES AMBERTHETS
# 26          26            26      NaN          NaN        LES GREFFETS OUEST
# 27          27            27      NaN          NaN             LES TRILLERES
# 28          28            28     18.0          RUE                DES GRAVES
# 29          29            29     27.0          RUE           DE LA BROCHETTE
# 30          30            30      NaN          NaN                AUX RIVONS
# 31          31            31    337.0          RTE                 DE CROYAT
# 32          32            32      NaN          NaN                    VAVRES
# 33          33            33   5134.0          NaN                    VAVRES
# 34          34            34      5.0          RUE             EDGAR  QUINET
# 35          35            35   5188.0          NaN                LES JORDES
# 36          36            36    660.0          RTE             DE STRASBOURG
# 37          37            37      NaN          NaN                 VACAGNOLE
# 38          38            38   6058.0          NaN                   OUSSIAT
# 39          39            39    288.0          RTE                DE L ETANG
# 40          40            40      NaN          NaN                EN CUNIERE
#
#     Code postal                     Commune                            Ville  \
# 0        1250.0                   CEYZERIAT                   1250 CEYZERIAT
# 1        1290.0                        LAIZ                        1290 LAIZ
# 2        1290.0                        LAIZ                        1290 LAIZ
# 3        1290.0                        LAIZ                        1290 LAIZ
# 4        1960.0                    PERONNAS                    1960 PERONNAS
# 5        1370.0               VAL-REVERMONT               1370 VAL REVERMONT
# 6        1270.0                     COLIGNY                     1270 COLIGNY
# 7        1270.0                     COLIGNY                     1270 COLIGNY
# 8        1000.0             BOURG-EN-BRESSE             1000 BOURG EN BRESSE
# 9        1000.0             BOURG-EN-BRESSE             1000 BOURG EN BRESSE
# 10       1000.0       SAINT-DENIS-LES-BOURG       1000 SAINT DENIS LES BOURG
# 11       1000.0       SAINT-DENIS-LES-BOURG       1000 SAINT DENIS LES BOURG
# 12       1440.0                      VIRIAT                      1440 VIRIAT
# 13       1270.0                     COLIGNY                     1270 COLIGNY
# 14       1000.0             BOURG-EN-BRESSE             1000 BOURG EN BRESSE
# 15       1250.0                     TOSSIAT                     1250 TOSSIAT
# 16       1250.0                     TOSSIAT                     1250 TOSSIAT
# 17       1310.0                   MONTRACOL                   1310 MONTRACOL
# 18       1310.0                   MONTRACOL                   1310 MONTRACOL
# 20       1000.0             BOURG-EN-BRESSE             1000 BOURG EN BRESSE
# 21       1000.0             BOURG-EN-BRESSE             1000 BOURG EN BRESSE
# 22       1240.0                    CERTINES                    1240 CERTINES
# 23       1240.0                    CERTINES                    1240 CERTINES
# 24       1960.0  SAINT-ANDRE-SUR-VIEUX-JONC  1960 SAINT ANDRE SUR VIEUX JONC
# 25       1000.0       SAINT-DENIS-LES-BOURG       1000 SAINT DENIS LES BOURG
# 26       1440.0                      VIRIAT                      1440 VIRIAT
# 27       1440.0                      VIRIAT                      1440 VIRIAT
# 28       1000.0             BOURG-EN-BRESSE             1000 BOURG EN BRESSE
# 29       1370.0                  MEILLONNAS                  1370 MEILLONNAS
# 30       1190.0     CHAVANNES-SUR-REYSSOUZE     1190 CHAVANNES SUR REYSSOUZE
# 31       1290.0        SAINT-JEAN-SUR-VEYLE        1290 SAINT JEAN SUR VEYLE
# 32       1340.0                  MALAFRETAZ                  1340 MALAFRETAZ
# 33       1340.0                  MALAFRETAZ                  1340 MALAFRETAZ
# 34       1000.0             BOURG-EN-BRESSE             1000 BOURG EN BRESSE
# 35       1560.0                      CORMOZ                      1560 CORMOZ
# 36       1270.0                 VILLEMOTIER                 1270 VILLEMOTIER
# 37       1340.0                    ATTIGNAT                    1340 ATTIGNAT
# 38       1160.0                  PONT-D AIN                  1160 PONT D AIN
# 39       1190.0     CHAVANNES-SUR-REYSSOUZE     1190 CHAVANNES SUR REYSSOUZE
# 40       1190.0     CHAVANNES-SUR-REYSSOUZE     1190 CHAVANNES SUR REYSSOUZE
#
#                                               Adresse INSEE_COM  Commune_Lat  \
# 0                             FORTUNAT 1250 CEYZERIAT    1072.0    46.183217
# 1                    TERRES DES CINQ SAULES 1290 LAIZ    1203.0    46.246992
# 2                        BOIS DU CHAMP RION 1290 LAIZ    1203.0    46.246992
# 3                               EN COROBERT 1290 LAIZ    1203.0    46.246992
# 4                  RUE DE LA CHARTREUSE 1960 PERONNAS    1289.0    46.171190
# 5                    CHAMP PORTIER 1370 VAL-REVERMONT       NaN          NaN
# 6                                CHAMPEL 1270 COLIGNY    1108.0    46.386664
# 7                          5367  LORETTE 1270 COLIGNY    1108.0    46.386664
# 8   31 RUE COMTE DE LA TEYSSONNIERE 1000 BOURG-EN-...    1053.0    46.205152
# 9         6 AV DU CHAMP DE FOIRE 1000 BOURG-EN-BRESSE    1053.0    46.205152
# 10  904 CHE DES GDES CADALLES 1000 SAINT-DENIS-LES...    1344.0    46.211200
# 11            LES CADALLES 1000 SAINT-DENIS-LES-BOURG    1344.0    46.211200
# 12                             LES FOSSES 1440 VIRIAT    1451.0    46.250899
# 13                  5104  COLIGNY LE BAS 1270 COLIGNY    1108.0    46.386664
# 14             16 RUE DES GRAVES 1000 BOURG-EN-BRESSE    1053.0    46.205152
# 15                    2 IMP DU COLOMBIER 1250 TOSSIAT    1422.0    46.138479
# 16                          AU COLOMBIER 1250 TOSSIAT    1422.0    46.138479
# 17               102 IMP DE LA CULOTTE 1310 MONTRACOL    1264.0    46.186720
# 18                          LE VILLAGE 1310 MONTRACOL    1264.0    46.186720
# 20  10 ALL DE LA PETITE REYSSOUZE 1000 BOURG-EN-BR...    1053.0    46.205152
# 21  12 ALL DE LA PETITE REYSSOUZE 1000 BOURG-EN-BR...    1053.0    46.205152
# 22              5090  HAMEAU DES RIPPES 1240 CERTINES    1069.0    46.133795
# 23                    HAMEAU DES RIPPES 1240 CERTINES    1069.0    46.133795
# 24         A LA CROIX 1960 SAINT-ANDRE-SUR-VIEUX-JONC    1336.0    46.149241
# 25          LES AMBERTHETS 1000 SAINT-DENIS-LES-BOURG    1344.0    46.211200
# 26                     LES GREFFETS OUEST 1440 VIRIAT    1451.0    46.250899
# 27                          LES TRILLERES 1440 VIRIAT    1451.0    46.250899
# 28             18 RUE DES GRAVES 1000 BOURG-EN-BRESSE    1053.0    46.205152
# 29             27 RUE DE LA BROCHETTE 1370 MEILLONNAS    1241.0    46.244998
# 30            AUX RIVONS 1190 CHAVANNES-SUR-REYSSOUZE    1094.0    46.437979
# 31        337 RTE DE CROYAT 1290 SAINT-JEAN-SUR-VEYLE    1365.0    46.268363
# 32                             VAVRES 1340 MALAFRETAZ    1229.0    46.329555
# 33                       5134  VAVRES 1340 MALAFRETAZ    1229.0    46.329555
# 34           5 RUE EDGAR  QUINET 1000 BOURG-EN-BRESSE    1053.0    46.205152
# 35                       5188  LES JORDES 1560 CORMOZ    1124.0    46.433663
# 36             660 RTE DE STRASBOURG 1270 VILLEMOTIER    1445.0    46.345854
# 37                            VACAGNOLE 1340 ATTIGNAT    1024.0    46.286180
# 38                      6058  OUSSIAT 1160 PONT-D AIN       NaN          NaN
# 39    288 RTE DE L ETANG 1190 CHAVANNES-SUR-REYSSOUZE    1094.0    46.437979
# 40            EN CUNIERE 1190 CHAVANNES-SUR-REYSSOUZE    1094.0    46.437979
#
#     Commune_Lon       lon        lat Code departement  Code commune  \
# 0      5.320072  5.323007  46.173753               01           NaN
# 1      4.899335  4.892457  46.246330               01           NaN
# 2      4.899335  4.892457  46.246330               01           NaN
# 3      4.899335  4.881913  46.248368               01           NaN
# 4      5.218022  5.227583  46.184979               01           NaN
# 5           NaN  5.342953  46.264482               01           NaN
# 6      5.330823  5.349373  46.380992               01           NaN
# 7      5.330823  5.351500  46.380469               01           NaN
# 8      5.246021  5.208966  46.197026               01           NaN
# 9      5.246021  5.229923  46.206965               01           NaN
# 10     5.184628  5.190634  46.202056               01           NaN
# 11     5.184628  5.201312  46.209676               01           NaN
# 12     5.223022  5.228985  46.239131               01           NaN
# 13     5.330823  5.347011  46.388046               01           NaN
# 14     5.246021  5.232291  46.199495               01           NaN
# 15     5.304001  5.311045  46.141154               01           NaN
# 16     5.304001  5.316550  46.138500               01           NaN
# 17     5.117060  5.121617  46.193815               01           NaN
# 18     5.117060  5.123510  46.197500               01           NaN
# 20     5.246021  5.235649  46.201210               01           NaN
# 21     5.246021  5.235654  46.201202               01           NaN
# 22     5.262395  5.264580  46.132900               01           NaN
# 23     5.262395  5.264580  46.132900               01           NaN
# 24     5.141752  5.113673  46.131453               01           NaN
# 25     5.184628  5.190634  46.202056               01           NaN
# 26     5.223022  5.216788  46.253318               01           NaN
# 27     5.223022  5.216788  46.253318               01           NaN
# 28     5.246021  5.232291  46.199495               01           NaN
# 29     5.335947  5.347133  46.237818               01           NaN
# 30     5.006937  4.993350  46.430200               01           NaN
# 31     4.921984  4.914515  46.263766               01           NaN
# 32     5.143863  5.158703  46.338489               01           NaN
# 33     5.143863  5.158703  46.338489               01           NaN
# 34     5.246021  5.225448  46.204005               01           NaN
# 35     5.221813  5.232700  46.448400               01           NaN
# 36     5.310362  5.329078  46.356967               01           NaN
# 37     5.179523  5.173981  46.267647               01           NaN
# 38          NaN  5.361196  46.055795               01           NaN
# 39     5.006937  4.993350  46.430200               01           NaN
# 40     5.006937  4.998884  46.435980               01           NaN
#
#    Code commune INSEE  coordonnees_gps Code postal 5 chiffres code_iris_clean
# 0                 NaN              NaN                  01250      10720000.0
# 1                 NaN              NaN                  01290      12030000.0
# 2                 NaN              NaN                  01290      12030000.0
# 3                 NaN              NaN                  01290      12030000.0
# 4                 NaN              NaN                  01960      12890102.0
# 5                 NaN              NaN                  01370       014260000
# 6                 NaN              NaN                  01270      11080000.0
# 7                 NaN              NaN                  01270      11080000.0
# 8                 NaN              NaN                  01000      10530203.0
# 9                 NaN              NaN                  01000      10530101.0
# 10                NaN              NaN                  01000      13440000.0
# 11                NaN              NaN                  01000      13440000.0
# 12                NaN              NaN                  01440      14510101.0
# 13                NaN              NaN                  01270      11080000.0
# 14                NaN              NaN                  01000      10530302.0
# 15                NaN              NaN                  01250      14220000.0
# 16                NaN              NaN                  01250      14220000.0
# 17                NaN              NaN                  01310      12640000.0
# 18                NaN              NaN                  01310      12640000.0
# 20                NaN              NaN                  01000      10530501.0
# 21                NaN              NaN                  01000      10530501.0
# 22                NaN              NaN                  01240      10690000.0
# 23                NaN              NaN                  01240      10690000.0
# 24                NaN              NaN                  01960      13360000.0
# 25                NaN              NaN                  01000      13440000.0
# 26                NaN              NaN                  01440      14510102.0
# 27                NaN              NaN                  01440      14510102.0
# 28                NaN              NaN                  01000      10530302.0
# 29                NaN              NaN                  01370      12410000.0
# 30                NaN              NaN                  01190      10940000.0
# 31                NaN              NaN                  01290      13650000.0
# 32                NaN              NaN                  01340      12290000.0
# 33                NaN              NaN                  01340      12290000.0
# 34                NaN              NaN                  01000      10530101.0
# 35                NaN              NaN                  01560      11240000.0
# 36                NaN              NaN                  01270      14450000.0
# 37                NaN              NaN                  01340      10240000.0
# 38                NaN              NaN                  01160       013040000
# 39                NaN              NaN                  01190      10940000.0
# 40                NaN              NaN                  01190      10940000.0

# %%
adresses['corse'] = adresses['code_iris_clean'].str[0:2]
adresses = adresses[(adresses['corse'] != '2A') & (adresses['corse'] != '2B')]
adresses = adresses.drop(columns = {'corse'})
adresses.shape

adresses['code_iris_clean'] = adresses['code_iris_clean'].fillna(-1).astype(float).astype(int).astype(str)
adresses['code_iris_clean'] = adresses['code_iris_clean'].apply(lambda x: x.zfill(9))
adresses['code_iris_clean'] = adresses['code_iris_clean'].astype(str).replace('-00000001', np.nan)

adresses.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  No voie Type de voie                    Voie  \
# 0           0             0      NaN          NaN                FORTUNAT
# 1           1             1      NaN          NaN  TERRES DES CINQ SAULES
# 2           2             2      NaN          NaN      BOIS DU CHAMP RION
# 3           3             3      NaN          NaN             EN COROBERT
# 4           4             4      NaN          RUE        DE LA CHARTREUSE
#
#    Code postal    Commune           Ville                             Adresse  \
# 0       1250.0  CEYZERIAT  1250 CEYZERIAT             FORTUNAT 1250 CEYZERIAT
# 1       1290.0       LAIZ       1290 LAIZ    TERRES DES CINQ SAULES 1290 LAIZ
# 2       1290.0       LAIZ       1290 LAIZ        BOIS DU CHAMP RION 1290 LAIZ
# 3       1290.0       LAIZ       1290 LAIZ               EN COROBERT 1290 LAIZ
# 4       1960.0   PERONNAS   1960 PERONNAS  RUE DE LA CHARTREUSE 1960 PERONNAS
#
#   INSEE_COM  Commune_Lat  Commune_Lon       lon        lat Code departement  \
# 0    1072.0    46.183217     5.320072  5.323007  46.173753               01
# 1    1203.0    46.246992     4.899335  4.892457  46.246330               01
# 2    1203.0    46.246992     4.899335  4.892457  46.246330               01
# 3    1203.0    46.246992     4.899335  4.881913  46.248368               01
# 4    1289.0    46.171190     5.218022  5.227583  46.184979               01
#
#    Code commune Code commune INSEE  coordonnees_gps Code postal 5 chiffres  \
# 0           NaN                NaN              NaN                  01250
# 1           NaN                NaN              NaN                  01290
# 2           NaN                NaN              NaN                  01290
# 3           NaN                NaN              NaN                  01290
# 4           NaN                NaN              NaN                  01960
#
#   code_iris_clean
# 0       010720000
# 1       012030000
# 2       012030000
# 3       012030000
# 4       012890102

# %%
# On supprime les duplicates éventuels
adresses.drop_duplicates()
adresses.shape
# Out:
# (1112315, 20)

# %%
df.columns
# Out:
# Index(['No disposition', 'Date mutation', 'Nature mutation', 'Valeur fonciere',
#        'No voie', 'B/T/Q', 'Type de voie', 'Code voie', 'Voie', 'Code postal',
#        'Commune', 'Code departement', 'Code commune', 'Prefixe de section',
#        'Section', 'No plan', 'No Volume', '1er lot',
#        'Surface Carrez du 1er lot', '2eme lot', 'Surface Carrez du 2eme lot',
#        '3eme lot', 'Surface Carrez du 3eme lot', '4eme lot',
#        'Surface Carrez du 4eme lot', '5eme lot', 'Surface Carrez du 5eme lot',
#        'Nombre de lots', 'Code type local', 'Type local', 'Identifiant local',
#        'Surface reelle bati', 'Nombre pieces principales', 'Nature culture',
#        'Nature culture speciale', 'Surface terrain', 'Code commune INSEE',
#        'Ville', 'Adresse', 'Commune Alt', 'Prix m2', 'Paris', 'dep_name',
#        'region_name', 'Mer'],
#       dtype='object')

# %%
adresses.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'No voie', 'Type de voie', 'Voie',
#        'Code postal', 'Commune', 'Ville', 'Adresse', 'INSEE_COM',
#        'Commune_Lat', 'Commune_Lon', 'lon', 'lat', 'Code departement',
#        'Code commune', 'Code commune INSEE', 'coordonnees_gps',
#        'Code postal 5 chiffres', 'code_iris_clean'],
#       dtype='object')

# %%
adresses = adresses.drop(columns = {'Unnamed: 0', 'Unnamed: 0.1', 'No voie', 'Type de voie', 'Voie', 'Code postal',
                                   'Commune', 'Ville', 'INSEE_COM', 'Code departement', 'Code commune', 'Code commune INSEE',
                                    'coordonnees_gps'})
adresses.head()
# Out:
#                               Adresse  Commune_Lat  Commune_Lon       lon  \
# 0             FORTUNAT 1250 CEYZERIAT    46.183217     5.320072  5.323007
# 1    TERRES DES CINQ SAULES 1290 LAIZ    46.246992     4.899335  4.892457
# 2        BOIS DU CHAMP RION 1290 LAIZ    46.246992     4.899335  4.892457
# 3               EN COROBERT 1290 LAIZ    46.246992     4.899335  4.881913
# 4  RUE DE LA CHARTREUSE 1960 PERONNAS    46.171190     5.218022  5.227583
#
#          lat Code postal 5 chiffres code_iris_clean
# 0  46.173753                  01250       010720000
# 1  46.246330                  01290       012030000
# 2  46.246330                  01290       012030000
# 3  46.248368                  01290       012030000
# 4  46.184979                  01960       012890102

# %%
df = df.merge(adresses, on = "Adresse", how = "left")
df.head()
# Out:
#    No disposition Date mutation Nature mutation  Valeur fonciere  No voie  \
# 0               1    02/01/2020           Vente         268800.0     14.0
# 1               1    06/01/2020           Vente         878378.0      9.0
# 2               1    10/01/2020           Vente         680000.0     10.0
# 3               1    08/01/2020           Vente         370000.0     79.0
# 4               1    09/01/2020           Vente         741500.0    131.0
#
#   B/T/Q Type de voie Code voie             Voie  Code postal  ... Paris  \
# 0   NaN          RUE      0411      DE L'ARCADE      75008.0  ...     1
# 1   NaN           BD      5888  DE LA MADELEINE      75001.0  ...     1
# 2   NaN          RUE      1200  DU BOURG L'ABBE      75003.0  ...     1
# 3   NaN          RUE      0420     DES ARCHIVES      75003.0  ...     1
# 4   NaN          RUE      8525      SAINT DENIS      75001.0  ...     1
#
#    dep_name    region_name  Mer Commune_Lat  Commune_Lon       lon        lat  \
# 0     Paris  Île-de-France    0         NaN          NaN  2.323688  48.871652
# 1     Paris  Île-de-France    0         NaN          NaN  2.326961  48.869560
# 2     Paris  Île-de-France    0         NaN          NaN  2.351889  48.864062
# 3     Paris  Île-de-France    0         NaN          NaN  2.359887  48.863220
# 4     Paris  Île-de-France    0         NaN          NaN  2.347447  48.858758
#
#    Code postal 5 chiffres code_iris_clean
# 0                   75008       751083106
# 1                   75001       751010402
# 2                   75003       751031204
# 3                   75003       751031003
# 4                   75001       751010101
#
# [5 rows x 51 columns]

# %%
df.to_csv('04 - dvf_with_gps_iris.csv')
