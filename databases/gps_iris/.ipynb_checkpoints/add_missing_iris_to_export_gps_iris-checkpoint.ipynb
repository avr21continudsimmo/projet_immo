# %%
import pandas as pd

# %%
df = pd.read_csv('export_gps_iris_ALL.csv', dtype = {'Code postal 5 chiffres': str, 'Code commune INSEE': str,
                                             'code_iris': str})
df.head()
# Out:
# C:\Users\olivier\anaconda\envs\Geo\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (8) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    Unnamed: 0  No voie Type de voie                    Voie  Code postal  \
# 0           0      NaN          NaN                FORTUNAT       1250.0
# 1           1      NaN          NaN  TERRES DES CINQ SAULES       1290.0
# 2           2      NaN          NaN      BOIS DU CHAMP RION       1290.0
# 3           3      NaN          NaN             EN COROBERT       1290.0
# 4           4      NaN          RUE        DE LA CHARTREUSE       1960.0
#
#      Commune           Ville                             Adresse INSEE_COM  \
# 0  CEYZERIAT  1250 CEYZERIAT             FORTUNAT 1250 CEYZERIAT    1072.0
# 1       LAIZ       1290 LAIZ    TERRES DES CINQ SAULES 1290 LAIZ    1203.0
# 2       LAIZ       1290 LAIZ        BOIS DU CHAMP RION 1290 LAIZ    1203.0
# 3       LAIZ       1290 LAIZ               EN COROBERT 1290 LAIZ    1203.0
# 4   PERONNAS   1960 PERONNAS  RUE DE LA CHARTREUSE 1960 PERONNAS    1289.0
#
#    Commune_Lat  Commune_Lon   code_iris       lon        lat Code departement  \
# 0    46.183217     5.320072  10720000.0  5.323007  46.173753               01
# 1    46.246992     4.899335  12030000.0  4.892457  46.246330               01
# 2    46.246992     4.899335  12030000.0  4.892457  46.246330               01
# 3    46.246992     4.899335  12030000.0  4.881913  46.248368               01
# 4    46.171190     5.218022  12890102.0  5.227583  46.184979               01
#
#    Code commune Code commune INSEE  coordonnees_gps Code postal 5 chiffres
# 0           NaN                NaN              NaN                  01250
# 1           NaN                NaN              NaN                  01290
# 2           NaN                NaN              NaN                  01290
# 3           NaN                NaN              NaN                  01290
# 4           NaN                NaN              NaN                  01960

# %%
missing_iris = pd.read_csv('iris_missing_completed.csv')
missing_iris.head()
# Out:
# C:\Users\olivier\anaconda\envs\Geo\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (9,10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    Unnamed: 0  index                               Adresse  Commune_Lat  \
# 0           0      5      CHAMP PORTIER 1370 VAL-REVERMONT          NaN
# 1           1     19  5340 IMP GRAND CHAMP 1310 SAINT-REMY    46.184664
# 2           2     38         6058  OUSSIAT 1160 PONT-D AIN          NaN
# 3           3     42             5136  LE BOURG 1160 PRIAY    46.019752
# 4           4     43                   LE BOURG 1160 PRIAY    46.019752
#
#    Commune_Lon       lon        lat Code departement  Code postal 5 chiffres  \
# 0          NaN  5.342953  46.264482               01                  1370.0
# 1     5.167714  6.161794  49.174718               01                  1310.0
# 2          NaN  5.361196  46.055795               01                  1160.0
# 3     5.285234  5.207310  46.069185               01                  1160.0
# 4     5.285234  5.207310  46.069185               01                  1160.0
#
#   Code commune INSEE code_iris_clean
# 0              01426       014260000
# 1              01385             NaN
# 2              01304       013040000
# 3              01314             NaN
# 4              01314             NaN

# %%
missing_iris = missing_iris.drop(columns = {'Unnamed: 0', 'index', 'Commune_Lat', 'Commune_Lon', 'lon', 'lat', 'Code departement',
                            'Code postal 5 chiffres', 'Code commune INSEE'})
missing_iris.head()
# Out:
#                                 Adresse code_iris_clean
# 0      CHAMP PORTIER 1370 VAL-REVERMONT       014260000
# 1  5340 IMP GRAND CHAMP 1310 SAINT-REMY             NaN
# 2         6058  OUSSIAT 1160 PONT-D AIN       013040000
# 3             5136  LE BOURG 1160 PRIAY             NaN
# 4                   LE BOURG 1160 PRIAY             NaN

# %%
full_export = df.merge(missing_iris, on = "Adresse", how = "left")

# %%
full_export['code_iris_clean'] = full_export['code_iris_clean'].where(full_export['code_iris'].isna(), full_export['code_iris'])

# %%
full_export[full_export['code_iris_clean'].isna()].head()
# Out:
#      Unnamed: 0  No voie Type de voie          Voie  Code postal  \
# 19           19   5340.0          IMP   GRAND CHAMP       1310.0
# 42           42   5136.0          NaN      LE BOURG       1160.0
# 43           43      NaN          NaN      LE BOURG       1160.0
# 183         183      NaN          NaN   CHAMP DE LU       1340.0
# 184         184      NaN          NaN  BOIS DE L HU       1340.0
#
#                     Commune                        Ville  \
# 19               SAINT-REMY              1310 SAINT REMY
# 42                    PRIAY                   1160 PRIAY
# 43                    PRIAY                   1160 PRIAY
# 183  SAINT-DIDIER-D AUSSIAT  1340 SAINT DIDIER D AUSSIAT
# 184  SAINT-DIDIER-D AUSSIAT  1340 SAINT DIDIER D AUSSIAT
#
#                                       Adresse INSEE_COM  Commune_Lat  \
# 19       5340 IMP GRAND CHAMP 1310 SAINT-REMY    1385.0    46.184664
# 42                  5136  LE BOURG 1160 PRIAY    1314.0    46.019752
# 43                        LE BOURG 1160 PRIAY    1314.0    46.019752
# 183   CHAMP DE LU 1340 SAINT-DIDIER-D AUSSIAT       NaN          NaN
# 184  BOIS DE L HU 1340 SAINT-DIDIER-D AUSSIAT       NaN          NaN
#
#      Commune_Lon code_iris       lon        lat Code departement  \
# 19      5.167714       NaN  6.161794  49.174718               01
# 42      5.285234       NaN  5.207310  46.069185               01
# 43      5.285234       NaN  5.207310  46.069185               01
# 183          NaN       NaN       NaN        NaN               01
# 184          NaN       NaN       NaN        NaN               01
#
#      Code commune Code commune INSEE  coordonnees_gps Code postal 5 chiffres  \
# 19            NaN                NaN              NaN                  01310
# 42            NaN                NaN              NaN                  01160
# 43            NaN                NaN              NaN                  01160
# 183           NaN                NaN              NaN                  01340
# 184           NaN                NaN              NaN                  01340
#
#     code_iris_clean
# 19              NaN
# 42              NaN
# 43              NaN
# 183             NaN
# 184             NaN

# %%
full_export[full_export['code_iris'].isna()].head()
# Out:
#     Unnamed: 0  No voie Type de voie           Voie  Code postal  \
# 5            5      NaN          NaN  CHAMP PORTIER       1370.0
# 19          19   5340.0          IMP    GRAND CHAMP       1310.0
# 38          38   6058.0          NaN        OUSSIAT       1160.0
# 42          42   5136.0          NaN       LE BOURG       1160.0
# 43          43      NaN          NaN       LE BOURG       1160.0
#
#           Commune               Ville                               Adresse  \
# 5   VAL-REVERMONT  1370 VAL REVERMONT      CHAMP PORTIER 1370 VAL-REVERMONT
# 19     SAINT-REMY     1310 SAINT REMY  5340 IMP GRAND CHAMP 1310 SAINT-REMY
# 38     PONT-D AIN     1160 PONT D AIN         6058  OUSSIAT 1160 PONT-D AIN
# 42          PRIAY          1160 PRIAY             5136  LE BOURG 1160 PRIAY
# 43          PRIAY          1160 PRIAY                   LE BOURG 1160 PRIAY
#
#    INSEE_COM  Commune_Lat  Commune_Lon code_iris       lon        lat  \
# 5        NaN          NaN          NaN       NaN  5.342953  46.264482
# 19    1385.0    46.184664     5.167714       NaN  6.161794  49.174718
# 38       NaN          NaN          NaN       NaN  5.361196  46.055795
# 42    1314.0    46.019752     5.285234       NaN  5.207310  46.069185
# 43    1314.0    46.019752     5.285234       NaN  5.207310  46.069185
#
#    Code departement  Code commune Code commune INSEE  coordonnees_gps  \
# 5                01           NaN                NaN              NaN
# 19               01           NaN                NaN              NaN
# 38               01           NaN                NaN              NaN
# 42               01           NaN                NaN              NaN
# 43               01           NaN                NaN              NaN
#
#    Code postal 5 chiffres code_iris_clean
# 5                   01370       014260000
# 19                  01310             NaN
# 38                  01160       013040000
# 42                  01160             NaN
# 43                  01160             NaN

# %%
full_export = full_export.drop(columns = {'code_iris'})
full_export.head()
# Out:
#    Unnamed: 0  No voie Type de voie                    Voie  Code postal  \
# 0           0      NaN          NaN                FORTUNAT       1250.0
# 1           1      NaN          NaN  TERRES DES CINQ SAULES       1290.0
# 2           2      NaN          NaN      BOIS DU CHAMP RION       1290.0
# 3           3      NaN          NaN             EN COROBERT       1290.0
# 4           4      NaN          RUE        DE LA CHARTREUSE       1960.0
#
#      Commune           Ville                             Adresse INSEE_COM  \
# 0  CEYZERIAT  1250 CEYZERIAT             FORTUNAT 1250 CEYZERIAT    1072.0
# 1       LAIZ       1290 LAIZ    TERRES DES CINQ SAULES 1290 LAIZ    1203.0
# 2       LAIZ       1290 LAIZ        BOIS DU CHAMP RION 1290 LAIZ    1203.0
# 3       LAIZ       1290 LAIZ               EN COROBERT 1290 LAIZ    1203.0
# 4   PERONNAS   1960 PERONNAS  RUE DE LA CHARTREUSE 1960 PERONNAS    1289.0
#
#    Commune_Lat  Commune_Lon       lon        lat Code departement  \
# 0    46.183217     5.320072  5.323007  46.173753               01
# 1    46.246992     4.899335  4.892457  46.246330               01
# 2    46.246992     4.899335  4.892457  46.246330               01
# 3    46.246992     4.899335  4.881913  46.248368               01
# 4    46.171190     5.218022  5.227583  46.184979               01
#
#    Code commune Code commune INSEE  coordonnees_gps Code postal 5 chiffres  \
# 0           NaN                NaN              NaN                  01250
# 1           NaN                NaN              NaN                  01290
# 2           NaN                NaN              NaN                  01290
# 3           NaN                NaN              NaN                  01290
# 4           NaN                NaN              NaN                  01960
#
#   code_iris_clean
# 0      10720000.0
# 1      12030000.0
# 2      12030000.0
# 3      12030000.0
# 4      12890102.0

# %%
full_export['code_iris_clean'].isna().sum()
# Out:
# 63683

# %%
full_export.to_csv('export_gps_iris_ALL.csv')
